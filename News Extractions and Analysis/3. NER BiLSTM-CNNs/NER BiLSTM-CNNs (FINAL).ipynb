# %% [markdown]
# ### import libraries

# %%
import pandas as pd
import numpy as np
from keras.models import Model, load_model
from keras.layers import TimeDistributed, Conv1D, Dense, Embedding, Input, Dropout, LSTM, Bidirectional, MaxPooling1D, \
    Flatten, concatenate
from keras.utils import plot_model, Progbar
from keras.initializers import RandomUniform
from keras.optimizers import SGD, Nadam
import numpy as np
from keras.callbacks import Callback
from seqeval.metrics import accuracy_score,classification_report,f1_score
from copy import deepcopy
import seqeval
import tensorflow as tf
from keras import backend as K
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

# %%
# Built-in functions
from withpos.preprocessing import iterate_minibatches, padding, convLabels

from withpos.preprocessing_labeled import toLabeledNER, readLabeled, toArray, createBatches, createMatrices, \
        addCharInformation, tag_dataset
from withpos.preprocessing_newdata import toArray_new,createBatches_new, createMatrices_new, \
        addCharInformation_new,tag_dataset_new, get_prediction_ner_new, prediction_ner_to_df_new

# %% [markdown]
# ## Load POS Tagged Data, and Take Random Sample

# %%
# Load Data
data_main = pd.read_csv("./../2. POS TAGGING/OUTPUT/POS_CLEAN.csv",index_col=0)

# Take random sample
random_index = list(pd.read_csv("./INPUT/random index.csv", index_col=0)['index'])
sample = data_main.loc[random_index]
sample
# Out:
#                                                    Link            Date Time  \
# 3033  https://radarbromo.jawapos.com/kraksaan/30/12/...  2020-12-30 00:00:00
# 1287  https://radarjember.jawapos.com/berita-daerah/...  2020-12-29 14:10:00
# 3046  https://radarbromo.jawapos.com/probolinggo/29/...  2020-12-29 00:00:00
# 510   https://jatimnow.com/baca-32404-pemotor-asal-n...  2020-12-28 16:46:36
# 511   https://jatimnow.com/baca-32400-bocah-3-tahun-...  2020-12-28 15:18:19
# ...                                                 ...                  ...
# 2739  https://radarmadiun.jawapos.com/dump-truk-puta...  2020-04-03 17:26:00
# 465   https://news.detik.com/berita-jawa-timur/d-486...  2020-01-22 16:55:00
# 1077  https://radarbromo.jawapos.com/utama/20/03/202...  2020-03-20 02:02:12
# 1067  https://radarsurabaya.jawapos.com/read/2020/04...  2020-04-03 17:28:22
# 1141  https://radarbromo.jawapos.com/utama/16/01/202...  2020-01-16 21:15:29
#
#                                                   Title  \
# 3033  Menyeberang, Tukang Becak Tewas Tertabrak Truk...
# 1287                       Waduh, kok Bisa Menerobos?\n
# 3046  Rem Motor Matik Blong, Sekeluarga Terjun ke Pe...
# 510   Pemotor asal Nganjuk Tewas dalam Kecelakaan di...
# 511   Bocah 3 Tahun di Pacitan Tewas Tertabrak Truk ...
# ...                                                 ...
# 2739  Dump Truk Putar Balik Dihantam Beat ÃÂÃÂ¢Ã...
# 465   Pegawai Dishub Tewas Terlindas Truk di Jalur P...
# 1077  Sopir Ngantuk, Minibus Tabrak Median di Jalan ...
# 1067  Ngantuk, Pemotor Tabrak Truk Trailer yang Teng...
# 1141  Selip saat Hujan, Truk Boks Ini Tabrak Genio d...
#
#                                                 Content  Label
# 3033  KRAKSAAN <PROPN> , <PUNCT> Radar <PROPN> Bromo...    1.0
# 1287  TEROBOS <NOUN> LINTASAN <NOUN> : <PUNCT> Sebua...    1.0
# 3046  SUMBER <PROPN> , <PUNCT> Radar <PROPN> Bromo <...    1.0
# 510   jatimnow.com <PROPN> - <PUNCT> Arief <PROPN> (...    1.0
# 511   jatimnow.com <PROPN> - <PUNCT> Seorang <DET> b...    1.0
# ...                                                 ...    ...
# 2739  PACITAN <PROPN> , <PUNCT> Jawa <PROPN> Pos <PR...    1.0
# 465   Situbondo <PROPN> - <PUNCT> Seorang <DET> pega...    1.0
# 1077  PASURUAN <PROPN> , <PUNCT> Radar <PROPN> Bromo...    1.0
# 1067  GRESIKNasib <NOUN> sial <ADJ> dialami <VERB> N...    1.0
# 1141  BEJI <PROPN> , <PUNCT> Radar <PROPN> Bromo <PR...    1.0
#
# [228 rows x 5 columns]

# %% [markdown]
# ## Labeling

# %% [markdown]
# Function toLabeledNER untuk membuat hasil POS Tag menjadi tabel yang bisa dilabeli dengan mudah

# %%
to_label = toLabeledNER(sample,'Content')
to_label
# Out:
#       article sentence                          word      pos
# 0        3033           ----------DOCSTART----------
# 1        3033        0                      KRAKSAAN  <PROPN>
# 2        3033        0                             ,  <PUNCT>
# 3        3033        0                         Radar  <PROPN>
# 4        3033        0                         Bromo  <PROPN>
# ...       ...      ...                           ...      ...
# 60428    1141     3814                        lancar   <VERB>
# 60429    1141     3814                      beberapa    <DET>
# 60430    1141     3814                           jam   <NOUN>
# 60431    1141     3814                      kemudian    <ADV>
# 60432    1141     3814                             .  <PUNCT>
#
# [60433 rows x 4 columns]

# %% [markdown]
# Load data yang telah diberi anotasi manual

# %% [markdown]
# ## Load data

# %%
data_ = readLabeled(FILE_DIR = "./INPUT/TO_LABELLING_NER-LABELED.csv")
data_
# Out:
#       article sentence                          word      pos     ner
# 0        3033      NaN  ----------DOCSTART----------      NaN       O
# 1        3033        0                      KRAKSAAN  <PROPN>       O
# 2        3033        0                             ,  <PUNCT>       O
# 3        3033        0                         Radar  <PROPN>  B-MISC
# 4        3033        0                         Bromo  <PROPN>  I-MISC
# ...       ...      ...                           ...      ...     ...
# 60428    1141     3814                        lancar   <VERB>       O
# 60429    1141     3814                      beberapa    <DET>       O
# 60430    1141     3814                           jam   <NOUN>       O
# 60431    1141     3814                      kemudian    <ADV>       O
# 60432    1141     3814                             .  <PUNCT>       O
#
# [60433 rows x 5 columns]

# %%
# Remove barrier
data = data_[pd.Series(['DOCSTART' not in str(i) for i in data_.word])]
data['pos']=data['pos'].apply(lambda x: x.replace('<','').replace('>','').replace('<','').replace('>','') if type(x)==str else None)
data.index = range(len(data))

data
# Out:
# <ipython-input-6-0c0cdde6d9d2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pos']=data['pos'].apply(lambda x: x.replace('<','').replace('>','').replace('<','').replace('>','') if type(x)==str else None)
#       article sentence      word    pos     ner
# 0        3033        0  KRAKSAAN  PROPN       O
# 1        3033        0         ,  PUNCT       O
# 2        3033        0     Radar  PROPN  B-MISC
# 3        3033        0     Bromo  PROPN  I-MISC
# 4        3033        0     Nahas  PROPN       O
# ...       ...      ...       ...    ...     ...
# 60200    1141     3814    lancar   VERB       O
# 60201    1141     3814  beberapa    DET       O
# 60202    1141     3814       jam   NOUN       O
# 60203    1141     3814  kemudian    ADV       O
# 60204    1141     3814         .  PUNCT       O
#
# [60205 rows x 5 columns]

# %%
# Convert to array format
array = toArray(data)
array
# Out:
# [[['KRAKSAAN', 'O', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Radar', 'B-MISC', 'PROPN'],
#   ['Bromo', 'I-MISC', 'PROPN'],
#   ['Nahas', 'O', 'PROPN'],
#   ['menimpa', 'O', 'VERB'],
#   ['Miskari', 'B-PER', 'PUNCT'],
#   ['59', 'B-AGE', 'NUM'],
#   [',', 'O', 'PUNCT'],
#   ['Selasa', 'B-DATE', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['29/12', 'B-DATE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['malam', 'B-TIME', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Tukang', 'O', 'PROPN'],
#   ['becak', 'B-VEHICLE', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['ditabrak', 'O', 'VERB'],
#   ['sebuah', 'O', 'DET'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['boks', 'I-VEHICLE', 'NOUN'],
#   ['saat', 'O', 'SCONJ'],
#   ['hendak', 'O', 'ADV'],
#   ['menyeberang', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['jalan', 'B-LOC', 'NOUN'],
#   ['raya', 'I-LOC', 'NOUN'],
#   ['Kelurahan', 'I-LOC', 'PROPN'],
#   ['Patokan', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kraksaan', 'B-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Probolinggo', 'I-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Ia', 'O', 'PRON'],
#   ['pun', 'O', 'PART'],
#   ['langsung', 'O', 'ADV'],
#   ['meninggal', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['lokasi', 'O', 'NOUN'],
#   ['kejadian', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kecelakaan', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['terjadi', 'O', 'VERB'],
#   ['sekitar', 'O', 'ADP'],
#   ['pukul', 'O', 'NOUN'],
#   ['21', 'B-TIME', 'NUM'],
#   ['.', 'O', 'PUNCT']],
#  [['Saat', 'O', 'SCONJ'],
#   ['itu', 'O', 'DET'],
#   ['warga', 'O', 'NOUN'],
#   ['Kelurahan', 'B-LOC', 'PROPN'],
#   ['Sidomukti', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kraksaan', 'B-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['itu', 'O', 'DET'],
#   ['tengah', 'O', 'NOUN'],
#   ['mengayuh', 'O', 'VERB'],
#   ['becaknya', 'B-VEHICLE', 'NOUN'],
#   ['dari', 'O', 'ADP'],
#   ['timur', 'O', 'NOUN'],
#   ['ke', 'O', 'ADP'],
#   ['barat', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Dia', 'O', 'PRON'],
#   ['mengayuh', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['lajur', 'O', 'NOUN'],
#   ['selatan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['tepatnya', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['barat', 'O', 'NOUN'],
#   ['jembatan', 'B-LOC', 'NOUN'],
#   ['kembar', 'I-LOC', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['Kraksaan', 'B-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Sesaat', 'O', 'SCONJ'],
#   ['kemudian', 'O', 'ADV'],
#   [',', 'O', 'PUNCT'],
#   ['Miskari', 'B-PER', 'PROPN'],
#   ['menyeberang', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['utara', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Lalu', 'O', 'SCONJ'],
#   [',', 'O', 'PUNCT'],
#   ['dari', 'O', 'ADP'],
#   ['arah', 'O', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['sama', 'O', 'ADJ'],
#   ['meluncur', 'O', 'VERB'],
#   ['sebuah', 'O', 'DET'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['boks', 'I-VEHICLE', 'NOUN'],
#   ['bernopol', 'O', 'PROPN'],
#   ['L', 'B-PLATE', 'PROPN'],
#   ['8672', 'I-PLATE', 'NUM'],
#   ['AK', 'I-PLATE', 'PROPN'],
#   ['disopiri', 'O', 'PROPN'],
#   ['Dwi', 'B-PER', 'PROPN'],
#   ['Julianto', 'I-PER', 'PROPN'],
#   ['Maulana', 'I-PER', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['23', 'B-AGE', 'NUM'],
#   [',', 'O', 'PUNCT'],
#   ['warga', 'O', 'NOUN'],
#   ['Sumbertaman', 'B-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Wonoasih', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kota', 'B-LOC', 'PROPN'],
#   ['Probolinggo', 'I-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Diduga', 'O', 'PROPN'],
#   ['kurang', 'B-CAUSE', 'ADV'],
#   ['konsentrasi', 'I-CAUSE', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['langsung', 'O', 'ADJ'],
#   ['menabrak', 'O', 'VERB'],
#   ['becak', 'B-VEHICLE', 'NOUN'],
#   ['tanpa', 'O', 'ADP'],
#   ['muatan', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['.', 'O', 'PUNCT']],
#  [['Becak', 'B-VEHICLE', 'PROPN'],
#   ['pun', 'O', 'PART'],
#   ['langsung', 'O', 'ADV'],
#   ['terguling', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['lokasi', 'O', 'NOUN'],
#   ['kejadian', 'O', 'NOUN'],
#   ['bersama', 'O', 'ADP'],
#   ['korban', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kanitlaka', 'B-ORG', 'ADP'],
#   ['Satlantas', 'I-ORG', 'PROPN'],
#   ['Polres', 'I-ORG', 'PROPN'],
#   ['Probolinggo', 'I-ORG', 'PROPN'],
#   ['Ipda', 'B-PER', 'PROPN'],
#   ['Nyoman', 'I-PER', 'PROPN'],
#   ['Harayasa', 'I-PER', 'PUNCT'],
#   ['mengatakan', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['boks', 'I-VEHICLE', 'NOUN'],
#   ['kehilangan', 'O', 'VERB'],
#   ['kendali', 'O', 'NOUN'],
#   ['saat', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['.', 'O', 'PUNCT']],
#  [['Kemudian', 'O', 'ADV'],
#   ['menabrak', 'O', 'VERB'],
#   ['becak', 'B-VEHICLE', 'NOUN'],
#   ['tanpa', 'O', 'ADP'],
#   ['penumpang', 'O', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['dikayuh', 'O', 'VERB'],
#   ['korban', 'O', 'NOUN'],
#   ['Miskari', 'B-PER', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['Insiden', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['membuat', 'O', 'VERB'],
#   ['kepala', 'O', 'NOUN'],
#   ['korban', 'O', 'NOUN'],
#   ['luka', 'O', 'NOUN'],
#   ['parah', 'O', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['Dari', 'O', 'ADP'],
#   ['hasil', 'O', 'NOUN'],
#   ['olah', 'O', 'NOUN'],
#   ['TKP', 'O', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['pengemudi', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['boks', 'I-VEHICLE', 'NOUN'],
#   ['diduga', 'O', 'VERB'],
#   ['kurang', 'B-CAUSE', 'ADV'],
#   ['konsentrasi', 'I-CAUSE', 'NOUN'],
#   ['saat', 'O', 'SCONJ'],
#   ['sedang', 'O', 'ADV'],
#   ['mengemudi', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Akibat', 'O', 'SCONJ'],
#   ['kejadian', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   [',', 'O', 'PUNCT'],
#   ['korban', 'O', 'NOUN'],
#   ['langsung', 'O', 'ADJ'],
#   ['meninggal', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['TKP', 'O', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['ujar', 'O', 'PROPN'],
#   ['Nyoman', 'B-PER', 'PROPN'],
#   ['saat', 'O', 'SCONJ'],
#   ['dikonfirmasi', 'O', 'VERB'],
#   ['Rabu', 'B-DATE', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['30/12', 'B-DATE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['.', 'O', 'PUNCT']],
#  [['Usai', 'O', 'PROPN'],
#   ['menabrak', 'O', 'VERB'],
#   ['korban', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['menurut', 'O', 'ADP'],
#   ['Nyoman', 'B-PER', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['pengemudi', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['boks', 'I-VEHICLE', 'NOUN'],
#   ['tidak', 'O', 'PART'],
#   ['langsung', 'O', 'ADV'],
#   ['berhenti', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Dia', 'O', 'PRON'],
#   ['malah', 'O', 'ADV'],
#   ['hendak', 'O', 'ADV'],
#   ['kabur', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Namun', 'O', 'SCONJ'],
#   [',', 'O', 'PUNCT'],
#   ['warga', 'O', 'NOUN'],
#   ['sekitar', 'O', 'ADP'],
#   ['yang', 'O', 'PRON'],
#   ['melihat', 'O', 'VERB'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['langsung', 'O', 'ADV'],
#   ['menghentikan', 'O', 'VERB'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['boks', 'I-VEHICLE', 'NOUN'],
#   ['tersebut', 'O', 'DET'],
#   ['.', 'O', 'PUNCT']],
#  [['Usai', 'O', 'ADV'],
#   ['menabrak', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['boks', 'I-VEHICLE', 'NOUN'],
#   ['tidak', 'O', 'PART'],
#   ['langsung', 'O', 'ADV'],
#   ['berhenti', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Malah', 'O', 'ADV'],
#   ['tetap', 'O', 'ADV'],
#   ['melaju', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['arah', 'O', 'NOUN'],
#   ['barat', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Untungnya', 'O', 'VERB'],
#   ['oleh', 'O', 'ADP'],
#   ['warga', 'O', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['sekitar', 'O', 'ADP'],
#   ['TKP', 'O', 'PROPN'],
#   ['dikejar', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Saat', 'O', 'NOUN'],
#   ['ini', 'O', 'DET'],
#   ['dua', 'O', 'NUM'],
#   ['kendaraan', 'O', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['terlibat', 'O', 'VERB'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['sudah', 'O', 'ADV'],
#   ['kami', 'O', 'PRON'],
#   ['amankan', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['pos', 'B-ORG', 'NOUN'],
#   ['lantas', 'I-ORG', 'ADJ'],
#   [',', 'O', 'PUNCT'],
#   ['katanya', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Mau', 'O', 'PROPN'],
#   ['Nyalip', 'B-PER', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Ditabrak', 'O', 'VERB'],
#   ['TrailerSebelumnya', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['di', 'O', 'ADP'],
#   ['malam', 'O', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['sama', 'O', 'ADJ'],
#   ['juga', 'O', 'ADV'],
#   ['terjadi', 'O', 'VERB'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['Jalan', 'B-LOC', 'PROPN'],
#   ['Raya', 'I-LOC', 'PROPN'],
#   ['Pajurangan', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Gending', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Probolinggo', 'I-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kecelakaan', 'O', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['terjadi', 'O', 'VERB'],
#   ['sekitar', 'O', 'ADP'],
#   ['pukul', 'O', 'NOUN'],
#   ['19', 'B-TIME', 'NUM'],
#   [',', 'O', 'PUNCT'],
#   ['itu', 'O', 'DET'],
#   ['melibatkan', 'O', 'VERB'],
#   ['dua', 'O', 'NUM'],
#   ['kendaraan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Yaitu', 'O', 'ADV'],
#   [',', 'O', 'PUNCT'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['Honda', 'I-VEHICLE', 'PROPN'],
#   ['Vario', 'I-VEHICLE', 'PROPN'],
#   ['nopol', 'O', 'PROPN'],
#   ['N', 'B-PLATE', 'PROPN'],
#   ['5914', 'I-PLATE', 'NUM'],
#   ['N', 'I-PLATE', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['dikendarai', 'O', 'VERB'],
#   ['Muhammad', 'B-PER', 'PROPN'],
#   ['Saiful', 'I-PER', 'PROPN'],
#   ['Amin', 'I-PER', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['20', 'B-AGE', 'NUM'],
#   [',', 'O', 'PUNCT'],
#   ['warga', 'O', 'NOUN'],
#   ['RT', 'B-LOC', 'PROPN'],
#   ['3/RW', 'I-LOC', 'PUNCT'],
#   ['1', 'I-LOC', 'NUM'],
#   [',', 'O', 'PUNCT'],
#   ['Desa', 'B-LOC', 'PROPN'],
#   ['Alassumur', 'I-LOC', 'PROPN'],
#   ['Lor', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Besuk', 'I-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Dan', 'O', 'CCONJ'],
#   ['satu', 'O', 'NUM'],
#   ['lagi', 'O', 'ADV'],
#   [',', 'O', 'PUNCT'],
#   ['yaitu', 'O', 'SCONJ'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['trailer', 'I-VEHICLE', 'NOUN'],
#   ['Nopol', 'O', 'PROPN'],
#   ['L', 'B-PLATE', 'PROPN'],
#   ['9299', 'I-PLATE', 'NUM'],
#   ['UL', 'I-PLATE', 'PROPN'],
#   ['yang', 'O', 'PRON'],
#   ['disopiri', 'O', 'VERB'],
#   ['Joyo', 'B-PER', 'PROPN'],
#   ['Kamsono', 'I-PER', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['62', 'B-AGE', 'NUM'],
#   [',', 'O', 'PUNCT'],
#   ['warga', 'O', 'NOUN'],
#   ['Desa', 'B-LOC', 'PROPN'],
#   ['Talok', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Bangsal', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Mojokerto', 'I-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kanitlaka', 'B-ORG', 'PROPN'],
#   ['Satlantas', 'I-ORG', 'PROPN'],
#   ['Polres', 'I-ORG', 'PROPN'],
#   ['Probolinggo', 'I-ORG', 'PROPN'],
#   ['Ipda', 'B-PER', 'PROPN'],
#   ['Nyoman', 'I-PER', 'PROPN'],
#   ['Harayasa', 'I-PER', 'PROPN'],
#   ['menjelaskan', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['awalnya', 'O', 'ADV'],
#   ['pengendara', 'O', 'NOUN'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['melaju', 'O', 'VERB'],
#   ['dari', 'O', 'ADP'],
#   ['barat', 'O', 'NOUN'],
#   ['ke', 'O', 'ADP'],
#   ['timur', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Sampai', 'O', 'ADP'],
#   ['di', 'O', 'ADP'],
#   ['Jalan', 'B-LOC', 'PROPN'],
#   ['Raya', 'I-LOC', 'PROPN'],
#   ['Pajurangan', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['hendak', 'O', 'ADV'],
#   ['menyalip', 'O', 'VERB'],
#   ['sebuah', 'O', 'DET'],
#   ['kendaraan', 'O', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['depannya', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Namun', 'O', 'SCONJ'],
#   [',', 'O', 'PUNCT'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['menyalip', 'B-CAUSE', 'VERB'],
#   ['terlalu', 'I-CAUSE', 'ADV'],
#   ['ke', 'I-CAUSE', 'ADP'],
#   ['kanan', 'I-CAUSE', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Dalam', 'O', 'ADP'],
#   ['waktu', 'O', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['sama', 'O', 'ADJ'],
#   [',', 'O', 'PUNCT'],
#   ['melaju', 'O', 'VERB'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['trailer', 'I-VEHICLE', 'NOUN'],
#   ['dari', 'O', 'ADP'],
#   ['arah', 'O', 'NOUN'],
#   ['berlawanan', 'O', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['Akibatnya', 'O', 'SCONJ'],
#   [',', 'O', 'PUNCT'],
#   ['terjadilah', 'O', 'VERB'],
#   ['tabrakan', 'O', 'NOUN'],
#   ['antara', 'O', 'ADP'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['trailer', 'I-VEHICLE', 'NOUN'],
#   ['dan', 'O', 'CCONJ'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['.', 'I-VEHICLE', 'PUNCT']],
#  [['Pengendara', 'O', 'NOUN'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['Saiful', 'B-PER', 'PROPN'],
#   ['Amin', 'I-PER', 'PROPN'],
#   ['langsung', 'O', 'ADV'],
#   ['dilarikan', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['IGD', 'B-MISC', 'PROPN'],
#   ['RSUD', 'I-MISC', 'PROPN'],
#   ['Waluyo', 'I-MISC', 'PROPN'],
#   ['Jati', 'I-MISC', 'PROPN'],
#   ['Kraksaan', 'I-MISC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Tapi', 'O', 'SCONJ'],
#   ['hanya', 'O', 'ADV'],
#   ['mengalami', 'O', 'VERB'],
#   ['luka', 'O', 'NOUN'],
#   ['ringan', 'O', 'ADJ'],
#   [',', 'O', 'PUNCT'],
#   ['terang', 'O', 'ADJ'],
#   ['Nyoman', 'B-PER', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Adapun', 'O', 'SCONJ'],
#   ['supir', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['trailer', 'I-VEHICLE', 'NOUN'],
#   ['tidak', 'O', 'PART'],
#   ['terluka', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Truk', 'B-VEHICLE', 'PROPN'],
#   ['trailer', 'I-VEHICLE', 'PROPN'],
#   ['juga', 'O', 'ADV'],
#   ['tidak', 'O', 'PART'],
#   ['ada', 'O', 'VERB'],
#   ['yang', 'O', 'PRON'],
#   ['rusak', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Sementara', 'O', 'SCONJ'],
#   ['sepeda', 'B-VEHICLE', 'NOUN'],
#   ['motor', 'I-VEHICLE', 'NOUN'],
#   ['pengendara', 'O', 'NOUN'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['Saiful', 'B-PER', 'PROPN'],
#   ['Amin', 'I-PER', 'PROPN'],
#   ['hancur', 'O', 'VERB'],
#   ['parah', 'O', 'ADJ'],
#   ['di', 'O', 'ADP'],
#   ['bagian', 'O', 'NOUN'],
#   ['depan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['TEROBOS', 'O', 'NOUN'],
#   ['LINTASAN', 'O', 'NOUN'],
#   [':', 'O', 'PUNCT'],
#   ['Sebuah', 'O', 'DET'],
#   ['mobil', 'B-VEHICLE', 'NOUN'],
#   ['Isuzu', 'I-VEHICLE', 'PROPN'],
#   ['Panther', 'I-VEHICLE', 'PROPN'],
#   ['bernopol', 'O', 'PROPN'],
#   ['P', 'B-PLATE', 'PROPN'],
#   ['1249', 'I-PLATE', 'NUM'],
#   ['GA', 'I-PLATE', 'PROPN'],
#   ['tampak', 'O', 'VERB'],
#   ['menerobos', 'O', 'VERB'],
#   ['perlintasan', 'O', 'NOUN'],
#   ['kereta', 'B-VEHICLE', 'NOUN'],
#   ['api', 'I-VEHICLE', 'NOUN'],
#   ['walaupun', 'O', 'SCONJ'],
#   ['sudah', 'O', 'ADV'],
#   ['ditutup', 'O', 'VERB'],
#   ['oleh', 'O', 'ADP'],
#   ['petugas', 'O', 'NOUN'],
#   ['jaga', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['JEMBER', 'O', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['RADARJEMBER.ID', 'O', 'PROPN'],
#   ['Terjadinya', 'O', 'VERB'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['jalan', 'O', 'NOUN'],
#   ['raya', 'O', 'NOUN'],
#   ['kerap', 'O', 'ADV'],
#   ['kali', 'O', 'ADV'],
#   ['diawali', 'O', 'VERB'],
#   ['dengan', 'O', 'ADP'],
#   ['pelanggaran', 'O', 'NOUN'],
#   ['atau', 'O', 'CCONJ'],
#   ['kecerobohan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Seperti', 'O', 'ADP'],
#   ['mobil', 'B-VEHICLE', 'NOUN'],
#   ['Isuzu', 'I-VEHICLE', 'PROPN'],
#   ['Panther', 'I-VEHICLE', 'PROPN'],
#   ['P', 'B-PLATE', 'PROPN'],
#   ['1249', 'I-PLATE', 'NUM'],
#   ['GA', 'I-PLATE', 'PROPN'],
#   ['yang', 'O', 'PRON'],
#   ['melintas', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['Jalan', 'B-LOC', 'PROPN'],
#   ['Udang', 'I-LOC', 'PROPN'],
#   ['Windu', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kelurahan', 'B-LOC', 'PROPN'],
#   ['Mangli', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Kaliwates', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Senin', 'B-DATE', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['28/12', 'B-DATE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['siang', 'B-TIME', 'NOUN'],
#   ['kemarin', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Mobil', 'B-VEHICLE', 'PROPN'],
#   ['ini', 'O', 'DET'],
#   ['tampak', 'O', 'VERB'],
#   ['melewati', 'O', 'VERB'],
#   ['palang', 'O', 'NOUN'],
#   ['pintu', 'O', 'NOUN'],
#   ['perlintasan', 'O', 'NOUN'],
#   ['kereta', 'B-VEHICLE', 'NOUN'],
#   ['api', 'I-VEHICLE', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Saat', 'O', 'SCONJ'],
#   ['petugas', 'O', 'NOUN'],
#   ['jaga', 'O', 'NOUN'],
#   ['perlintasan', 'O', 'NOUN'],
#   ['kereta', 'B-VEHICLE', 'NOUN'],
#   ['api', 'I-VEHICLE', 'NOUN'],
#   ['(', 'O', 'PUNCT'],
#   ['KA', 'B-VEHICLE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['di', 'O', 'ADP'],
#   ['Jalan', 'B-LOC', 'PROPN'],
#   ['Udang', 'I-LOC', 'PROPN'],
#   ['Windu', 'I-LOC', 'PROPN'],
#   ['tersebut', 'O', 'DET'],
#   ['menutup', 'O', 'VERB'],
#   ['perlintasan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['sopir', 'O', 'NOUN'],
#   ['tetap', 'O', 'ADV'],
#   ['menerobos', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Padahal', 'O', 'SCONJ'],
#   ['sirene', 'O', 'NOUN'],
#   ['pertanda', 'O', 'NOUN'],
#   ['perlintasan', 'O', 'NOUN'],
#   ['akan', 'O', 'ADV'],
#   ['ditutup', 'O', 'VERB'],
#   ['sudah', 'O', 'ADV'],
#   ['berbunyi', 'O', 'VERB'],
#   ['cukup', 'O', 'ADV'],
#   ['lantang', 'O', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['Bahkan', 'O', 'SCONJ'],
#   [',', 'O', 'PUNCT'],
#   ['ketika', 'O', 'SCONJ'],
#   ['hendak', 'O', 'ADV'],
#   ['menutup', 'O', 'VERB'],
#   ['pintu', 'O', 'NOUN'],
#   ['perlintasan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['petugas', 'O', 'NOUN'],
#   ['jaga', 'O', 'NOUN'],
#   ['harus', 'O', 'ADV'],
#   ['menundanya', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Sayangnya', 'O', 'ADV'],
#   [',', 'O', 'PUNCT'],
#   ['jarak', 'O', 'NOUN'],
#   ['antara', 'O', 'ADP'],
#   ['mobil', 'B-VEHICLE', 'NOUN'],
#   ['dengan', 'O', 'ADP'],
#   ['perlintasan', 'O', 'NOUN'],
#   ['kereta', 'B-VEHICLE', 'NOUN'],
#   ['sudah', 'O', 'ADV'],
#   ['sangat', 'O', 'ADV'],
#   ['dekat', 'O', 'ADJ'],
#   [',', 'O', 'PUNCT'],
#   ['sehingga', 'O', 'SCONJ'],
#   ['mau', 'O', 'ADV'],
#   ['tidak', 'O', 'PART'],
#   ['mau', 'O', 'VERB'],
#   ['mobil', 'B-VEHICLE', 'NOUN'],
#   ['tersebut', 'O', 'DET'],
#   ['harus', 'O', 'ADV'],
#   ['berhenti', 'O', 'VERB'],
#   ['tepat', 'O', 'ADJ'],
#   ['di', 'O', 'ADP'],
#   ['samping', 'O', 'NOUN'],
#   ['rel', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Tentu', 'O', 'ADV'],
#   ['saja', 'O', 'ADV'],
#   [',', 'O', 'PUNCT'],
#   ['jaraknya', 'O', 'VERB'],
#   ['dengan', 'O', 'ADP'],
#   ['kereta', 'B-VEHICLE', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['melaju', 'O', 'VERB'],
#   ['sangat', 'O', 'ADV'],
#   ['dekat', 'O', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['Beruntung', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['masih', 'O', 'ADV'],
#   ['ada', 'O', 'VERB'],
#   ['jarak', 'O', 'NOUN'],
#   ['antara', 'O', 'ADP'],
#   ['perlintasan', 'O', 'NOUN'],
#   ['dengan', 'O', 'ADP'],
#   ['pintu', 'O', 'NOUN'],
#   ['KA', 'B-VEHICLE', 'PROPN'],
#   ['yang', 'O', 'PRON'],
#   ['ditutup', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Kondisi', 'O', 'NOUN'],
#   ['ini', 'O', 'DET'],
#   ['tentu', 'O', 'ADV'],
#   ['sangat', 'O', 'ADV'],
#   ['membahayakan', 'O', 'VERB'],
#   ['tidak', 'O', 'PART'],
#   ['hanya', 'O', 'ADV'],
#   ['bagi', 'O', 'ADP'],
#   ['pengguna', 'O', 'NOUN'],
#   ['jalan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['namun', 'O', 'SCONJ'],
#   ['juga', 'O', 'ADV'],
#   ['rangkaian', 'O', 'NOUN'],
#   ['kereta', 'B-VEHICLE', 'NOUN'],
#   ['api', 'I-VEHICLE', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['melintas', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Ayo', 'O', 'PROPN'],
#   ['tertib', 'O', 'PROPN'],
#   ['berlalu', 'O', 'VERB'],
#   ['lintas', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kecelakaan', 'O', 'NOUN'],
#   ['lalu', 'O', 'ADP'],
#   ['lintas', 'O', 'NOUN'],
#   ['juga', 'O', 'ADV'],
#   ['kerap', 'O', 'ADV'],
#   ['terjadi', 'O', 'VERB'],
#   ['karena', 'O', 'SCONJ'],
#   ['kecerobohan', 'B-CAUSE', 'NOUN'],
#   ['pengemudi', 'I-CAUSE', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['sendiri', 'O', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['SUMBER', 'O', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Radar', 'B-MISC', 'PROPN'],
#   ['Bromo', 'I-MISC', 'PROPN'],
#   ['Rencana', 'O', 'PROPN'],
#   ['Ramadhan', 'B-PER', 'PROPN'],
#   ['Budi', 'I-PER', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['25', 'B-AGE', 'NUM'],
#   ['beserta', 'O', 'CCONJ'],
#   ['istri', 'O', 'NOUN'],
#   ['dan', 'O', 'CCONJ'],
#   ['anaknya', 'O', 'NOUN'],
#   ['untuk', 'O', 'ADP'],
#   ['pulang', 'O', 'VERB'],
#   ['usai', 'O', 'VERB'],
#   ['dari', 'O', 'ADP'],
#   ['Sumber', 'B-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Probolinggo', 'I-LOC', 'PROPN'],
#   ['berujung', 'O', 'VERB'],
#   ['tragedi', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Motor', 'B-VEHICLE', 'PROPN'],
#   ['matiknya', 'I-VEHICLE', 'NOUN'],
#   ['alami', 'O', 'ADJ'],
#   ['rem', 'B-CAUSE', 'NOUN'],
#   ['blong', 'I-CAUSE', 'NOUN'],
#   ['hingga', 'O', 'ADP'],
#   ['terjun', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['pekarangan', 'O', 'NOUN'],
#   ['warga', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kecelakaan', 'O', 'NOUN'],
#   ['tunggal', 'O', 'ADJ'],
#   ['itu', 'O', 'DET'],
#   ['terjadi', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['jalan', 'O', 'NOUN'],
#   ['Desa/Kecamatan', 'B-LOC', 'PROPN'],
#   ['Sumber', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Selasa', 'B-DATE', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['29/12', 'B-DATE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['sekitar', 'O', 'ADP'],
#   ['pukul', 'O', 'NOUN'],
#   ['16', 'B-TIME', 'NUM'],
#   ['.', 'O', 'PUNCT']],
#  [['Sore', 'B-TIME', 'PROPN'],
#   ['itu', 'O', 'DET'],
#   ['rombongan', 'O', 'NOUN'],
#   ['sekeluarga', 'O', 'NOUN'],
#   ['asal', 'O', 'NOUN'],
#   ['Jalan', 'B-LOC', 'PROPN'],
#   ['WR', 'I-LOC', 'PROPN'],
#   ['Supratman', 'I-LOC', 'PROPN'],
#   ['Sentono', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kelurahan', 'B-LOC', 'PROPN'],
#   ['Jati', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Mayangan', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kota', 'B-LOC', 'PROPN'],
#   ['Probolinggo', 'I-LOC', 'PROPN'],
#   ['itu', 'O', 'DET'],
#   ['hendak', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['arah', 'O', 'NOUN'],
#   ['kota', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Mereka', 'O', 'PRON'],
#   ['mengendarai', 'O', 'VERB'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['Honda', 'I-VEHICLE', 'PROPN'],
#   ['Beat', 'I-VEHICLE', 'PROPN'],
#   ['bernopol', 'O', 'PROPN'],
#   ['N', 'B-PLATE', 'PROPN'],
#   ['6347', 'I-PLATE', 'NUM'],
#   ['ST.', 'I-PLATE', 'PUNCT'],
#   ['Yang', 'O', 'PRON'],
#   ['mengendarai', 'O', 'VERB'],
#   ['adalah', 'O', 'AUX'],
#   ['Ramadhan', 'B-PER', 'PROPN'],
#   ['Budi', 'I-PER', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Sementara', 'O', 'SCONJ'],
#   ['sang', 'O', 'DET'],
#   ['istri', 'O', 'NOUN'],
#   ['Dewi', 'B-PER', 'PROPN'],
#   ['Nuke', 'I-PER', 'PROPN'],
#   ['Mayasari', 'I-PER', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['28', 'B-AGE', 'NUM'],
#   [',', 'O', 'PUNCT'],
#   ['dan', 'O', 'CCONJ'],
#   ['anaknya', 'O', 'NOUN'],
#   ['Akbar', 'B-PER', 'PROPN'],
#   ['berusia', 'O', 'VERB'],
#   ['2', 'B-AGE', 'NUM'],
#   ['tahun', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['dibonceng', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Korban', 'O', 'PROPN'],
#   ['Dewi', 'B-PER', 'PROPN'],
#   ['Nuke', 'I-PER', 'PROPN'],
#   ['Mayasari', 'I-PER', 'PROPN'],
#   ['sesaat', 'O', 'ADV'],
#   ['sebelum', 'O', 'ADV'],
#   ['dirujuk', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['RSUD', 'B-MISC', 'PROPN'],
#   ['dr', 'I-MISC', 'PROPN'],
#   ['Moh', 'I-MISC', 'PROPN'],
#   ['Saleh', 'I-MISC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['(', 'O', 'PUNCT'],
#   ['Polsek', 'B-ORG', 'PROPN'],
#   ['Sumber', 'I-ORG', 'PROPN'],
#   ['for', 'O', 'PROPN'],
#   ['Jawa', 'B-MISC', 'PROPN'],
#   ['Pos', 'I-MISC', 'PROPN'],
#   ['Radar', 'B-MISC', 'PROPN'],
#   ['Bromo', 'I-MISC', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['Kapolsek', 'B-ORG', 'PROPN'],
#   ['Sumber', 'I-ORG', 'PROPN'],
#   ['Iptu', 'B-PER', 'PROPN'],
#   ['Sono', 'I-PER', 'PROPN'],
#   ['menjelaskan', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['saat', 'O', 'SCONJ'],
#   ['sampai', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['lokasi', 'O', 'NOUN'],
#   ['kejadian', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['rem', 'B-CAUSE', 'NOUN'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['matik', 'I-VEHICLE', 'ADJ'],
#   ['korban', 'O', 'NOUN'],
#   ['alami', 'O', 'ADJ'],
#   ['panas', 'B-CAUSE', 'ADJ'],
#   ['dan', 'O', 'CCONJ'],
#   ['tak', 'B-CAUSE', 'PART'],
#   ['berfungsi', 'I-CAUSE', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Alias', 'O', 'PROPN'],
#   ['ngeblong', 'B-CAUSE', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Untuk', 'O', 'ADP'],
#   ['menghindari', 'O', 'VERB'],
#   ['tabrakan', 'O', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['lebih', 'O', 'ADV'],
#   ['fatal', 'O', 'ADJ'],
#   [',', 'O', 'PUNCT'],
#   ['Ramadhan', 'B-PER', 'PROPN'],
#   ['Budi', 'I-PER', 'PROPN'],
#   ['memilih', 'O', 'VERB'],
#   ['membelokkan', 'O', 'VERB'],
#   ['motornya', 'B-VEHICLE', 'NOUN'],
#   ['untuk', 'O', 'ADP'],
#   ['masuk', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['pekarangan', 'O', 'NOUN'],
#   ['warga', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kecelakaan', 'O', 'NOUN'],
#   ['akibat', 'O', 'NOUN'],
#   ['rem', 'B-CAUSE', 'NOUN'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['blong', 'B-CAUSE', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Diduga', 'O', 'VERB'],
#   ['rem', 'B-CAUSE', 'NOUN'],
#   ['blong', 'I-CAUSE', 'NOUN'],
#   ['akibat', 'O', 'NOUN'],
#   ['panas', 'O', 'ADJ'],
#   ['setelah', 'O', 'ADP'],
#   ['dipakai', 'O', 'VERB'],
#   ['terus', 'O', 'ADV'],
#   ['menerus', 'O', 'VERB'],
#   ['saat', 'O', 'ADP'],
#   ['posisi', 'O', 'NOUN'],
#   ['jalan', 'O', 'NOUN'],
#   ['menurun', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Kemudian', 'O', 'SCONJ'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['pun', 'O', 'ADV'],
#   ['masuk', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['pekarangan', 'O', 'NOUN'],
#   ['warga', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['katanya', 'O', 'NOUN'],
#   ['Iptu', 'B-PER', 'PROPN'],
#   ['Sono', 'I-PER', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Akibat', 'O', 'SCONJ'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['tunggal', 'O', 'ADJ'],
#   ['itu', 'O', 'DET'],
#   [',', 'O', 'PUNCT'],
#   ['korban', 'O', 'NOUN'],
#   ['Budi', 'B-PER', 'PROPN'],
#   ['alami', 'O', 'VERB'],
#   ['luka', 'O', 'NOUN'],
#   ['patah', 'O', 'VERB'],
#   ['jari', 'O', 'NOUN'],
#   ['kelingking', 'O', 'NOUN'],
#   ['tangan', 'O', 'NOUN'],
#   ['sebelah', 'O', 'ADP'],
#   ['kanan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['luka', 'O', 'NOUN'],
#   ['robek', 'O', 'VERB'],
#   ['pada', 'O', 'ADP'],
#   ['tulang', 'O', 'NOUN'],
#   ['kering', 'O', 'ADJ'],
#   ['bawah', 'O', 'ADP'],
#   ['lutut', 'O', 'NOUN'],
#   ['kaki', 'O', 'NOUN'],
#   ['sebelah', 'O', 'NOUN'],
#   ['kanan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['dan', 'O', 'CCONJ'],
#   ['memar', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['punggung', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Sedangkan', 'O', 'SCONJ'],
#   ['korban', 'O', 'NOUN'],
#   ['Dewi', 'B-PER', 'PROPN'],
#   ['alami', 'O', 'VERB'],
#   ['luka', 'O', 'NOUN'],
#   ['robek', 'O', 'VERB'],
#   ['kaki', 'O', 'NOUN'],
#   ['sebelah', 'O', 'ADP'],
#   ['kanan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['luka', 'O', 'NOUN'],
#   ['robek', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['pelipis', 'O', 'NOUN'],
#   ['mata', 'O', 'NOUN'],
#   ['sebelah', 'O', 'NOUN'],
#   ['kiri', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Dewi', 'B-PER', 'PROPN'],
#   ['harus', 'O', 'ADV'],
#   ['dirujuk', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['RSUD', 'B-MISC', 'PROPN'],
#   ['dr', 'I-MISC', 'PROPN'],
#   ['Moh', 'I-MISC', 'PROPN'],
#   ['.', 'I-MISC', 'PUNCT']],
#  [['Soleh', 'I-MISC', 'PROPN'],
#   ['Kota', 'B-LOC', 'PROPN'],
#   ['Probolinggo', 'I-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Sedangkan', 'O', 'SCONJ'],
#   ['korban', 'O', 'NOUN'],
#   ['Akbar', 'B-PER', 'PROPN'],
#   ['anaknya', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['alami', 'O', 'ADJ'],
#   ['memar', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['dahi', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Semua', 'O', 'DET'],
#   ['korban', 'O', 'NOUN'],
#   ['hanya', 'O', 'ADV'],
#   ['alami', 'O', 'ADJ'],
#   ['luka', 'O', 'NOUN'],
#   ['luka', 'O', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['Satu', 'O', 'NUM'],
#   ['korban', 'O', 'NOUN'],
#   ['dirujuk', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['RSUD', 'B-MISC', 'PROPN'],
#   ['Moch', 'I-MISC', 'PROPN'],
#   ['Saleh', 'I-MISC', 'PROPN'],
#   ['Kota', 'B-LOC', 'PROPN'],
#   ['Probolinggo', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['ujar', 'O', 'PROPN'],
#   ['Sono', 'B-PER', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['jatimnow.com', 'B-MISC', 'PROPN'],
#   ['-', 'O', 'PUNCT'],
#   ['Arief', 'B-PER', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['34', 'B-AGE', 'NUM'],
#   [')', 'O', 'PUNCT'],
#   ['pemotor', 'B-VEHICLE', 'NOUN'],
#   ['asal', 'O', 'NOUN'],
#   ['Desa', 'B-LOC', 'PROPN'],
#   ['Jaan', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Gondang', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Nganjuk', 'I-LOC', 'PROPN'],
#   ['tewas', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['Jalan', 'B-LOC', 'PROPN'],
#   ['Raya', 'I-LOC', 'PROPN'],
#   ['Bypass', 'I-LOC', 'PROPN'],
#   ['Kecamatan', 'I-LOC', 'PROPN'],
#   ['Krian', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Sidoarjo', 'I-LOC', 'PROPN'],
#   ['setelah', 'O', 'ADP'],
#   ['tertabrak', 'O', 'VERB'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['Fuso', 'I-VEHICLE', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kanit', 'B-ORG', 'PROPN'],
#   ['Laka', 'I-ORG', 'PROPN'],
#   ['Satlantas', 'I-ORG', 'PROPN'],
#   ['Polresta', 'I-ORG', 'PROPN'],
#   ['Sidoarjo', 'I-ORG', 'PROPN'],
#   ['AKP', 'B-PER', 'PROPN'],
#   ['Sugeng', 'I-PER', 'PROPN'],
#   ['Sulistiyono', 'I-PER', 'PROPN'],
#   ['mengatakan', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['korban', 'O', 'NOUN'],
#   ['mengendarai', 'O', 'VERB'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['Honda', 'I-VEHICLE', 'PROPN'],
#   ['Vario', 'I-VEHICLE', 'PROPN'],
#   ['bernopol', 'O', 'PROPN'],
#   ['AG', 'B-PLATE', 'PROPN'],
#   ['6110', 'I-PLATE', 'NUM'],
#   ['XU', 'I-PLATE', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Sementara', 'O', 'SCONJ'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['Fuso', 'I-VEHICLE', 'PROPN'],
#   ['bernopol', 'O', 'PROPN'],
#   ['N', 'B-PLATE', 'PROPN'],
#   ['8332', 'I-PLATE', 'NUM'],
#   ['UW', 'I-PLATE', 'PROPN'],
#   ['disopiri', 'O', 'PROPN'],
#   ['Andik', 'B-PER', 'PROPN'],
#   ['Mintoko', 'I-PER', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['24', 'B-AGE', 'NUM'],
#   [')', 'O', 'PUNCT'],
#   [',', 'O', 'PUNCT'],
#   ['asal', 'O', 'NOUN'],
#   ['Desa', 'B-LOC', 'PROPN'],
#   ['Krondonan', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Gondang', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Bojonegoro', 'I-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Sugeng', 'B-PER', 'PROPN'],
#   ['menyebut', 'O', 'VERB'],
#   ['bahwa', 'O', 'SCONJ'],
#   ['saat', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['melaju', 'O', 'VERB'],
#   ['dari', 'O', 'ADP'],
#   ['arah', 'O', 'NOUN'],
#   ['barat', 'O', 'NOUN'],
#   ['ke', 'O', 'ADP'],
#   ['timur', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Saat', 'O', 'SCONJ'],
#   ['sampai', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['lokasi', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['mencoba', 'O', 'VERB'],
#   ['mendahului', 'O', 'VERB'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['Fuso', 'I-VEHICLE', 'PROPN'],
#   ['yang', 'O', 'PRON'],
#   ['melaju', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['depannya', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Korban', 'O', 'PROPN'],
#   ['mendahului', 'O', 'VERB'],
#   ['Fuso', 'B-VEHICLE', 'PROPN'],
#   ['dari', 'O', 'ADP'],
#   ['sebelah', 'O', 'NOUN'],
#   ['kanan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Namun', 'O', 'SCONJ'],
#   ['pada', 'O', 'ADP'],
#   ['saat', 'O', 'NOUN'],
#   ['mendahului', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['diduga', 'O', 'VERB'],
#   ['menabrak', 'O', 'VERB'],
#   ['median', 'O', 'NOUN'],
#   ['jalan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Motor', 'B-VEHICLE', 'PROPN'],
#   ['terjatuh', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['kanan', 'O', 'NOUN'],
#   ['dan', 'O', 'CCONJ'],
#   ['pengendaranya', 'O', 'NOUN'],
#   ['terjatuh', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['kiri', 'O', 'NOUN'],
#   ['lalu', 'O', 'ADV'],
#   ['tertabrak', 'O', 'VERB'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['tersebut', 'O', 'DET'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'PROPN'],
#   ['ujar', 'O', 'PROPN'],
#   ['Sugeng', 'B-PER', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Senin', 'B-DATE', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['28/12/2020', 'B-DATE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['.', 'O', 'PUNCT']],
#  [['Sugeng', 'B-PER', 'PROPN'],
#   ['menambahkan', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['korban', 'O', 'NOUN'],
#   ['meninggal', 'O', 'VERB'],
#   ['setelah', 'O', 'ADP'],
#   ['terlindas', 'O', 'VERB'],
#   ['roda', 'O', 'NOUN'],
#   ['belakang', 'O', 'ADJ'],
#   ['sebelah', 'O', 'ADP'],
#   ['kanan', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['Fuso', 'I-VEHICLE', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Penyebab', 'O', 'NOUN'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['diduga', 'O', 'VERB'],
#   ['korban', 'O', 'NOUN'],
#   ['kurang', 'B-CAUSE', 'ADV'],
#   ['hati-hati', 'I-CAUSE', 'ADJ'],
#   ['pada', 'O', 'ADP'],
#   ['saat', 'O', 'NOUN'],
#   ['mendahului', 'O', 'VERB'],
#   ['kendaraan', 'O', 'NOUN'],
#   ['Fuso', 'O', 'PROPN'],
#   ['yang', 'O', 'PRON'],
#   ['berada', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['depannya', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'PROPN'],
#   ['pungkasnya', 'O', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['jatimnow.com', 'B-MISC', 'PROPN'],
#   ['-', 'O', 'PUNCT'],
#   ['Seorang', 'O', 'DET'],
#   ['bocah', 'O', 'NOUN'],
#   ['berumur', 'O', 'VERB'],
#   ['3', 'B-AGE', 'NUM'],
#   ['tahun', 'O', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['Pacitan', 'B-LOC', 'PROPN'],
#   ['tewas', 'O', 'VERB'],
#   ['tertabrak', 'O', 'VERB'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['disopiri', 'O', 'VERB'],
#   ['ayahnya', 'O', 'NOUN'],
#   ['sendiri', 'O', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['Balita', 'O', 'PROPN'],
#   ['itu', 'O', 'DET'],
#   ['meninggal', 'O', 'VERB'],
#   ['lantaran', 'O', 'SCONJ'],
#   ['mengalami', 'O', 'VERB'],
#   ['luka', 'O', 'NOUN'],
#   ['pada', 'O', 'ADP'],
#   ['bagian', 'O', 'NOUN'],
#   ['kepala', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Banit', 'B-ORG', 'PROPN'],
#   ['Laka', 'I-ORG', 'PROPN'],
#   ['Sat', 'I-ORG', 'PROPN'],
#   ['Lantas', 'I-ORG', 'PROPN'],
#   ['Polres', 'I-ORG', 'PROPN'],
#   ['Pacitan', 'I-ORG', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Brigadir', 'B-PER', 'PROPN'],
#   ['Dian', 'I-PER', 'PROPN'],
#   ['Oktrivian', 'I-PER', 'PROPN'],
#   ['menyebut', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['terjadi', 'O', 'VERB'],
#   ['Minggu', 'B-DATE', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['27/12/2020', 'B-DATE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['sore', 'B-TIME', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Namun', 'O', 'SCONJ'],
#   ['peristiwa', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['baru', 'O', 'ADJ'],
#   ['dilaporkan', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['Unit', 'B-ORG', 'PROPN'],
#   ['Laka', 'I-ORG', 'PROPN'],
#   ['pada', 'O', 'ADP'],
#   ['malam', 'B-TIME', 'NOUN'],
#   ['harinya', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Katanya', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['peristiwa', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['terjadi', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['Dusun', 'B-LOC', 'PROPN'],
#   ['Tanggung', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Desa', 'B-LOC', 'PROPN'],
#   ['Sanggrahan', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Kebonagung', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Pacitan', 'I-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Truk', 'B-VEHICLE', 'PROPN'],
#   ['engkel', 'I-VEHICLE', 'PROPN'],
#   ['bernopol', 'O', 'PROPN'],
#   ['AE', 'B-PLATE', 'PROPN'],
#   ['8042', 'I-PLATE', 'NUM'],
#   ['UY', 'I-PLATE', 'PROPN'],
#   ['itu', 'O', 'DET'],
#   ['disopiri', 'O', 'NOUN'],
#   ['Suripto', 'B-PER', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['61', 'B-AGE', 'NUM'],
#   [')', 'O', 'PUNCT'],
#   [',', 'O', 'PUNCT'],
#   ['ayah', 'O', 'NOUN'],
#   ['korban', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Truk', 'B-VEHICLE', 'PROPN'],
#   ['itu', 'O', 'DET'],
#   ['diparkir', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['depan', 'O', 'NOUN'],
#   ['rumah', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Anak', 'O', 'PROPN'],
#   ['pertama', 'O', 'NUM'],
#   ['si', 'O', 'DET'],
#   ['sopir', 'O', 'NOUN'],
#   ['saat', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['meminta', 'O', 'VERB'],
#   ['uang', 'O', 'NOUN'],
#   ['jajan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'ADP'],
#   ['jelasnya', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['Senin', 'B-DATE', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['28/12/2020', 'B-DATE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['.', 'O', 'PUNCT']],
#  [['Setelah', 'O', 'SCONJ'],
#   ['memberikan', 'O', 'VERB'],
#   ['uang', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['Suripto', 'B-PER', 'PROPN'],
#   ['bergegas', 'O', 'VERB'],
#   ['naik', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['kemudi', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['untuk', 'O', 'ADP'],
#   ['mengantarkan', 'O', 'VERB'],
#   ['kayu', 'O', 'NOUN'],
#   ['sengon', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Namun', 'O', 'SCONJ'],
#   ['rupanya', 'O', 'ADV'],
#   [',', 'O', 'PUNCT'],
#   ['anak', 'O', 'NOUN'],
#   ['keduanya', 'O', 'ADJ'],
#   ['yang', 'O', 'PRON'],
#   ['bernama', 'O', 'VERB'],
#   ['Rista', 'B-PER', 'PROPN'],
#   ['berada', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['depan', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['dan', 'O', 'CCONJ'],
#   ['tertabrak', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Korban', 'O', 'PROPN'],
#   ['mengalami', 'O', 'VERB'],
#   ['luka', 'O', 'NOUN'],
#   ['terbuka', 'O', 'ADJ'],
#   ['pada', 'O', 'ADP'],
#   ['kening', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['meninggal', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['TKP', 'O', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'NOUN'],
#   ['terangnya', 'O', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['Sementara', 'O', 'SCONJ'],
#   ['Kepala', 'O', 'PROPN'],
#   ['Desa', 'B-LOC', 'PROPN'],
#   ['Sanggrahan', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Sutarno', 'B-PER', 'PROPN'],
#   ['mengaku', 'O', 'VERB'],
#   ['melihat', 'O', 'VERB'],
#   ['peristiwa', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['dan', 'O', 'CCONJ'],
#   ['menyebut', 'O', 'VERB'],
#   ['tidak', 'O', 'PART'],
#   ['ada', 'O', 'VERB'],
#   ['unsur', 'O', 'NOUN'],
#   ['kesengajaan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Karena', 'O', 'SCONJ'],
#   ['saat', 'O', 'NOUN'],
#   ['anak', 'O', 'NOUN'],
#   ['pertama', 'O', 'ADJ'],
#   ['meminta', 'O', 'VERB'],
#   ['uang', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['korban', 'O', 'NOUN'],
#   ['masih', 'O', 'ADV'],
#   ['bermain', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['teras', 'O', 'NOUN'],
#   ['rumah', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Ternyata', 'O', 'SCONJ'],
#   ['saat', 'O', 'ADP'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['jalan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['korban', 'O', 'NOUN'],
#   ['berada', 'O', 'VERB'],
#   ['sekitar', 'O', 'ADP'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Tahunya', 'O', 'NOUN'],
#   ['pun', 'O', 'ADV'],
#   ['saat', 'O', 'ADP'],
#   ['Riko', 'B-PER', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['anak', 'O', 'NOUN'],
#   ['pertama', 'O', 'NUM'],
#   [')', 'O', 'PUNCT'],
#   ['teriak', 'O', 'VERB'],
#   ['kalau', 'O', 'SCONJ'],
#   ['adiknya', 'O', 'NOUN'],
#   ['terlindas', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Setelah', 'O', 'SCONJ'],
#   ['diberitahu', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['korban', 'O', 'NOUN'],
#   ['langsung', 'O', 'ADJ'],
#   ['dibawa', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['puskemas', 'B-MISC', 'NOUN'],
#   ['tapi', 'O', 'SCONJ'],
#   ['nyawanya', 'O', 'NOUN'],
#   ['tidak', 'O', 'PART'],
#   ['tertolong', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'PROPN'],
#   ['pungkas', 'O', 'PROPN'],
#   ['Sutarno', 'B-PER', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Pasuruan', 'O', 'PROPN'],
#   ['-', 'O', 'PUNCT'],
#   ['Sebuah', 'O', 'DET'],
#   ['pikap', 'B-VEHICLE', 'NOUN'],
#   ['terjun', 'O', 'NOUN'],
#   ['ke', 'O', 'ADP'],
#   ['parit', 'O', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['jalan', 'B-LOC', 'NOUN'],
#   ['umum', 'I-LOC', 'ADJ'],
#   ['jurusan', 'O', 'NOUN'],
#   ['Malang-Surabaya', 'B-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['tepatnya', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['Desa/Kecamatan', 'B-LOC', 'PROPN'],
#   ['Purwodadi', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Pasuruan', 'I-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kendaraan', 'O', 'NOUN'],
#   ['bak', 'O', 'NOUN'],
#   ['terbuka', 'O', 'ADJ'],
#   ['yang', 'O', 'PRON'],
#   ['dikemudikan', 'O', 'VERB'],
#   ['sopir', 'O', 'NOUN'],
#   ['perempuan', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['masuk', 'O', 'VERB'],
#   ['parit', 'O', 'NOUN'],
#   ['setelah', 'O', 'ADP'],
#   ['menghindari', 'O', 'VERB'],
#   ['kendaraan', 'O', 'NOUN'],
#   ['lain', 'O', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['Kanit', 'B-ORG', 'PROPN'],
#   ['Laka', 'I-ORG', 'PROPN'],
#   ['Lantas', 'I-ORG', 'PROPN'],
#   ['Polres', 'I-ORG', 'PROPN'],
#   ['Pasuruan', 'I-ORG', 'PROPN'],
#   ['Iptu', 'B-PER', 'PROPN'],
#   ['Marti', 'I-PER', 'PROPN'],
#   ['mengatakan', 'O', 'VERB'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['terjadi', 'O', 'VERB'],
#   ['pukul', 'O', 'NOUN'],
#   ['12.15', 'B-TIME', 'NUM'],
#   ['WIB', 'O', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Lokasi', 'O', 'NOUN'],
#   ['kejadian', 'O', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['jalan', 'O', 'NOUN'],
#   ['menyempit', 'O', 'VERB'],
#   ['karena', 'O', 'SCONJ'],
#   ['perbaikan', 'O', 'NOUN'],
#   ['jembatan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Kecelakaan', 'O', 'PROPN'],
#   ['bermula', 'O', 'VERB'],
#   ['saat', 'O', 'NOUN'],
#   ['pikap', 'B-VEHICLE', 'NOUN'],
#   ['melaju', 'O', 'VERB'],
#   ['dari', 'O', 'ADP'],
#   ['arah', 'O', 'NOUN'],
#   ['Malang-Surabaya', 'B-LOC', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['lajur', 'O', 'NOUN'],
#   ['lambat', 'O', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['Saat', 'O', 'SCONJ'],
#   ['di', 'O', 'ADP'],
#   ['lokasi', 'O', 'NOUN'],
#   ['penyempitan', 'O', 'NOUN'],
#   ['jalan', 'O', 'NOUN'],
#   ['karena', 'O', 'SCONJ'],
#   ['perbaikan', 'O', 'NOUN'],
#   ['jembatan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['di', 'O', 'ADP'],
#   ['lajur', 'O', 'NOUN'],
#   ['cepat', 'O', 'ADJ'],
#   ['melaju', 'O', 'VERB'],
#   ['kendaraan', 'O', 'NOUN'],
#   ['lain', 'O', 'ADJ'],
#   ['sehingga', 'O', 'SCONJ'],
#   ['pikap', 'B-VEHICLE', 'NOUN'],
#   ['menghindar', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['arah', 'O', 'NOUN'],
#   ['kiri', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'ADP'],
#   ['kata', 'O', 'NOUN'],
#   ['Marti', 'B-PER', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Minggu', 'B-DATE', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['27/12/2020', 'B-DATE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Saat', 'O', 'SCONJ'],
#   ['menghindar', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['kiri', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['pikap', 'B-VEHICLE', 'NOUN'],
#   ['masuk', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['dalam', 'O', 'ADP'],
#   ['parit', 'O', 'NOUN'],
#   ['sebelah', 'O', 'NOUN'],
#   ['kiri', 'O', 'NOUN'],
#   ['jalan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'NOUN'],
#   ['terang', 'O', 'ADJ'],
#   ['Marti', 'B-PER', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Meski', 'O', 'SCONJ'],
#   ['kondisi', 'O', 'NOUN'],
#   ['pikap', 'B-VEHICLE', 'NOUN'],
#   ['rusak', 'O', 'VERB'],
#   ['berat', 'O', 'ADJ'],
#   [',', 'O', 'PUNCT'],
#   ['pengemudinya', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['Yuliani', 'B-PER', 'PROPN'],
#   ['Magfiro', 'I-PER', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['34', 'B-AGE', 'NUM'],
#   [')', 'O', 'PUNCT'],
#   ['warga', 'O', 'NOUN'],
#   ['Jalan', 'B-LOC', 'PROPN'],
#   ['Untung', 'I-LOC', 'PROPN'],
#   ['Suropati', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Pohjentrek', 'B-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Pasuruan', 'B-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['selamat', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Begitu', 'O', 'ADV'],
#   ['juga', 'O', 'ADV'],
#   ['penumpangnya', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['Abdul', 'B-PER', 'PROPN'],
#   ['Firmansyah', 'I-PER', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['17', 'B-AGE', 'NUM'],
#   [')', 'O', 'PUNCT'],
#   ['hanya', 'O', 'ADV'],
#   ['mengalami', 'O', 'VERB'],
#   ['luka', 'O', 'NOUN'],
#   ['ringan', 'O', 'ADJ'],
#   ['.', 'O', 'PUNCT']],
#  [['Mereka', 'O', 'PRON'],
#   ['mendapatkan', 'O', 'VERB'],
#   ['perawatan', 'O', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['puskesmas', 'B-MISC', 'NOUN'],
#   ['setempat', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Sebabnya', 'O', 'ADV'],
#   ['pengemudi', 'O', 'NOUN'],
#   ['pikap', 'B-VEHICLE', 'NOUN'],
#   ['kurang', 'B-CAUSE', 'ADV'],
#   ['hati', 'I-CAUSE', 'ADJ'],
#   ['-', 'I-CAUSE', 'PUNCT'],
#   ['hati', 'I-CAUSE', 'NOUN'],
#   ['dan', 'O', 'CCONJ'],
#   ['konsentrasi', 'B-CAUSE', 'NOUN'],
#   ['sehingga', 'O', 'SCONJ'],
#   ['mengakibatkan', 'O', 'VERB'],
#   ['terjadinya', 'O', 'NOUN'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['lalu', 'O', 'ADP'],
#   ['lintas', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'PROPN'],
#   ['pungkas', 'O', 'PROPN'],
#   ['Marti', 'B-PER', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['jatimnow.com', 'B-MISC', 'PROPN'],
#   ['-', 'O', 'PUNCT'],
#   ['Empat', 'O', 'NUM'],
#   ['orang', 'O', 'NOUN'],
#   ['terluka', 'O', 'VERB'],
#   ['dalam', 'O', 'ADP'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['mobil', 'B-VEHICLE', 'NOUN'],
#   ['pikap', 'I-VEHICLE', 'NOUN'],
#   ['Suzuki', 'I-VEHICLE', 'PROPN'],
#   ['Carry', 'I-VEHICLE', 'PROPN'],
#   ['bernopol', 'O', 'PROPN'],
#   ['N', 'B-PLATE', 'PROPN'],
#   ['9563', 'I-PLATE', 'NUM'],
#   ['WE', 'I-PLATE', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Mobil', 'B-VEHICLE', 'PROPN'],
#   ['itu', 'O', 'DET'],
#   ['terperosok', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['sungai', 'O', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['Jalan', 'B-LOC', 'PROPN'],
#   ['Raya', 'I-LOC', 'PROPN'],
#   ['Malang-Surabaya', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Desa', 'B-LOC', 'PROPN'],
#   ['Purwodadi', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Purwodadi', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Pasuruan', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['sekitar', 'O', 'ADP'],
#   ['pukul', 'O', 'NOUN'],
#   ['12.15', 'B-TIME', 'NUM'],
#   ['Wib', 'O', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Minggu', 'B-DATE', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['27/12/2020', 'B-DATE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['.', 'O', 'PUNCT']],
#  [['Kanit', 'B-ORG', 'PROPN'],
#   ['Laka', 'I-ORG', 'PROPN'],
#   ['Satlantas', 'I-ORG', 'PROPN'],
#   ['Polres', 'I-ORG', 'PROPN'],
#   ['Pasuruan', 'I-ORG', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Iptu', 'B-PER', 'PROPN'],
#   ['Marti', 'I-PER', 'PROPN'],
#   ['mengatakan', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['keempat', 'O', 'NUM'],
#   ['korban', 'O', 'NOUN'],
#   ['luka', 'O', 'NOUN'],
#   ['tersebut', 'O', 'DET'],
#   ['saat', 'O', 'NOUN'],
#   ['ini', 'O', 'DET'],
#   ['sudah', 'O', 'ADV'],
#   ['mendapatkan', 'O', 'VERB'],
#   ['perawatan', 'O', 'NOUN'],
#   ['medis', 'O', 'ADJ'],
#   ['di', 'O', 'ADP'],
#   ['Puskesmas', 'B-MISC', 'PROPN'],
#   ['Purwodadi', 'I-MISC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Kecelakaan', 'O', 'NOUN'],
#   ['tersebut', 'O', 'DET'],
#   ['ditangani', 'O', 'VERB'],
#   ['Pos', 'B-ORG', 'PROPN'],
#   ['Lantas', 'I-ORG', 'PROPN'],
#   ['Purwodadi', 'I-ORG', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Informasi', 'O', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['saya', 'O', 'PRON'],
#   ['terima', 'O', 'VERB'],
#   ['sementara', 'O', 'NOUN'],
#   ['ini', 'O', 'DET'],
#   ['ada', 'O', 'VERB'],
#   ['empat', 'O', 'NUM'],
#   ['orang', 'O', 'NOUN'],
#   ['terluka', 'O', 'VERB'],
#   ['dan', 'O', 'CCONJ'],
#   ['semuanya', 'O', 'PRON'],
#   ['kini', 'O', 'ADV'],
#   ['sudah', 'O', 'ADV'],
#   ['sehat', 'O', 'ADJ'],
#   [',', 'O', 'PUNCT'],
#   ['tidak', 'O', 'PART'],
#   ['ada', 'O', 'VERB'],
#   ['yang', 'O', 'PRON'],
#   ['parah', 'O', 'ADJ'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'NOUN'],
#   ['jelas', 'O', 'ADJ'],
#   ['Marti', 'B-PER', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Terkait', 'O', 'VERB'],
#   ['identitas', 'O', 'NOUN'],
#   ['dan', 'O', 'CCONJ'],
#   ['kronologi', 'O', 'NOUN'],
#   ['kejadiannya', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['Marti', 'B-PER', 'PROPN'],
#   ['belum', 'O', 'ADV'],
#   ['berani', 'O', 'VERB'],
#   ['berkomentar', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Sebab', 'O', 'SCONJ'],
#   ['anggota', 'O', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['TKP', 'O', 'PROPN'],
#   ['masih', 'O', 'ADV'],
#   ['memeriksa', 'O', 'VERB'],
#   ['saksi-saksi', 'O', 'NOUN'],
#   ['serta', 'O', 'CCONJ'],
#   ['korban', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Untuk', 'O', 'ADP'],
#   ['keterangan', 'O', 'NOUN'],
#   ['lengkapnya', 'O', 'NOUN'],
#   ['tunggu', 'O', 'NOUN'],
#   ['sebentar', 'O', 'ADV'],
#   ['ya', 'O', 'PROPN'],
# ...
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['kontainer', 'I-VEHICLE', 'NOUN'],
#   ['dari', 'O', 'ADP'],
#   ['sisi', 'O', 'NOUN'],
#   ['kiri', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Namun', 'O', 'SCONJ'],
#   ['diduga', 'O', 'NOUN'],
#   ['tidak', 'B-CAUSE', 'PART'],
#   ['mampu', 'I-CAUSE', 'ADV'],
#   ['menguasai', 'I-CAUSE', 'VERB'],
#   ['laju', 'I-CAUSE', 'NOUN'],
#   ['kendaraannya', 'I-CAUSE', 'NOUN'],
#   ['karena', 'O', 'SCONJ'],
#   ['ada', 'O', 'VERB'],
#   ['pengendara', 'O', 'NOUN'],
#   ['lain', 'O', 'ADJ'],
#   ['yang', 'O', 'PRON'],
#   ['melintas', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['depannya', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['korban', 'O', 'NOUN'],
#   ['oleng', 'O', 'PROPN'],
#   ['dan', 'O', 'CCONJ'],
#   ['menyerempet', 'O', 'VERB'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['hingga', 'O', 'ADP'],
#   ['korban', 'O', 'NOUN'],
#   ['terjatuh', 'O', 'VERB'],
#   ['dan', 'O', 'CCONJ'],
#   ['tertabrak', 'O', 'VERB'],
#   ['roda', 'O', 'NOUN'],
#   ['belakang', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Anggota', 'B-ORG', 'NOUN'],
#   ['Unit', 'I-ORG', 'PROPN'],
#   ['Laka', 'I-ORG', 'PROPN'],
#   ['Lantas', 'I-ORG', 'PROPN'],
#   ['Polrestabes', 'I-ORG', 'PROPN'],
#   ['Surabaya', 'I-ORG', 'PROPN'],
#   ['yang', 'O', 'PRON'],
#   ['mendapatkan', 'O', 'VERB'],
#   ['laporan', 'O', 'NOUN'],
#   ['langsung', 'O', 'ADJ'],
#   ['menuju', 'O', 'VERB'],
#   ['lokasi', 'O', 'NOUN'],
#   ['untuk', 'O', 'ADP'],
#   ['melakukan', 'O', 'VERB'],
#   ['olah', 'O', 'NOUN'],
#   ['TKP', 'O', 'PROPN'],
#   ['dan', 'O', 'CCONJ'],
#   ['mengevakuasi', 'O', 'VERB'],
#   ['jasad', 'O', 'NOUN'],
#   ['korban', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Sedangkan', 'O', 'SCONJ'],
#   ['sopir', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['juga', 'O', 'ADV'],
#   ['langsung', 'O', 'ADV'],
#   ['diamankan', 'O', 'VERB'],
#   ['untuk', 'O', 'ADP'],
#   ['dimintai', 'O', 'VERB'],
#   ['keterangan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kanit', 'B-ORG', 'PROPN'],
#   ['Laka', 'I-ORG', 'PROPN'],
#   ['Satlantas', 'I-ORG', 'PROPN'],
#   ['Polrestabes', 'I-ORG', 'PROPN'],
#   ['Surabaya', 'I-ORG', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['AKP', 'B-PER', 'PROPN'],
#   ['M', 'I-PER', 'PROPN'],
#   ['Faqih', 'I-PER', 'PROPN'],
#   ['mengaku', 'O', 'VERB'],
#   ['jika', 'O', 'SCONJ'],
#   ['hingga', 'O', 'ADP'],
#   ['saat', 'O', 'NOUN'],
#   ['ini', 'O', 'DET'],
#   ['pihaknya', 'O', 'NOUN'],
#   ['masih', 'O', 'ADV'],
#   ['melakukan', 'O', 'VERB'],
#   ['pemeriksaan', 'O', 'NOUN'],
#   ['intensif', 'O', 'ADJ'],
#   ['terhadap', 'O', 'ADP'],
#   ['sopir', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Masih', 'O', 'ADV'],
#   ['dalam', 'O', 'ADP'],
#   ['penyelidikan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Sopir', 'O', 'PROPN'],
#   ['dan', 'O', 'CCONJ'],
#   ['sejumlah', 'O', 'DET'],
#   ['saksi', 'O', 'NOUN'],
#   ['masih', 'O', 'ADV'],
#   ['kami', 'O', 'PRON'],
#   ['periksa', 'O', 'VERB'],
#   ['untuk', 'O', 'ADP'],
#   ['mengetahui', 'O', 'VERB'],
#   ['penyebab', 'O', 'NOUN'],
#   ['pasti', 'O', 'ADJ'],
#   ['terjadinya', 'O', 'VERB'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['tersebut', 'O', 'DET'],
#   ['.', 'O', 'PUNCT']],
#  [['Nanti', 'O', 'ADV'],
#   ['perkembangannya', 'O', 'NOUN'],
#   ['kita', 'O', 'PRON'],
#   ['sampaikan', 'O', 'VERB'],
#   ['lagi', 'O', 'ADV'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'PROPN'],
#   ['ujar', 'O', 'PROPN'],
#   ['Faqih', 'B-PER', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Akibat', 'O', 'NOUN'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['ini', 'O', 'DET'],
#   [',', 'O', 'PUNCT'],
#   ['Jalan', 'B-LOC', 'PROPN'],
#   ['Raya', 'I-LOC', 'PROPN'],
#   ['Sememi', 'I-LOC', 'PUNCT'],
#   ['sempat', 'O', 'ADV'],
#   ['mengalami', 'O', 'VERB'],
#   ['kemacetan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Sejumlah', 'O', 'DET'],
#   ['petugas', 'O', 'NOUN'],
#   ['gabungan', 'O', 'ADJ'],
#   ['berada', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['lokasi', 'O', 'NOUN'],
#   ['untuk', 'O', 'ADP'],
#   ['membantu', 'O', 'VERB'],
#   ['mengurai', 'O', 'VERB'],
#   ['kemacetan', 'O', 'NOUN'],
#   ['tersebut', 'O', 'DET'],
#   ['.', 'O', 'PUNCT']],
#  [['SIDOARJO', 'O', 'PROPN'],
#   ['Hendri', 'B-PER', 'PROPN'],
#   ['Susanto', 'B-PER', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['41', 'B-AGE', 'NUM'],
#   [',', 'O', 'PUNCT'],
#   ['warga', 'O', 'NOUN'],
#   ['Wonokitri', 'B-LOC', 'PROPN'],
#   ['1/20-K', 'I-LOC', 'PROPN'],
#   ['Kelurahan', 'I-LOC', 'PROPN'],
#   ['Pakis', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Sawahan', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Surabaya', 'B-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['tewas', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['Jalan', 'B-LOC', 'PROPN'],
#   ['Raya', 'I-LOC', 'PROPN'],
#   ['Waru', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Senin', 'B-DATE', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['12-Jul', 'B-DATE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['.', 'O', 'PUNCT']],
#  [['Korban', 'O', 'PROPN'],
#   ['terlibat', 'O', 'VERB'],
#   ['dalam', 'O', 'ADP'],
#   ['kecelakaan', 'O', 'NOUN'],
#   ['saat', 'O', 'SCONJ'],
#   ['mengendarai', 'O', 'VERB'],
#   ['motornya', 'B-VEHICLE', 'NOUN'],
#   ['sekitar', 'O', 'ADP'],
#   ['pukul', 'O', 'NOUN'],
#   ['10', 'B-TIME', 'NUM'],
#   ['siang', 'B-TIME', 'NOUN'],
#   ['ini', 'O', 'DET'],
#   ['.', 'O', 'PUNCT']],
#  [['Kanit', 'B-ORG', 'PROPN'],
#   ['Laka', 'I-ORG', 'PROPN'],
#   ['Lantas', 'I-ORG', 'PROPN'],
#   ['Polresta', 'I-ORG', 'PROPN'],
#   ['Sidoarjo', 'I-ORG', 'PROPN'],
#   ['AKP', 'B-PER', 'PROPN'],
#   ['Sugeng', 'I-PER', 'PROPN'],
#   ['Sulistyono', 'I-PER', 'PROPN'],
#   ['mengatakan', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['korban', 'O', 'NOUN'],
#   ['saat', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['diketahui', 'O', 'VERB'],
#   ['sedang', 'O', 'ADV'],
#   ['mengendarai', 'O', 'VERB'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['Honda', 'I-VEHICLE', 'PROPN'],
#   ['nopol', 'O', 'PROPN'],
#   ['L', 'B-PLATE', 'PROPN'],
#   ['6456', 'I-PLATE', 'NUM'],
#   ['ZR', 'I-PLATE', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Korban', 'O', 'PROPN'],
#   ['berkendara', 'O', 'VERB'],
#   ['dari', 'O', 'ADP'],
#   ['arah', 'O', 'NOUN'],
#   ['utara', 'O', 'NOUN'],
#   ['ke', 'O', 'ADP'],
#   ['selatan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Saat', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   [',', 'O', 'PUNCT'],
#   ['korban', 'O', 'NOUN'],
#   ['terlihat', 'O', 'VERB'],
#   ['berusaha', 'O', 'VERB'],
#   ['mendahului', 'B-CAUSE', 'VERB'],
#   ['kendaraan', 'I-CAUSE', 'NOUN'],
#   ['lain', 'I-CAUSE', 'ADJ'],
#   ['di', 'O', 'ADP'],
#   ['depannya', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Ada', 'O', 'VERB'],
#   ['truck', 'B-VEHICLE', 'NOUN'],
#   ['trailler', 'I-VEHICLE', 'NOUN'],
#   ['nopol', 'O', 'PROPN'],
#   ['L', 'B-PLATE', 'PROPN'],
#   ['8548', 'I-PLATE', 'NUM'],
#   ['UL', 'I-PLATE', 'PROPN'],
#   ['yang', 'O', 'PRON'],
#   ['berjalan', 'O', 'VERB'],
#   ['dari', 'O', 'ADP'],
#   ['arah', 'O', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['sama', 'O', 'ADJ'],
#   [',', 'O', 'PUNCT'],
#   ['yang', 'O', 'PRON'],
#   ['berusaha', 'O', 'VERB'],
#   ['korban', 'O', 'NOUN'],
#   ['dahului', 'O', 'VERB'],
#   [',', 'O', 'PUNCT'],
#   ['kata', 'O', 'NOUN'],
#   ['Sugeng', 'B-PER', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Truck', 'B-VEHICLE', 'PROPN'],
#   ['trailler', 'I-VEHICLE', 'PROPN'],
#   ['nopol', 'O', 'PROPN'],
#   ['L', 'B-PLATE', 'PROPN'],
#   ['8548', 'I-PLATE', 'NUM'],
#   ['UL', 'I-PLATE', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['diketahui', 'O', 'VERB'],
#   ['sedang', 'O', 'ADV'],
#   ['dikemudikan', 'O', 'VERB'],
#   ['oleh', 'O', 'ADP'],
#   ['Riadi', 'B-PER', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['58', 'B-AGE', 'NUM'],
#   [',', 'O', 'PUNCT'],
#   ['warga', 'O', 'NOUN'],
#   ['Pogot', 'B-LOC', 'PROPN'],
#   ['Baru', 'I-LOC', 'PROPN'],
#   ['7-Mar', 'O', 'PROPN'],
#   ['RT', 'B-LOC', 'PROPN'],
#   ['06/RW', 'I-LOC', 'PUNCT'],
#   ['6', 'I-LOC', 'NUM'],
#   ['Tanah', 'B-LOC', 'PROPN'],
#   ['Kalikedinding', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Surabaya', 'B-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Korban', 'O', 'PROPN'],
#   ['yang', 'O', 'PRON'],
#   ['berusaha', 'O', 'VERB'],
#   ['mendahului', 'O', 'VERB'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['dari', 'O', 'ADP'],
#   ['sebelah', 'O', 'NOUN'],
#   ['kanan', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['terlibat', 'O', 'VERB'],
#   ['aksi', 'O', 'NOUN'],
#   ['serempetan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Akibatnya', 'O', 'SCONJ'],
#   ['korban', 'O', 'NOUN'],
#   ['terjatuh', 'O', 'VERB'],
#   ['dari', 'O', 'ADP'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['dan', 'O', 'CCONJ'],
#   ['terkapar', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['aspal', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Apesnya', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['korban', 'O', 'NOUN'],
#   ['terlindas', 'O', 'VERB'],
#   ['roda', 'O', 'NOUN'],
#   ['belakang', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Akibatnya', 'O', 'SCONJ'],
#   ['korban', 'O', 'NOUN'],
#   ['tewas', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['lokasi', 'O', 'NOUN'],
#   ['kejadian', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Sejumlah', 'O', 'DET'],
#   ['petugas', 'O', 'NOUN'],
#   ['lalu', 'O', 'ADP'],
#   ['lintas', 'O', 'NOUN'],
#   ['langsung', 'O', 'ADJ'],
#   ['melakukan', 'O', 'VERB'],
#   ['olah', 'O', 'NOUN'],
#   ['TKP', 'O', 'PROPN'],
#   ['dan', 'O', 'CCONJ'],
#   ['mengevakuasi', 'O', 'VERB'],
#   ['korban', 'O', 'NOUN'],
#   ['ke', 'O', 'ADP'],
#   ['rumah', 'O', 'NOUN'],
#   ['sakit', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kejadiannya', 'O', 'NOUN'],
#   ['tepat', 'O', 'ADJ'],
#   ['di', 'O', 'ADP'],
#   ['depan', 'O', 'NOUN'],
#   ['PT', 'B-LOC', 'PROPN'],
#   ['.', 'I-LOC', 'PUNCT']],
#  [['Soda', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['dan', 'O', 'CCONJ'],
#   ['petugas', 'O', 'NOUN'],
#   ['mengamankan', 'O', 'VERB'],
#   ['barang', 'O', 'NOUN'],
#   ['bukti', 'O', 'NOUN'],
#   ['dan', 'O', 'CCONJ'],
#   ['memeriksa', 'O', 'VERB'],
#   ['saksi-saksi', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['ujar', 'O', 'PROPN'],
#   ['Sugeng', 'B-PER', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Hasil', 'O', 'NOUN'],
#   ['analisa', 'O', 'NOUN'],
#   ['petugas', 'O', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['lapangan', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['kejadian', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['diduga', 'O', 'VERB'],
#   ['akibat', 'O', 'ADP'],
#   ['kurang', 'B-CAUSE', 'ADV'],
#   ['hati-hatinya', 'I-CAUSE', 'VERB'],
#   ['korban', 'O', 'NOUN'],
#   ['saat', 'O', 'ADP'],
#   ['mengendarai', 'O', 'VERB'],
#   ['motornya', 'B-VEHICLE', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kecelakaan', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['awalnya', 'O', 'ADV'],
#   ['ditangani', 'O', 'VERB'],
#   ['Unit', 'B-ORG', 'PROPN'],
#   ['Lantas', 'I-ORG', 'PROPN'],
#   ['Polsek', 'I-ORG', 'PROPN'],
#   ['Waru', 'I-ORG', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Saat', 'O', 'NOUN'],
#   ['ini', 'O', 'DET'],
#   ['sudah', 'O', 'ADV'],
#   ['dilimpahkan', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['Unit', 'B-ORG', 'PROPN'],
#   ['Laka', 'I-ORG', 'PROPN'],
#   ['Lantas', 'I-ORG', 'PROPN'],
#   ['Polresta', 'I-ORG', 'PROPN'],
#   ['Sidoarjo', 'I-ORG', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['jelasnya', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['jatimnow.com', 'B-MISC', 'PROPN'],
#   ['-', 'O', 'PUNCT'],
#   ['Sebuah', 'O', 'DET'],
#   ['dump', 'B-VEHICLE', 'NOUN'],
#   ['truk', 'I-VEHICLE', 'NOUN'],
#   ['bermuatan', 'O', 'NOUN'],
#   ['semen', 'O', 'NOUN'],
#   ['bernopol', 'O', 'PROPN'],
#   ['S', 'B-PLATE', 'PROPN'],
#   ['8930', 'I-PLATE', 'NUM'],
#   ['HK', 'I-PLATE', 'PROPN'],
#   ['terjun', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['sungai', 'B-LOC', 'NOUN'],
#   ['di', 'O', 'ADP'],
#   ['Jalan', 'B-LOC', 'PROPN'],
#   ['Raya', 'I-LOC', 'PROPN'],
#   ['Ponorogo-Solo', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['tepatnya', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['Desa', 'B-LOC', 'PROPN'],
#   ['Sumoroto', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Kauman', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Ponorogo', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Senin', 'B-DATE', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['7/12/2020', 'B-DATE', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['.', 'O', 'PUNCT']],
#  [['Kapolsek', 'B-ORG', 'PROPN'],
#   ['Sumoroto', 'I-ORG', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kompol', 'B-PER', 'PROPN'],
#   ['Nyoto', 'I-PER', 'PROPN'],
#   ['mengatakan', 'O', 'VERB'],
#   ['peristiwa', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['berawal', 'O', 'VERB'],
#   ['dari', 'O', 'ADP'],
#   ['sopir', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['bernama', 'O', 'VERB'],
#   ['M.', 'B-PER', 'PUNCT'],
#   ['Eko', 'I-PER', 'PROPN'],
#   ['Afrianto', 'I-PER', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['25', 'B-AGE', 'NUM'],
#   [')', 'O', 'PUNCT'],
#   ['menghindari', 'O', 'VERB'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['Honda', 'I-VEHICLE', 'PROPN'],
#   ['Beat', 'I-VEHICLE', 'PROPN'],
#   ['bernopol', 'O', 'PROPN'],
#   ['AE', 'B-PLATE', 'PROPN'],
#   ['5154', 'I-PLATE', 'NUM'],
#   ['WA', 'I-PLATE', 'PROPN'],
#   ['yang', 'O', 'PRON'],
#   ['terjatuh', 'O', 'VERB'],
#   ['di', 'O', 'ADP'],
#   ['jalan', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Pengendara', 'O', 'NOUN'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['adalah', 'O', 'AUX'],
#   ['Alberto', 'B-PER', 'PROPN'],
#   ['Iwangga', 'I-PER', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['19', 'B-AGE', 'NUM'],
#   [')', 'O', 'PUNCT'],
#   [',', 'O', 'PUNCT'],
#   ['seorang', 'O', 'DET'],
#   ['pelajar', 'O', 'NOUN'],
#   ['asal', 'O', 'NOUN'],
#   ['Desa', 'B-LOC', 'PROPN'],
#   ['Gelang', 'I-LOC', 'PROPN'],
#   ['Kulon', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kecamatan', 'B-LOC', 'PROPN'],
#   ['Samping', 'I-LOC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ['Kabupaten', 'B-LOC', 'PROPN'],
#   ['Ponorogo', 'I-LOC', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Sopir', 'O', 'PROPN'],
#   ['dump', 'B-VEHICLE', 'PROPN'],
#   ['truk', 'I-VEHICLE', 'NOUN'],
#   ['berusaha', 'O', 'VERB'],
#   ['menghindari', 'B-CAUSE', 'VERB'],
#   ['sepeda', 'B-VEHICLE', 'NOUN'],
#   ['motor', 'I-VEHICLE', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['jatuh', 'O', 'VERB'],
#   ['tersebut', 'O', 'DET'],
#   ['dengan', 'O', 'ADP'],
#   ['membanting', 'O', 'VERB'],
#   ['kemudi', 'O', 'NOUN'],
#   ['ke', 'O', 'ADP'],
#   ['kiri', 'O', 'NOUN'],
#   ['dan', 'O', 'CCONJ'],
#   ['menabrak', 'O', 'VERB'],
#   ['pohon', 'O', 'NOUN'],
#   ['trembesi', 'O', 'NOUN'],
#   ['kemudian', 'O', 'ADV'],
#   ['masuk', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['sungai', 'O', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'ADP'],
#   ['katanya', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['Peristiwa', 'O', 'NOUN'],
#   ['itu', 'O', 'DET'],
#   ['mengakibatkan', 'O', 'VERB'],
#   ['sopir', 'O', 'NOUN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['terjepit', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Baru', 'O', 'PROPN'],
#   ['saja', 'O', 'ADV'],
#   ['bisa', 'O', 'ADV'],
#   ['dievakuasi', 'O', 'VERB'],
#   ['sopirnya', 'O', 'NOUN'],
#   ['dan', 'O', 'CCONJ'],
#   ['telah', 'O', 'ADV'],
#   ['dibawa', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['Rumah', 'B-MISC', 'PROPN'],
#   ['Sakit', 'I-MISC', 'PROPN'],
#   ['Umum', 'I-MISC', 'PROPN'],
#   ['Daerah', 'I-MISC', 'PROPN'],
#   ['(', 'O', 'PUNCT'],
#   ['RSUD', 'B-MISC', 'PROPN'],
#   [')', 'O', 'PUNCT'],
#   ['dr', 'B-MISC', 'PROPN'],
#   ['Harjono', 'I-MISC', 'PROPN'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'PROPN'],
#   ['ujarnya', 'O', 'PROPN'],
#   ['.', 'O', 'PUNCT']],
#  [['Kernet', 'O', 'PROPN'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['Jiono', 'B-PER', 'ADV'],
#   ['mengatakan', 'O', 'VERB'],
#   ['bahwa', 'O', 'SCONJ'],
#   ['rekannya', 'O', 'NOUN'],
#   ['bermaksud', 'O', 'VERB'],
#   ['menghindari', 'O', 'VERB'],
#   ['motor', 'B-VEHICLE', 'NOUN'],
#   ['yang', 'O', 'PRON'],
#   ['jatuh', 'O', 'VERB'],
#   ['.', 'O', 'PUNCT']],
#  [['Untuk', 'O', 'ADP'],
#   ['meminimalisir', 'B-CAUSE', 'VERB'],
#   ['korban', 'I-CAUSE', 'NOUN'],
#   [',', 'O', 'PUNCT'],
#   ['truk', 'B-VEHICLE', 'NOUN'],
#   ['diarahkan', 'O', 'VERB'],
#   ['ke', 'O', 'ADP'],
#   ['sungai', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  [['``', 'O', 'PUNCT'],
#   ['Kesempatan', 'B-CAUSE', 'NOUN'],
#   ['untuk', 'I-CAUSE', 'ADP'],
#   ['mengerem', 'I-CAUSE', 'VERB'],
#   ['sangat', 'I-CAUSE', 'ADV'],
#   ['terbatas', 'I-CAUSE', 'ADJ'],
#   [',', 'O', 'PUNCT'],
#   ["''", 'O', 'ADP'],
#   ['katanya', 'O', 'NOUN'],
#   ['.', 'O', 'PUNCT']],
#  ...]

# %% [markdown]
# ## Set Parameter

# %%
EPOCHS = 50               # paper: 80
DROPOUT = 0.5             # paper: 0.68
DROPOUT_RECURRENT = 0.25  # not specified in paper, 0.25 recommended
LSTM_STATE_SIZE = 200     # paper: 275
CONV_SIZE = 3             # paper: 3
LEARNING_RATE = 0.0105    # paper 0.0105
OPTIMIZER = Nadam()       # paper uses SGD(lr=self.learning_rate), Nadam() recommended

# %% [markdown]
# ## Final Model

# %%
"""Initialize class"""
class CNN_BLSTM_FINAL(object):
    
    def __init__(self, EPOCHS, DROPOUT, DROPOUT_RECURRENT, LSTM_STATE_SIZE, CONV_SIZE, LEARNING_RATE, OPTIMIZER):
        
        self.epochs = EPOCHS
        self.dropout = DROPOUT
        self.dropout_recurrent = DROPOUT_RECURRENT
        self.lstm_state_size = LSTM_STATE_SIZE
        self.conv_size = CONV_SIZE
        self.learning_rate = LEARNING_RATE
        self.optimizer = OPTIMIZER
        
    def loadData(self, train):
        #Load data and add character information
        self.trainSentences = train

    def addCharInfo(self):
        # format: [['EU', ['E', 'U'], 'B-ORG\n'], ...]
        self.trainSentences = addCharInformation(deepcopy(self.trainSentences))

    def embed(self):
        #Create word- and character-level embeddings

        labelSet = set()
        posSet=set()
        words = {}

        # read: token, char, label, pos
        for dataset in [self.trainSentences]:
            for sentence in dataset:
                for token, char, label, pos in sentence:
                    labelSet.add(label)
                    posSet.add(pos)
                    words[token.lower()] = True

        # char2Idx
        self.char2Idx = {"PADDING": 0, "UNKNOWN": 1}
        for c in " 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ.,-_()[]{}!?:;#'\"/\\%$`&=*+@^~|<>":
            self.char2Idx[c] = len(self.char2Idx)

        # label2Idx
        self.label2Idx = {}
        for label in labelSet:
            self.label2Idx[label] = len(self.label2Idx)# <- napa keren bangettt siii???????
        self.idx2Label = {v: k for k, v in self.label2Idx.items()}
        
        # pos2Idx
        self.pos2Idx = {}
        for pos in posSet:
            self.pos2Idx[pos]=len(self.pos2Idx)
        self.posEmbeddings = np.identity(len(self.pos2Idx), dtype='float32')
        #self.idx2Pos = {v: k for k,v in self.pos2Idx.items()}    
        
        # case2Idx
        case2Idx = {'numeric': 0, 'allLower': 1, 'allUpper': 2, 'initialUpper': 3, 'other': 4, 'mainly_numeric': 5,
                    'contains_digit': 6, 'PADDING_TOKEN': 7}
        self.caseEmbeddings = np.identity(len(case2Idx), dtype='float32')  # identity matrix used 

        # WordEmbeddings GLoVE
        word2Idx = {}
        self.wordEmbeddings = []
        fEmbeddings = open('vectors.txt', encoding="utf-8")
        # loop through each word in embeddings
        for line in fEmbeddings:
            split = line.strip().split(" ")
            word = split[0]  # embedding word entry
            if len(word2Idx) == 0:  # add padding+unknown
                word2Idx["PADDING_TOKEN"] = len(word2Idx)
                vector = np.zeros(len(split) - 1)  # zero vector for 'PADDING' word
                self.wordEmbeddings.append(vector)
                word2Idx["UNKNOWN_TOKEN"] = len(word2Idx)
                vector = np.random.uniform(-0.25, 0.25, len(split) - 1)
                self.wordEmbeddings.append(vector)
            if word.lower() in words:
                vector = np.array([float(num) for num in split[1:]])
                self.wordEmbeddings.append(vector)  # word embedding vector
                word2Idx[word] = len(word2Idx)  # corresponding word dict
        self.wordEmbeddings = np.array(self.wordEmbeddings)

        # format: [[wordindices], [caseindices], [padded word indices], [label indices], [pos indices]]
        # FROM PREPRO
        self.train_set = padding(createMatrices(self.trainSentences, word2Idx, self.label2Idx, case2Idx, self.char2Idx, self.pos2Idx))
        return word2Idx, case2Idx, self.char2Idx, self.pos2Idx, self.idx2Label
    
    def createBatches(self):
        #Create batches
        self.train_idx, self.train_batch, self.train_batch_len = createBatches(self.train_set)
        return [self.train_idx, self.train_batch, self.train_batch_len]
    
    def tag_dataset(self, dataset, model):
        correctLabels = []
        predLabels = []
        progbar = Progbar(len(dataset))
        #print("Tagging token..")
        for i, data in enumerate(dataset):
            tokens, casing, char, labels, pos = data
            tokens = np.asarray([tokens])
            casing = np.asarray([casing])
            char = np.asarray([char])
            pos = np.asarray([pos])
            pred = model.predict([tokens, casing, char, pos], verbose=False)[0]#disinilah dia memprediksi modelnya
            progbar.update(i+1)
            pred = pred.argmax(axis=-1)  # Predict the classes
            correctLabels.append(labels)
            predLabels.append(pred)
        #print("Done.")
        return correctLabels, predLabels
    
    def buildModel(self):
        #Model layers
        # character input
        character_input = Input(shape=(None, 52,), name="Character_input_final")
        
        # sebelum embedding_initializer #<-masuk char2Idx
        embed_char_out = TimeDistributed(
            Embedding(len(self.char2Idx), 30, embeddings_initializer=RandomUniform(minval=-0.5, maxval=0.5)), name="Character_embedding_final")(
            character_input)
        
        dropout = Dropout(self.dropout)(embed_char_out)

        # CNN <-char tadi masuk ke CNN
        conv1d_out = TimeDistributed(Conv1D(kernel_size=self.conv_size, filters=30, padding='same', activation='tanh', strides=1), name="Convolution_final")(dropout)
        maxpool_out = TimeDistributed(MaxPooling1D(52), name="Maxpool_final")(conv1d_out)
        char = TimeDistributed(Flatten(), name="Flatten_final")(maxpool_out)
        char = Dropout(self.dropout)(char)

        # word-level input #<-masuk wordEmbeddings
        words_input = Input(shape=(None,), dtype='int32', name='words_input_final')
        words = Embedding(input_dim=self.wordEmbeddings.shape[0], output_dim=self.wordEmbeddings.shape[1], weights=[self.wordEmbeddings],
                          trainable=False,embeddings_initializer=RandomUniform(minval=-0.5, maxval=0.5))(words_input)
        # case-info input #<-masuk caseEmbeddings
        casing_input = Input(shape=(None,), dtype='int32', name='casing_input_final')
        casing = Embedding(output_dim=self.caseEmbeddings.shape[1], input_dim=self.caseEmbeddings.shape[0], weights=[self.caseEmbeddings],
                           trainable=False, embeddings_initializer=RandomUniform(minval=-0.5, maxval=0.5))(casing_input)
        # pos-info input #<-masuk caseEmbeddings
        pos_input = Input(shape=(None,), dtype='int32', name='pos_input_final')
        pos = Embedding(output_dim=self.posEmbeddings.shape[1], input_dim=self.posEmbeddings.shape[0], weights=[self.posEmbeddings],
                        trainable=False,embeddings_initializer=RandomUniform(minval=-0.5, maxval=0.5))(pos_input) #<-disini weh

        # concat & BLSTM
        output = concatenate([words, casing, char, pos])
        output = Bidirectional(LSTM(self.lstm_state_size, 
                                    return_sequences=True, 
                                    dropout=self.dropout,                        # on input to each LSTM block
                                    recurrent_dropout=self.dropout_recurrent     # on recurrent input signal
                                   ), name="BLSTM_final")(output)
        output = TimeDistributed(Dense(len(self.label2Idx), activation='softmax'),name="Softmax_layer_final")(output)

        # Set up model
        self.model = Model(inputs=[words_input, casing_input, character_input, pos_input], outputs=[output])
        self.model.compile(loss='sparse_categorical_crossentropy', optimizer=self.optimizer)
        # save clear weight into variable
        self.init_weights = self.model.get_weights()

        # Plot model
        plot_model(self.model, to_file='./OUTPUT/model_plot_final.png', show_shapes=True, show_layer_names=True)
        print("Model built. Saved model_plot_final.png\n")
        
    def train(self):
        #Default training

        for epoch in range(self.epochs):    
            print("Epoch {}/{}".format(epoch+1, self.epochs))
            for i,batch in enumerate(iterate_minibatches(self.train_batch,self.train_batch_len)):
                labels,tokens,casing,char,postag = batch       
                self.model.train_on_batch([tokens,casing,char,postag], labels)
                
        # save model
        self.model.save("./OUTPUT/FINAL.h5")
        print("Final Model's weights saved.")
        
        self.model.set_weights(self.init_weights)  # clear model
        print("Model weights cleared.")
        
        del(self.model)
        K.clear_session()
        
        return "./OUTPUT/FINAL.h5"
        
    print("Class initialized.")
# Out:
# Class initialized.

# %%
TRAIN_DATA = deepcopy(array)
cnn_blstm = CNN_BLSTM_FINAL(EPOCHS, DROPOUT, DROPOUT_RECURRENT, LSTM_STATE_SIZE, CONV_SIZE, LEARNING_RATE, OPTIMIZER)
cnn_blstm.loadData(TRAIN_DATA)
cnn_blstm.addCharInfo()
word2Idx, case2Idx, char2Idx, pos2Idx, idx2Label = cnn_blstm.embed()
b = cnn_blstm.createBatches()
cnn_blstm.buildModel()
directory = cnn_blstm.train()
# Out:
# Model built. Saved model_plot_final.png
#
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# Final Model's weights saved.
# Model weights cleared.

# %% [markdown]
# ## Get the Predicted Tags! >.<

# %%
# Load The Final Model
model = load_model(directory)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Character_input_final (InputLay [(None, None, 52)]   0
# __________________________________________________________________________________________________
# Character_embedding_final (Time (None, None, 52, 30) 2910        Character_input_final[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, 52, 30) 0           Character_embedding_final[0][0]
# __________________________________________________________________________________________________
# Convolution_final (TimeDistribu (None, None, 52, 30) 2730        dropout[0][0]
# __________________________________________________________________________________________________
# Maxpool_final (TimeDistributed) (None, None, 1, 30)  0           Convolution_final[0][0]
# __________________________________________________________________________________________________
# words_input_final (InputLayer)  [(None, None)]       0
# __________________________________________________________________________________________________
# casing_input_final (InputLayer) [(None, None)]       0
# __________________________________________________________________________________________________
# Flatten_final (TimeDistributed) (None, None, 30)     0           Maxpool_final[0][0]
# __________________________________________________________________________________________________
# pos_input_final (InputLayer)    [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 50)     218150      words_input_final[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, None, 8)      64          casing_input_final[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 30)     0           Flatten_final[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, None, 15)     225         pos_input_final[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, 103)    0           embedding_1[0][0]
#                                                                  embedding_2[0][0]
#                                                                  dropout_1[0][0]
#                                                                  embedding_3[0][0]
# __________________________________________________________________________________________________
# BLSTM_final (Bidirectional)     (None, None, 400)    486400      concatenate[0][0]
# __________________________________________________________________________________________________
# Softmax_layer_final (TimeDistri (None, None, 21)     8421        BLSTM_final[0][0]
# ==================================================================================================
# Total params: 718,900
# Trainable params: 500,461
# Non-trainable params: 218,439
# __________________________________________________________________________________________________

# %%
# Convert to Array
DATA = deepcopy(data_main)

data_ = toLabeledNER(DATA,'Content')
data_ = data_[pd.Series(['DOCSTART' not in str(i) for i in data_.word])]
data_['pos']=data_['pos'].apply(lambda x: x.replace('<','').replace('>','').replace('<','').replace('>','') if type(x)==str else None)
array_ = toArray_new(data_)
array_
# Out:
# [[['SIDOARJO', 'PROPN'],
#   ['Sebuah', 'DET'],
#   ['truk', 'NOUN'],
#   ['Toyota', 'PROPN'],
#   ['Dyna', 'PROPN'],
#   ['nopol', 'PROPN'],
#   ['L', 'PROPN'],
#   ['8894', 'NUM'],
#   ['US', 'PROPN'],
#   ['yang', 'PRON'],
#   ['melaju', 'VERB'],
#   ['di', 'ADP'],
#   ['Jalan', 'PROPN'],
#   ['Raya', 'PROPN'],
#   ['Seduri', 'PROPN'],
#   ['terguling', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Selasa', 'PROPN'],
#   ['(', 'PUNCT'],
#   ['29/12', 'PROPN'],
#   [')', 'PUNCT'],
#   ['malam', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Hal', 'NOUN'],
#   ['itu', 'DET'],
#   ['membuat', 'VERB'],
#   ['sopir', 'NOUN'],
#   ['harus', 'ADV'],
#   ['dilarikan', 'VERB'],
#   ['ke', 'ADP'],
#   ['rumah', 'NOUN'],
#   ['sakit', 'NOUN'],
#   ['untuk', 'ADP'],
#   ['menjalani', 'VERB'],
#   ['perawatan', 'NOUN'],
#   ['lantaran', 'SCONJ'],
#   ['mengalami', 'VERB'],
#   ['luka-luka', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Informasi', 'NOUN'],
#   ['yang', 'PRON'],
#   ['berhasil', 'VERB'],
#   ['dihimpun', 'VERB'],
#   [',', 'PUNCT'],
#   ['awalnya', 'ADV'],
#   ['truk', 'NOUN'],
#   ['melaju', 'VERB'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['timur', 'NOUN'],
#   ['ke', 'ADP'],
#   ['barat', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Namun', 'SCONJ'],
#   ['tepat', 'ADJ'],
#   ['di', 'ADP'],
#   ['lokasi', 'NOUN'],
#   ['kejadian', 'NOUN'],
#   ['ban', 'NOUN'],
#   ['belakang', 'ADJ'],
#   ['truk', 'NOUN'],
#   ['di', 'ADP'],
#   ['bagian', 'NOUN'],
#   ['kiri', 'NOUN'],
#   ['mengalami', 'VERB'],
#   ['slip', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Hal', 'NOUN'],
#   ['itu', 'DET'],
#   ['membuat', 'VERB'],
#   ['truk', 'NOUN'],
#   ['kehilangan', 'VERB'],
#   ['keseimbangan', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['tidak', 'PART'],
#   ['bisa', 'ADV'],
#   ['mengendalikan', 'VERB'],
#   ['laju', 'NOUN'],
#   ['kendaraan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Karena', 'SCONJ'],
#   ['pengemudi', 'NOUN'],
#   ['kendaraan', 'NOUN'],
#   ['itu', 'DET'],
#   ['tidak', 'PART'],
#   ['bisa', 'ADV'],
#   ['mengendalikan', 'VERB'],
#   [',', 'PUNCT'],
#   ['kemudian', 'ADV'],
#   ['truk', 'NOUN'],
#   ['oleng', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['terguling', 'VERB'],
#   ['ke', 'ADP'],
#   ['kiri', 'NOUN'],
#   ['jalan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['kata', 'NOUN'],
#   ['petugas', 'NOUN'],
#   ['Lantas', 'ADJ'],
#   ['Polsel', 'PUNCT'],
#   ['Balongbendo', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Aipda', 'PROPN'],
#   ['Slamet', 'PROPN'],
#   ['W', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Rabu', 'PROPN'],
#   ['(', 'PUNCT'],
#   ['30/12', 'PROPN'],
#   [')', 'PUNCT'],
#   ['.', 'PUNCT']],
#  [['Akibatnya', 'SCONJ'],
#   [',', 'PUNCT'],
#   ['pengemudi', 'NOUN'],
#   ['truk', 'NOUN'],
#   [',', 'PUNCT'],
#   ['Wagiran', 'PROPN'],
#   [',', 'PUNCT'],
#   ['45', 'NUM'],
#   [',', 'PUNCT'],
#   ['warga', 'NOUN'],
#   ['Desa', 'PROPN'],
#   ['Mlirip', 'PROPN'],
#   ['RT', 'PROPN'],
#   ['02/RW', 'PUNCT'],
#   ['05', 'NUM'],
#   ['Kecamatan', 'PROPN'],
#   ['Jetis', 'PROPN'],
#   ['Kabupaten', 'PROPN'],
#   ['Mojokerto', 'PROPN'],
#   ['mengalami', 'VERB'],
#   ['luka', 'NOUN'],
#   ['telinga', 'NOUN'],
#   ['kiri', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Penumpang', 'NOUN'],
#   ['dalam', 'ADP'],
#   ['kabin', 'NOUN'],
#   [',', 'PUNCT'],
#   ['yaitu', 'SCONJ'],
#   ['Ahmad', 'PROPN'],
#   ['Fahrizal', 'PROPN'],
#   [',', 'PUNCT'],
#   ['29', 'NUM'],
#   [',', 'PUNCT'],
#   ['mengalami', 'VERB'],
#   ['luka-luka', 'NOUN'],
#   ['di', 'ADP'],
#   ['bagian', 'NOUN'],
#   ['punggung', 'NOUN'],
#   ['belakang', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Tak', 'PART'],
#   ['hanya', 'ADV'],
#   ['itu', 'DET'],
#   [',', 'PUNCT'],
#   ['warga', 'NOUN'],
#   ['Jalan', 'PROPN'],
#   ['Pesantren', 'PROPN'],
#   ['Desa', 'PROPN'],
#   ['Wonorejo', 'PROPN'],
#   ['RT', 'PROPN'],
#   ['04/RW', 'PUNCT'],
#   ['01', 'NUM'],
#   ['Kecamatan', 'PROPN'],
#   ['Trowulan', 'PROPN'],
#   ['Kabulaten', 'PROPN'],
#   ['Mojokerto', 'PROPN'],
#   ['itu', 'DET'],
#   ['juga', 'ADV'],
#   ['mengakami', 'VERB'],
#   ['luka', 'NOUN'],
#   ['tangan', 'NOUN'],
#   ['kanannya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Sementara', 'SCONJ'],
#   ['M.', 'PUNCT'],
#   ['Wahyu', 'PROPN'],
#   ['Pinanggih', 'PROPN'],
#   [',', 'PUNCT'],
#   ['26', 'NUM'],
#   [',', 'PUNCT'],
#   ['asal', 'NOUN'],
#   ['Bloto', 'PROPN'],
#   ['RT', 'PROPN'],
#   ['01/RW', 'PUNCT'],
#   ['02', 'NUM'],
#   ['Kecamatan', 'PROPN'],
#   ['Prajurit', 'PROPN'],
#   ['Kulon', 'PROPN'],
#   ['Kota', 'PROPN'],
#   ['Mojokerto', 'PROPN'],
#   ['mengalami', 'VERB'],
#   ['luka', 'NOUN'],
#   ['kaki', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['jari', 'NOUN'],
#   ['kanannya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Dua', 'NUM'],
#   ['orang', 'NOUN'],
#   ['penumpang', 'NOUN'],
#   ['di', 'ADP'],
#   ['dalam', 'ADP'],
#   ['kabinnya', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['sang', 'DET'],
#   ['pengemudi', 'NOUN'],
#   ['langsung', 'ADJ'],
#   ['dilarikan', 'VERB'],
#   ['ke', 'ADP'],
#   ['RS', 'PROPN'],
#   ['Anwar', 'PROPN'],
#   ['Medika', 'PROPN'],
#   [',', 'PUNCT'],
#   ['untuk', 'ADP'],
#   ['mendapat', 'VERB'],
#   ['pertolongan', 'NOUN'],
#   ['medis', 'ADJ'],
#   [',', 'PUNCT'],
#   ['ujarnya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Selain', 'ADP'],
#   ['itu', 'DET'],
#   [',', 'PUNCT'],
#   ['mereka', 'PRON'],
#   ['juga', 'ADV'],
#   ['menjalani', 'VERB'],
#   ['visum', 'NOUN'],
#   ['luka', 'ADJ'],
#   ['akibat', 'ADP'],
#   ['kecelakaan', 'NOUN'],
#   ['itu', 'DET'],
#   ['.', 'PUNCT']],
#  [['Aparat', 'NOUN'],
#   ['kepolisian', 'NOUN'],
#   ['yang', 'PRON'],
#   ['datang', 'VERB'],
#   ['ke', 'ADP'],
#   ['lokasi', 'NOUN'],
#   ['langsung', 'ADJ'],
#   ['menggelar', 'VERB'],
#   ['olah', 'NOUN'],
#   ['TKP', 'PROPN'],
#   ['dan', 'CCONJ'],
#   ['memeriksa', 'VERB'],
#   ['saksi-saksi', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Sedangkan', 'SCONJ'],
#   ['barang', 'NOUN'],
#   ['bukti', 'NOUN'],
#   ['diamankan', 'VERB'],
#   ['petugas', 'NOUN'],
#   ['sebagai', 'ADP'],
#   ['barang', 'NOUN'],
#   ['bukti', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Saat', 'NOUN'],
#   ['ini', 'DET'],
#   ['kasus', 'NOUN'],
#   ['laka', 'PROPN'],
#   ['lantas', 'VERB'],
#   ['itu', 'DET'],
#   ['ditangani', 'VERB'],
#   ['Unit', 'PROPN'],
#   ['Laka', 'PROPN'],
#   ['Satlantas', 'PROPN'],
#   ['Polresta', 'PROPN'],
#   ['Sidoarjo', 'PROPN'],
#   [',', 'PUNCT'],
#   ['jelasnya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['MALANG', 'PROPN'],
#   ['KOTA', 'PROPN'],
#   ['Mungkin', 'ADV'],
#   ['hari', 'NOUN'],
#   ['ini', 'DET'],
#   ['(', 'PUNCT'],
#   ['30/12', 'PROPN'],
#   [')', 'PUNCT'],
#   ['adalah', 'AUX'],
#   ['hari', 'NOUN'],
#   ['sial', 'ADJ'],
#   ['bagi', 'ADP'],
#   ['Bagyo', 'PROPN'],
#   [',', 'PUNCT'],
#   ['sopir', 'NOUN'],
#   ['angkot', 'NOUN'],
#   ['jurusan', 'NOUN'],
#   ['Lawang-Arjosari', 'VERB'],
#   ['dengan', 'ADP'],
#   ['nomor', 'NOUN'],
#   ['polisi', 'NOUN'],
#   ['N', 'PROPN'],
#   ['1554', 'NUM'],
#   ['UE', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Diduga', 'PROPN'],
#   ['melamun', 'VERB'],
#   [',', 'PUNCT'],
#   ['kendaraan', 'NOUN'],
#   ['yang', 'PRON'],
#   ['dikendarainya', 'VERB'],
#   ['masuk', 'VERB'],
#   ['ke', 'ADP'],
#   ['sungai', 'NOUN'],
#   ['di', 'ADP'],
#   ['Jalan', 'PROPN'],
#   ['Panji', 'PROPN'],
#   ['Suroso', 'PROPN'],
#   ['dekat', 'ADJ'],
#   ['Terminal', 'PROPN'],
#   ['Arjosari', 'PROPN'],
#   ['Malang', 'PROPN'],
#   ['sekitar', 'ADP'],
#   ['pukul', 'NOUN'],
#   ['11.00', 'NUM'],
#   ['WIB', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Pas', 'PROPN'],
#   ['jalan', 'NOUN'],
#   ['saya', 'PRON'],
#   ['nggak', 'PART'],
#   ['tahu', 'VERB'],
#   ['tiba-tiba', 'ADP'],
#   ['setir', 'NOUN'],
#   ['sudah', 'ADV'],
#   ['belok', 'VERB'],
#   ['kanan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['lalu', 'SCONJ'],
#   ['ban', 'NOUN'],
#   ['sudah', 'ADV'],
#   ['masuk', 'VERB'],
#   ['ke', 'ADP'],
#   ['pinggir', 'NOUN'],
#   ['sungai', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Karena', 'SCONJ'],
#   ['kurang', 'ADV'],
#   ['fokus', 'ADJ'],
#   [',', 'PUNCT'],
#   ['sepenglihatan', 'NOUN'],
#   ['saya', 'PRON'],
#   ['tadi', 'ADV'],
#   ['rodanya', 'NOUN'],
#   ['tiba-tiba', 'PRON'],
#   ['sudah', 'ADV'],
#   ['tidak', 'PART'],
#   ['nampak', 'VERB'],
#   ['di', 'ADP'],
#   ['aspal', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Tahu-tahu', 'SCONJ'],
#   ['saya', 'PRON'],
#   ['sudah', 'ADV'],
#   ['di', 'ADP'],
#   ['dalam', 'ADP'],
#   ['sungai', 'NOUN'],
#   [',', 'PUNCT'],
#   ['kata', 'NOUN'],
#   ['Bagyo', 'PROPN'],
#   ['sambil', 'ADV'],
#   ['menunggu', 'VERB'],
#   ['evakuasi', 'NOUN'],
#   ['pihak', 'NOUN'],
#   ['berwajib', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Namun', 'SCONJ'],
#   [',', 'PUNCT'],
#   ['Bagyo', 'PROPN'],
#   ['menampik', 'VERB'],
#   ['bahwa', 'SCONJ'],
#   ['dirinya', 'PRON'],
#   ['mengantuk', 'VERB'],
#   [',', 'PUNCT'],
#   ['melainkan', 'CCONJ'],
#   ['hanya', 'ADV'],
#   ['kurang', 'ADV'],
#   ['fokus', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Kalau', 'SCONJ'],
#   ['ngantuk', 'NOUN'],
#   ['nggak', 'PART'],
#   ['juga', 'ADV'],
#   [',', 'PUNCT'],
#   ['saya', 'PRON'],
#   ['sudah', 'ADV'],
#   ['sarapan', 'ADJ'],
#   [',', 'PUNCT'],
#   ['ungkapnya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Di', 'ADP'],
#   ['dalam', 'ADP'],
#   ['angkot', 'NOUN'],
#   ['terdapat', 'VERB'],
#   ['satu', 'DET'],
#   ['orang', 'NOUN'],
#   ['penumpang', 'NOUN'],
#   ['yang', 'PRON'],
#   ['ikut', 'VERB'],
#   ['terjatuh', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Untungnya', 'SCONJ'],
#   ['tidak', 'PART'],
#   ['ada', 'VERB'],
#   ['luka', 'NOUN'],
#   ['di', 'ADP'],
#   ['tubuh', 'NOUN'],
#   ['penumpang', 'NOUN'],
#   ['tersebut', 'DET'],
#   ['.', 'PUNCT']],
#  [['Tadi', 'SCONJ'],
#   ['penumpangnya', 'NOUN'],
#   ['perempuan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['tapi', 'SCONJ'],
#   ['sudah', 'ADV'],
#   ['pulang', 'VERB'],
#   [',', 'PUNCT'],
#   ['dia', 'PRON'],
#   ['tidak', 'PART'],
#   ['apa-apa', 'ADV'],
#   ['kok', 'PART'],
#   ['.', 'PUNCT']],
#  [['Dia', 'PRON'],
#   ['terpaksa', 'VERB'],
#   ['keluar', 'VERB'],
#   ['lewat', 'ADP'],
#   ['kaca', 'NOUN'],
#   ['belakang', 'ADJ'],
#   ['dan', 'CCONJ'],
#   ['saya', 'PRON'],
#   ['lewat', 'VERB'],
#   ['pintu', 'NOUN'],
#   ['depan', 'ADJ'],
#   [',', 'PUNCT'],
#   ['ujarnya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Karena', 'SCONJ'],
#   ['angkot', 'NOUN'],
#   ['yang', 'PRON'],
#   ['ditumpanginya', 'VERB'],
#   ['terguling', 'VERB'],
#   ['ke', 'ADP'],
#   ['sungai', 'NOUN'],
#   [',', 'PUNCT'],
#   ['Bagyo', 'PROPN'],
#   ['mengatakan', 'VERB'],
#   [',', 'PUNCT'],
#   ['terpaksa', 'VERB'],
#   ['penumpang', 'NOUN'],
#   ['tadi', 'ADV'],
#   ['pindah', 'VERB'],
#   ['naik', 'VERB'],
#   ['angkot', 'NOUN'],
#   ['lain', 'ADJ'],
#   ['karena', 'SCONJ'],
#   ['melanjutkan', 'VERB'],
#   ['perjalanan', 'NOUN'],
#   ['ke', 'ADP'],
#   ['Singosari', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Salah', 'DET'],
#   ['seorang', 'DET'],
#   ['saksi', 'NOUN'],
#   [',', 'PUNCT'],
#   ['Yayuk', 'PROPN'],
#   [',', 'PUNCT'],
#   ['yang', 'PRON'],
#   ['melihat', 'VERB'],
#   ['kejadian', 'NOUN'],
#   ['tersebut', 'DET'],
#   ['menuturkan', 'VERB'],
#   ['bahwa', 'SCONJ'],
#   ['angkot', 'PROPN'],
#   ['melaju', 'VERB'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['barat', 'NOUN'],
#   ['ke', 'ADP'],
#   ['timur', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Kemudian', 'ADP'],
#   ['putar', 'NOUN'],
#   ['balik', 'ADJ'],
#   ['lalu', 'ADV'],
#   ['lurus', 'ADJ'],
#   ['menuju', 'VERB'],
#   ['jalan', 'NOUN'],
#   ['besar', 'ADJ'],
#   ['sebelum', 'ADP'],
#   ['akhirnya', 'ADV'],
#   ['jatuh', 'VERB'],
#   ['ke', 'ADP'],
#   ['sungai', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Menurut', 'ADP'],
#   ['Yayuk', 'PROPN'],
#   [',', 'PUNCT'],
#   ['penumpang', 'NOUN'],
#   ['perempuan', 'NOUN'],
#   ['yang', 'PRON'],
#   ['ikut', 'VERB'],
#   ['terjatuh', 'VERB'],
#   ['di', 'ADP'],
#   ['sungai', 'NOUN'],
#   ['tadi', 'ADV'],
#   ['mengeluh', 'VERB'],
#   ['sakit', 'NOUN'],
#   ['pinggang', 'NOUN'],
#   ['usai', 'ADV'],
#   ['terjatuh', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Kayaknya', 'ADV'],
#   ['tadi', 'ADV'],
#   ['mau', 'ADV'],
#   ['balik', 'ADJ'],
#   ['terus', 'ADV'],
#   ['periksa', 'VERB'],
#   ['ke', 'ADP'],
#   ['tukang', 'NOUN'],
#   ['pijat', 'NOUN'],
#   [',', 'PUNCT'],
#   ['tuturnya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Salah', 'DET'],
#   ['satu', 'DET'],
#   ['anggota', 'NOUN'],
#   ['kepolisian', 'NOUN'],
#   ['yang', 'PRON'],
#   ['mengevakuasi', 'VERB'],
#   ['kejadian', 'NOUN'],
#   [',', 'PUNCT'],
#   ['Dedi', 'PROPN'],
#   ['mengatakan', 'VERB'],
#   [',', 'PUNCT'],
#   ['salah', 'DET'],
#   ['satu', 'DET'],
#   ['penyebab', 'NOUN'],
#   ['kecelakaan', 'NOUN'],
#   ['lalu', 'ADP'],
#   ['lintas', 'NOUN'],
#   ['tersebut', 'DET'],
#   ['adalah', 'AUX'],
#   ['akibat', 'NOUN'],
#   ['jalan', 'NOUN'],
#   ['licin', 'ADJ'],
#   ['yang', 'PRON'],
#   ['basah', 'ADJ'],
#   ['terkena', 'VERB'],
#   ['hujan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Angkot', 'PROPN'],
#   ['body-nya', 'PROPN'],
#   ['ringsek', 'PROPN'],
#   [',', 'PUNCT'],
#   ['nanti', 'ADV'],
#   ['diamankan', 'VERB'],
#   ['ke', 'ADP'],
#   ['Polres', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Sementara', 'SCONJ'],
#   ['penyebabnya', 'NOUN'],
#   ['karena', 'SCONJ'],
#   ['sopir', 'NOUN'],
#   ['kurang', 'ADV'],
#   ['fokus', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['KRAKSAAN', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Radar', 'PROPN'],
#   ['Bromo', 'PROPN'],
#   ['Nahas', 'PROPN'],
#   ['menimpa', 'VERB'],
#   ['Miskari', 'PUNCT'],
#   ['59', 'NUM'],
#   [',', 'PUNCT'],
#   ['Selasa', 'PROPN'],
#   ['(', 'PUNCT'],
#   ['29/12', 'PROPN'],
#   [')', 'PUNCT'],
#   ['malam', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Tukang', 'PROPN'],
#   ['becak', 'NOUN'],
#   ['itu', 'DET'],
#   ['ditabrak', 'VERB'],
#   ['sebuah', 'DET'],
#   ['truk', 'NOUN'],
#   ['boks', 'NOUN'],
#   ['saat', 'SCONJ'],
#   ['hendak', 'ADV'],
#   ['menyeberang', 'VERB'],
#   ['di', 'ADP'],
#   ['jalan', 'NOUN'],
#   ['raya', 'NOUN'],
#   ['Kelurahan', 'PROPN'],
#   ['Patokan', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kraksaan', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kabupaten', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Ia', 'PRON'],
#   ['pun', 'PART'],
#   ['langsung', 'ADV'],
#   ['meninggal', 'VERB'],
#   ['di', 'ADP'],
#   ['lokasi', 'NOUN'],
#   ['kejadian', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Kecelakaan', 'NOUN'],
#   ['itu', 'DET'],
#   ['terjadi', 'VERB'],
#   ['sekitar', 'ADP'],
#   ['pukul', 'NOUN'],
#   ['21.00', 'NUM'],
#   ['.', 'PUNCT']],
#  [['Saat', 'SCONJ'],
#   ['itu', 'DET'],
#   ['warga', 'NOUN'],
#   ['Kelurahan', 'PROPN'],
#   ['Sidomukti', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kraksaan', 'PROPN'],
#   [',', 'PUNCT'],
#   ['itu', 'DET'],
#   ['tengah', 'NOUN'],
#   ['mengayuh', 'VERB'],
#   ['becaknya', 'NOUN'],
#   ['dari', 'ADP'],
#   ['timur', 'NOUN'],
#   ['ke', 'ADP'],
#   ['barat', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Dia', 'PRON'],
#   ['mengayuh', 'VERB'],
#   ['di', 'ADP'],
#   ['lajur', 'NOUN'],
#   ['selatan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['tepatnya', 'VERB'],
#   ['di', 'ADP'],
#   ['barat', 'NOUN'],
#   ['jembatan', 'NOUN'],
#   ['kembar', 'NOUN'],
#   [',', 'PUNCT'],
#   ['Kraksaan', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Sesaat', 'SCONJ'],
#   ['kemudian', 'ADV'],
#   [',', 'PUNCT'],
#   ['Miskari', 'PROPN'],
#   ['menyeberang', 'VERB'],
#   ['ke', 'ADP'],
#   ['utara', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Lalu', 'SCONJ'],
#   [',', 'PUNCT'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['yang', 'PRON'],
#   ['sama', 'ADJ'],
#   ['meluncur', 'VERB'],
#   ['sebuah', 'DET'],
#   ['truk', 'NOUN'],
#   ['boks', 'NOUN'],
#   ['bernopol', 'PROPN'],
#   ['L', 'PROPN'],
#   ['8672', 'NUM'],
#   ['AK', 'PROPN'],
#   ['disopiri', 'PROPN'],
#   ['Dwi', 'PROPN'],
#   ['Julianto', 'PROPN'],
#   ['Maulana', 'PROPN'],
#   [',', 'PUNCT'],
#   ['23', 'NUM'],
#   [',', 'PUNCT'],
#   ['warga', 'NOUN'],
#   ['Sumbertaman', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Wonoasih', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kota', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Diduga', 'PROPN'],
#   ['kurang', 'ADV'],
#   ['konsentrasi', 'NOUN'],
#   [',', 'PUNCT'],
#   ['truk', 'NOUN'],
#   ['langsung', 'ADJ'],
#   ['menabrak', 'VERB'],
#   ['becak', 'NOUN'],
#   ['tanpa', 'ADP'],
#   ['muatan', 'NOUN'],
#   ['itu', 'DET'],
#   ['.', 'PUNCT']],
#  [['Becak', 'PROPN'],
#   ['pun', 'PART'],
#   ['langsung', 'ADV'],
#   ['terguling', 'VERB'],
#   ['di', 'ADP'],
#   ['lokasi', 'NOUN'],
#   ['kejadian', 'NOUN'],
#   ['bersama', 'ADP'],
#   ['korban', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Kanitlaka', 'ADP'],
#   ['Satlantas', 'PROPN'],
#   ['Polres', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['Ipda', 'PROPN'],
#   ['Nyoman', 'PROPN'],
#   ['Harayasa', 'PUNCT'],
#   ['mengatakan', 'VERB'],
#   [',', 'PUNCT'],
#   ['truk', 'NOUN'],
#   ['boks', 'NOUN'],
#   ['kehilangan', 'VERB'],
#   ['kendali', 'NOUN'],
#   ['saat', 'NOUN'],
#   ['itu', 'DET'],
#   ['.', 'PUNCT']],
#  [['Kemudian', 'ADV'],
#   ['menabrak', 'VERB'],
#   ['becak', 'NOUN'],
#   ['tanpa', 'ADP'],
#   ['penumpang', 'NOUN'],
#   ['yang', 'PRON'],
#   ['dikayuh', 'VERB'],
#   ['korban', 'NOUN'],
#   ['Miskari', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Insiden', 'NOUN'],
#   ['itu', 'DET'],
#   ['membuat', 'VERB'],
#   ['kepala', 'NOUN'],
#   ['korban', 'NOUN'],
#   ['luka', 'NOUN'],
#   ['parah', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Dari', 'ADP'],
#   ['hasil', 'NOUN'],
#   ['olah', 'NOUN'],
#   ['TKP', 'PROPN'],
#   [',', 'PUNCT'],
#   ['pengemudi', 'NOUN'],
#   ['truk', 'NOUN'],
#   ['boks', 'NOUN'],
#   ['diduga', 'VERB'],
#   ['kurang', 'ADV'],
#   ['konsentrasi', 'NOUN'],
#   ['saat', 'SCONJ'],
#   ['sedang', 'ADV'],
#   ['mengemudi', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Akibat', 'SCONJ'],
#   ['kejadian', 'NOUN'],
#   ['itu', 'DET'],
#   [',', 'PUNCT'],
#   ['korban', 'NOUN'],
#   ['langsung', 'ADJ'],
#   ['meninggal', 'VERB'],
#   ['di', 'ADP'],
#   ['TKP', 'PROPN'],
#   [',', 'PUNCT'],
#   ['ujar', 'PROPN'],
#   ['Nyoman', 'PROPN'],
#   ['saat', 'SCONJ'],
#   ['dikonfirmasi', 'VERB'],
#   ['Rabu', 'PROPN'],
#   ['(', 'PUNCT'],
#   ['30/12', 'PROPN'],
#   [')', 'PUNCT'],
#   ['.', 'PUNCT']],
#  [['Usai', 'PROPN'],
#   ['menabrak', 'VERB'],
#   ['korban', 'NOUN'],
#   [',', 'PUNCT'],
#   ['menurut', 'ADP'],
#   ['Nyoman', 'PROPN'],
#   [',', 'PUNCT'],
#   ['pengemudi', 'NOUN'],
#   ['truk', 'NOUN'],
#   ['boks', 'NOUN'],
#   ['tidak', 'PART'],
#   ['langsung', 'ADV'],
#   ['berhenti', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Dia', 'PRON'],
#   ['malah', 'ADV'],
#   ['hendak', 'ADV'],
#   ['kabur', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Namun', 'SCONJ'],
#   [',', 'PUNCT'],
#   ['warga', 'NOUN'],
#   ['sekitar', 'ADP'],
#   ['yang', 'PRON'],
#   ['melihat', 'VERB'],
#   ['kecelakaan', 'NOUN'],
#   ['itu', 'DET'],
#   ['langsung', 'ADV'],
#   ['menghentikan', 'VERB'],
#   ['truk', 'NOUN'],
#   ['boks', 'NOUN'],
#   ['tersebut', 'DET'],
#   ['.', 'PUNCT']],
#  [['Usai', 'ADV'],
#   ['menabrak', 'VERB'],
#   [',', 'PUNCT'],
#   ['truk', 'NOUN'],
#   ['boks', 'NOUN'],
#   ['tidak', 'PART'],
#   ['langsung', 'ADV'],
#   ['berhenti', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Malah', 'ADV'],
#   ['tetap', 'ADV'],
#   ['melaju', 'VERB'],
#   ['ke', 'ADP'],
#   ['arah', 'NOUN'],
#   ['barat', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Untungnya', 'VERB'],
#   ['oleh', 'ADP'],
#   ['warga', 'NOUN'],
#   ['di', 'ADP'],
#   ['sekitar', 'ADP'],
#   ['TKP', 'PROPN'],
#   ['dikejar', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Saat', 'NOUN'],
#   ['ini', 'DET'],
#   ['dua', 'NUM'],
#   ['kendaraan', 'NOUN'],
#   ['yang', 'PRON'],
#   ['terlibat', 'VERB'],
#   ['kecelakaan', 'NOUN'],
#   ['sudah', 'ADV'],
#   ['kami', 'PRON'],
#   ['amankan', 'VERB'],
#   ['di', 'ADP'],
#   ['pos', 'NOUN'],
#   ['lantas', 'ADJ'],
#   [',', 'PUNCT'],
#   ['katanya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Mau', 'PROPN'],
#   ['Nyalip', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Ditabrak', 'VERB'],
#   ['TrailerSebelumnya', 'NOUN'],
#   [',', 'PUNCT'],
#   ['di', 'ADP'],
#   ['malam', 'NOUN'],
#   ['yang', 'PRON'],
#   ['sama', 'ADJ'],
#   ['juga', 'ADV'],
#   ['terjadi', 'VERB'],
#   ['kecelakaan', 'NOUN'],
#   ['di', 'ADP'],
#   ['Jalan', 'PROPN'],
#   ['Raya', 'PROPN'],
#   ['Pajurangan', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Gending', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kabupaten', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Kecelakaan', 'NOUN'],
#   ['yang', 'PRON'],
#   ['terjadi', 'VERB'],
#   ['sekitar', 'ADP'],
#   ['pukul', 'NOUN'],
#   ['19.00', 'NUM'],
#   [',', 'PUNCT'],
#   ['itu', 'DET'],
#   ['melibatkan', 'VERB'],
#   ['dua', 'NUM'],
#   ['kendaraan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Yaitu', 'ADV'],
#   [',', 'PUNCT'],
#   ['motor', 'NOUN'],
#   ['Honda', 'PROPN'],
#   ['Vario', 'PROPN'],
#   ['nopol', 'PROPN'],
#   ['N', 'PROPN'],
#   ['5914', 'NUM'],
#   ['N', 'NOUN'],
#   ['yang', 'PRON'],
#   ['dikendarai', 'VERB'],
#   ['Muhammad', 'PROPN'],
#   ['Saiful', 'PROPN'],
#   ['Amin', 'PROPN'],
#   [',', 'PUNCT'],
#   ['20', 'NUM'],
#   [',', 'PUNCT'],
#   ['warga', 'NOUN'],
#   ['RT', 'PROPN'],
#   ['3/RW', 'PUNCT'],
#   ['1', 'NUM'],
#   [',', 'PUNCT'],
#   ['Desa', 'PROPN'],
#   ['Alassumur', 'PROPN'],
#   ['Lor', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Besuk', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Dan', 'CCONJ'],
#   ['satu', 'NUM'],
#   ['lagi', 'ADV'],
#   [',', 'PUNCT'],
#   ['yaitu', 'SCONJ'],
#   ['truk', 'NOUN'],
#   ['trailer', 'NOUN'],
#   ['Nopol', 'PROPN'],
#   ['L', 'PROPN'],
#   ['9299', 'NUM'],
#   ['UL', 'PROPN'],
#   ['yang', 'PRON'],
#   ['disopiri', 'VERB'],
#   ['Joyo', 'PROPN'],
#   ['Kamsono', 'PROPN'],
#   [',', 'PUNCT'],
#   ['62', 'NUM'],
#   [',', 'PUNCT'],
#   ['warga', 'NOUN'],
#   ['Desa', 'PROPN'],
#   ['Talok', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Bangsal', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kabupaten', 'PROPN'],
#   ['Mojokerto', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Kanitlaka', 'PROPN'],
#   ['Satlantas', 'PROPN'],
#   ['Polres', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['Ipda', 'PROPN'],
#   ['Nyoman', 'PROPN'],
#   ['Harayasa', 'PROPN'],
#   ['menjelaskan', 'VERB'],
#   [',', 'PUNCT'],
#   ['awalnya', 'ADV'],
#   ['pengendara', 'NOUN'],
#   ['motor', 'NOUN'],
#   ['melaju', 'VERB'],
#   ['dari', 'ADP'],
#   ['barat', 'NOUN'],
#   ['ke', 'ADP'],
#   ['timur', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Sampai', 'ADP'],
#   ['di', 'ADP'],
#   ['Jalan', 'PROPN'],
#   ['Raya', 'PROPN'],
#   ['Pajurangan', 'PROPN'],
#   [',', 'PUNCT'],
#   ['motor', 'NOUN'],
#   ['hendak', 'ADV'],
#   ['menyalip', 'VERB'],
#   ['sebuah', 'DET'],
#   ['kendaraan', 'NOUN'],
#   ['di', 'ADP'],
#   ['depannya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Namun', 'SCONJ'],
#   [',', 'PUNCT'],
#   ['motor', 'NOUN'],
#   ['menyalip', 'VERB'],
#   ['terlalu', 'ADV'],
#   ['ke', 'ADP'],
#   ['kanan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Dalam', 'ADP'],
#   ['waktu', 'NOUN'],
#   ['yang', 'PRON'],
#   ['sama', 'ADJ'],
#   [',', 'PUNCT'],
#   ['melaju', 'VERB'],
#   ['truk', 'NOUN'],
#   ['trailer', 'NOUN'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['berlawanan', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Akibatnya', 'SCONJ'],
#   [',', 'PUNCT'],
#   ['terjadilah', 'VERB'],
#   ['tabrakan', 'NOUN'],
#   ['antara', 'ADP'],
#   ['truk', 'NOUN'],
#   ['trailer', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['motor', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Pengendara', 'NOUN'],
#   ['motor', 'NOUN'],
#   ['Saiful', 'PROPN'],
#   ['Amin', 'PROPN'],
#   ['langsung', 'ADV'],
#   ['dilarikan', 'VERB'],
#   ['ke', 'ADP'],
#   ['IGD', 'PROPN'],
#   ['RSUD', 'PROPN'],
#   ['Waluyo', 'PROPN'],
#   ['Jati', 'PROPN'],
#   ['Kraksaan', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Tapi', 'SCONJ'],
#   ['hanya', 'ADV'],
#   ['mengalami', 'VERB'],
#   ['luka', 'NOUN'],
#   ['ringan', 'ADJ'],
#   [',', 'PUNCT'],
#   ['terang', 'ADJ'],
#   ['Nyoman', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Adapun', 'SCONJ'],
#   ['supir', 'NOUN'],
#   ['truk', 'NOUN'],
#   ['trailer', 'NOUN'],
#   ['tidak', 'PART'],
#   ['terluka', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Truk', 'PROPN'],
#   ['trailer', 'PROPN'],
#   ['juga', 'ADV'],
#   ['tidak', 'PART'],
#   ['ada', 'VERB'],
#   ['yang', 'PRON'],
#   ['rusak', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Sementara', 'SCONJ'],
#   ['sepeda', 'NOUN'],
#   ['motor', 'NOUN'],
#   ['pengendara', 'NOUN'],
#   ['motor', 'NOUN'],
#   ['Saiful', 'PROPN'],
#   ['Amin', 'PROPN'],
#   ['hancur', 'VERB'],
#   ['parah', 'ADJ'],
#   ['di', 'ADP'],
#   ['bagian', 'NOUN'],
#   ['depan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['TEROBOS', 'NOUN'],
#   ['LINTASAN', 'NOUN'],
#   [':', 'PUNCT'],
#   ['Sebuah', 'DET'],
#   ['mobil', 'NOUN'],
#   ['Isuzu', 'PROPN'],
#   ['Panther', 'PROPN'],
#   ['bernopol', 'PROPN'],
#   ['P', 'PROPN'],
#   ['1249', 'NUM'],
#   ['GA', 'PROPN'],
#   ['tampak', 'VERB'],
#   ['menerobos', 'VERB'],
#   ['perlintasan', 'NOUN'],
#   ['kereta', 'NOUN'],
#   ['api', 'NOUN'],
#   ['walaupun', 'SCONJ'],
#   ['sudah', 'ADV'],
#   ['ditutup', 'VERB'],
#   ['oleh', 'ADP'],
#   ['petugas', 'NOUN'],
#   ['jaga', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['JEMBER', 'PROPN'],
#   [',', 'PUNCT'],
#   ['RADARJEMBER.ID', 'PROPN'],
#   ['Terjadinya', 'VERB'],
#   ['kecelakaan', 'NOUN'],
#   ['di', 'ADP'],
#   ['jalan', 'NOUN'],
#   ['raya', 'NOUN'],
#   ['kerap', 'ADV'],
#   ['kali', 'ADV'],
#   ['diawali', 'VERB'],
#   ['dengan', 'ADP'],
#   ['pelanggaran', 'NOUN'],
#   ['atau', 'CCONJ'],
#   ['kecerobohan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Seperti', 'ADP'],
#   ['mobil', 'NOUN'],
#   ['Isuzu', 'PROPN'],
#   ['Panther', 'PROPN'],
#   ['P', 'PROPN'],
#   ['1249', 'NUM'],
#   ['GA', 'PROPN'],
#   ['yang', 'PRON'],
#   ['melintas', 'VERB'],
#   ['di', 'ADP'],
#   ['Jalan', 'PROPN'],
#   ['Udang', 'PROPN'],
#   ['Windu', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kelurahan', 'PROPN'],
#   ['Mangli', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Kaliwates', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Senin', 'PROPN'],
#   ['(', 'PUNCT'],
#   ['28/12', 'PROPN'],
#   [')', 'PUNCT'],
#   ['siang', 'NOUN'],
#   ['kemarin', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Mobil', 'PROPN'],
#   ['ini', 'DET'],
#   ['tampak', 'VERB'],
#   ['melewati', 'VERB'],
#   ['palang', 'NOUN'],
#   ['pintu', 'NOUN'],
#   ['perlintasan', 'NOUN'],
#   ['kereta', 'NOUN'],
#   ['api', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Saat', 'SCONJ'],
#   ['petugas', 'NOUN'],
#   ['jaga', 'NOUN'],
#   ['perlintasan', 'NOUN'],
#   ['kereta', 'NOUN'],
#   ['api', 'NOUN'],
#   ['(', 'PUNCT'],
#   ['KA', 'PROPN'],
#   [')', 'PUNCT'],
#   ['di', 'ADP'],
#   ['Jalan', 'PROPN'],
#   ['Udang', 'PROPN'],
#   ['Windu', 'PROPN'],
#   ['tersebut', 'DET'],
#   ['menutup', 'VERB'],
#   ['perlintasan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['sopir', 'NOUN'],
#   ['tetap', 'ADV'],
#   ['menerobos', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Padahal', 'SCONJ'],
#   ['sirene', 'NOUN'],
#   ['pertanda', 'NOUN'],
#   ['perlintasan', 'NOUN'],
#   ['akan', 'ADV'],
#   ['ditutup', 'VERB'],
#   ['sudah', 'ADV'],
#   ['berbunyi', 'VERB'],
#   ['cukup', 'ADV'],
#   ['lantang', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Bahkan', 'SCONJ'],
#   [',', 'PUNCT'],
#   ['ketika', 'SCONJ'],
#   ['hendak', 'ADV'],
#   ['menutup', 'VERB'],
#   ['pintu', 'NOUN'],
#   ['perlintasan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['petugas', 'NOUN'],
#   ['jaga', 'NOUN'],
#   ['harus', 'ADV'],
#   ['menundanya', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Sayangnya', 'ADV'],
#   [',', 'PUNCT'],
#   ['jarak', 'NOUN'],
#   ['antara', 'ADP'],
#   ['mobil', 'NOUN'],
#   ['dengan', 'ADP'],
#   ['perlintasan', 'NOUN'],
#   ['kereta', 'NOUN'],
#   ['sudah', 'ADV'],
#   ['sangat', 'ADV'],
#   ['dekat', 'ADJ'],
#   [',', 'PUNCT'],
#   ['sehingga', 'SCONJ'],
#   ['mau', 'ADV'],
#   ['tidak', 'PART'],
#   ['mau', 'VERB'],
#   ['mobil', 'NOUN'],
#   ['tersebut', 'DET'],
#   ['harus', 'ADV'],
#   ['berhenti', 'VERB'],
#   ['tepat', 'ADJ'],
#   ['di', 'ADP'],
#   ['samping', 'NOUN'],
#   ['rel', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Tentu', 'ADV'],
#   ['saja', 'ADV'],
#   [',', 'PUNCT'],
#   ['jaraknya', 'VERB'],
#   ['dengan', 'ADP'],
#   ['kereta', 'NOUN'],
#   ['yang', 'PRON'],
#   ['melaju', 'VERB'],
#   ['sangat', 'ADV'],
#   ['dekat', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Beruntung', 'NOUN'],
#   [',', 'PUNCT'],
#   ['masih', 'ADV'],
#   ['ada', 'VERB'],
#   ['jarak', 'NOUN'],
#   ['antara', 'ADP'],
#   ['perlintasan', 'NOUN'],
#   ['dengan', 'ADP'],
#   ['pintu', 'NOUN'],
#   ['KA', 'PROPN'],
#   ['yang', 'PRON'],
#   ['ditutup', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Kondisi', 'NOUN'],
#   ['ini', 'DET'],
#   ['tentu', 'ADV'],
#   ['sangat', 'ADV'],
#   ['membahayakan', 'VERB'],
#   ['tidak', 'PART'],
#   ['hanya', 'ADV'],
#   ['bagi', 'ADP'],
#   ['pengguna', 'NOUN'],
#   ['jalan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['namun', 'SCONJ'],
#   ['juga', 'ADV'],
#   ['rangkaian', 'NOUN'],
#   ['kereta', 'NOUN'],
#   ['api', 'NOUN'],
#   ['yang', 'PRON'],
#   ['melintas', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Ayo', 'PROPN'],
#   ['tertib', 'PROPN'],
#   ['berlalu', 'VERB'],
#   ['lintas', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Kecelakaan', 'NOUN'],
#   ['lalu', 'ADP'],
#   ['lintas', 'NOUN'],
#   ['juga', 'ADV'],
#   ['kerap', 'ADV'],
#   ['terjadi', 'VERB'],
#   ['karena', 'SCONJ'],
#   ['kecerobohan', 'NOUN'],
#   ['pengemudi', 'NOUN'],
#   ['itu', 'DET'],
#   ['sendiri', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['KRAKSAAN', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Radar', 'PROPN'],
#   ['Bromo', 'PROPN'],
#   ['Jumlah', 'PROPN'],
#   ['insiden', 'NOUN'],
#   ['kecelakaan', 'NOUN'],
#   ['yang', 'PRON'],
#   ['ditangani', 'VERB'],
#   ['Polres', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['selama', 'ADP'],
#   ['Januari-November', 'PROPN'],
#   ['di', 'ADP'],
#   ['tahun', 'NOUN'],
#   ['2020', 'NUM'],
#   ['.', 'PUNCT']],
#  [['Selama', 'ADP'],
#   ['11', 'NUM'],
#   ['bulan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['Satlantas', 'PROPN'],
#   ['Polres', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['mencatat', 'VERB'],
#   [',', 'PUNCT'],
#   ['ada', 'VERB'],
#   ['448', 'NUM'],
#   ['insiden', 'NOUN'],
#   ['kecelakaan', 'NOUN'],
#   ['di', 'ADP'],
#   ['wilayah', 'NOUN'],
#   ['hukumnya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Dari', 'ADP'],
#   ['jumlah', 'NOUN'],
#   ['448', 'NUM'],
#   ['insiden', 'NOUN'],
#   [',', 'PUNCT'],
#   ['65', 'NUM'],
#   ['korban', 'NOUN'],
#   ['di', 'ADP'],
#   ['antaranya', 'NOUN'],
#   ['meninggal', 'VERB'],
#   ['dunia', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Jika', 'SCONJ'],
#   ['dirinci', 'VERB'],
#   ['korban', 'NOUN'],
#   ['kecelakaan', 'NOUN'],
#   ['mencapai', 'VERB'],
#   ['sekitar', 'ADP'],
#   ['540', 'NUM'],
#   ['orang', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Korban', 'NOUN'],
#   ['kecelakaan', 'NOUN'],
#   ['paling', 'ADV'],
#   ['banyak', 'ADV'],
#   ['menderita', 'VERB'],
#   ['luka', 'NOUN'],
#   ['ringan', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Kanitlaka', 'ADP'],
#   ['Satlantas', 'PROPN'],
#   ['Polres', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['Iptu', 'PROPN'],
#   ['Nyoman', 'PROPN'],
#   ['Harayasa', 'PUNCT'],
#   ['mengatakan', 'VERB'],
#   [',', 'PUNCT'],
#   ['insiden', 'NOUN'],
#   ['kecelakaan', 'NOUN'],
#   ['lalu', 'CCONJ'],
#   ['lintas', 'NOUN'],
#   ['tersebut', 'DET'],
#   ['terjadi', 'VERB'],
#   ['di', 'ADP'],
#   ['sepanjang', 'ADP'],
#   ['ruas', 'NOUN'],
#   ['jalan', 'NOUN'],
#   ['Kabupaten', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   [',', 'PUNCT'],
#   ['khususnya', 'NOUN'],
#   ['yang', 'PRON'],
#   ['ditangani', 'VERB'],
#   ['Polres', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Kejadiannya', 'NOUN'],
#   ['hampir', 'ADV'],
#   ['mencapai', 'VERB'],
#   ['500', 'NUM'],
#   ['laka', 'PROPN'],
#   ['lantas', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Ratusan', 'DET'],
#   ['kejadian', 'NOUN'],
#   ['tersebut', 'DET'],
#   ['juga', 'ADV'],
#   ['sama', 'ADJ'],
#   ['halnya', 'VERB'],
#   ['dengan', 'ADP'],
#   ['korban', 'NOUN'],
#   ['yang', 'PRON'],
#   ['mengalami', 'VERB'],
#   ['kecelakaan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Jumlahnya', 'ADV'],
#   ['lebih', 'ADV'],
#   ['tinggi', 'ADJ'],
#   ['dari', 'ADP'],
#   ['pada', 'ADP'],
#   ['kejadiannya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Sebab', 'SCONJ'],
#   ['di', 'ADP'],
#   ['antara', 'ADP'],
#   ['kejadian', 'NOUN'],
#   [',', 'PUNCT'],
#   ['ada', 'VERB'],
#   ['kendaraan', 'NOUN'],
#   ['yang', 'PRON'],
#   ['dikendarai', 'VERB'],
#   ['lebih', 'ADV'],
#   ['dari', 'ADP'],
#   ['satu', 'NUM'],
#   ['orang', 'NOUN'],
#   [',', 'PUNCT'],
#   ['ujarnya', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Harayasa', 'PROPN'],
#   ['menyebutkan', 'VERB'],
#   [',', 'PUNCT'],
#   ['stiap', 'NOUN'],
#   ['bulan', 'NOUN'],
#   ['insiden', 'NOUN'],
#   ['kecelakaan', 'NOUN'],
#   ['memang', 'ADV'],
#   ['mengalami', 'VERB'],
#   ['naik', 'VERB'],
#   ['turun', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Sementara', 'SCONJ'],
#   ['itu', 'DET'],
#   [',', 'PUNCT'],
#   ['pada', 'ADP'],
#   ['ratusan', 'DET'],
#   ['kejadian', 'NOUN'],
#   ['tersebut', 'DET'],
#   [',', 'PUNCT'],
#   ['kendaraan', 'NOUN'],
#   ['yang', 'PRON'],
#   ['terlibat', 'VERB'],
#   ['laka', 'PROPN'],
#   ['lantas', 'ADV'],
#   ['sendiri', 'ADV'],
#   ['didominasi', 'VERB'],
#   ['oleh', 'ADP'],
#   ['kendaraan', 'NOUN'],
#   ['roda', 'NOUN'],
#   ['dua', 'NUM'],
#   ['.', 'PUNCT']],
#  [['Faktornya', 'NOUN'],
#   [',', 'PUNCT'],
#   ['lanjut', 'NOUN'],
#   ['Harayasa', 'NOUN'],
#   [',', 'PUNCT'],
#   ['ada', 'VERB'],
#   ['dua', 'NUM'],
#   ['.', 'PUNCT']],
#  [['Yang', 'PRON'],
#   ['pertama', 'ADJ'],
#   ['adalah', 'AUX'],
#   ['disebabkan', 'VERB'],
#   ['cuaca', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['human', 'PROPN'],
#   ['error', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Harayasa', 'PROPN'],
#   ['menjelaskan', 'VERB'],
#   [',', 'PUNCT'],
#   ['saat', 'SCONJ'],
#   ['cuaca', 'NOUN'],
#   ['buruk', 'ADJ'],
#   ['kejadian', 'NOUN'],
#   ['kecelakaan', 'NOUN'],
#   ['rentan', 'ADJ'],
#   ['terjadi', 'VERB'],
#   ['lantaran', 'SCONJ'],
#   ['dapat', 'ADV'],
#   ['menggangu', 'VERB'],
#   ['konsentrasi', 'NOUN'],
#   ['para', 'DET'],
#   ['pengendara', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Misal', 'NOUN'],
#   ['ada', 'VERB'],
#   ['pada', 'ADP'],
#   ['jarak', 'NOUN'],
#   ['pandang', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Sedang', 'ADV'],
#   ['pada', 'ADP'],
#   ['kondisi', 'NOUN'],
#   ['para', 'DET'],
#   ['pengendara', 'NOUN'],
#   [',', 'PUNCT'],
#   ['lanjut', 'ADV'],
#   ['dia', 'PRON'],
#   [',', 'PUNCT'],
#   ['dalam', 'ADP'],
#   ['kondisi', 'NOUN'],
#   ['kurang', 'ADV'],
#   ['baik', 'ADJ'],
#   ['juga', 'ADV'],
#   ['dapat', 'ADV'],
#   ['memunculkan', 'VERB'],
#   ['risiko', 'NOUN'],
#   ['kecelakaan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Seperti', 'ADP'],
#   ['saat', 'NOUN'],
#   ['hujan', 'NOUN'],
#   ['kondisi', 'NOUN'],
#   ['jalan', 'NOUN'],
#   ['licin', 'ADJ'],
#   ['dan', 'CCONJ'],
#   ['jarak', 'NOUN'],
#   ['pandang', 'NOUN'],
#   ['terbatas', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Lebih', 'ADV'],
#   ['baik', 'ADJ'],
#   ['berhenti', 'VERB'],
#   ['dan', 'CCONJ'],
#   ['menunggu', 'VERB'],
#   ['hujan', 'NOUN'],
#   ['selesai', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Sedangkan', 'SCONJ'],
#   ['saat', 'NOUN'],
#   ['kondisi', 'NOUN'],
#   ['berkendara', 'VERB'],
#   ['seperti', 'ADP'],
#   ['malam', 'NOUN'],
#   ['hari', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['dalam', 'ADP'],
#   ['keadaan', 'NOUN'],
#   ['mengantuk', 'VERB'],
#   ['juga', 'ADV'],
#   ['bisa', 'ADV'],
#   ['berhenti', 'VERB'],
#   ['untuk', 'ADP'],
#   ['sitirahat', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Hal', 'NOUN'],
#   ['itu', 'DET'],
#   ['dilakukan', 'VERB'],
#   ['guna', 'NOUN'],
#   ['mengurangi', 'VERB'],
#   ['risiko', 'NOUN'],
#   ['terjadinya', 'NOUN'],
#   ['kecelakaan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Untuk', 'ADP'],
#   ['jenis', 'NOUN'],
#   ['kendaraan', 'NOUN'],
#   ['yang', 'PRON'],
#   ['terlibat', 'VERB'],
#   ['kecelakaan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['mulai', 'VERB'],
#   ['dari', 'ADP'],
#   ['motor', 'NOUN'],
#   [',', 'PUNCT'],
#   ['minibus', 'NOUN'],
#   [',', 'PUNCT'],
#   ['pikap', 'NOUN'],
#   [',', 'PUNCT'],
#   ['hingga', 'ADP'],
#   ['truk', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Selain', 'ADP'],
#   ['itu', 'DET'],
#   ['pada', 'ADP'],
#   ['jenis', 'NOUN'],
#   ['profesi', 'NOUN'],
#   ['korban', 'NOUN'],
#   ['juga', 'ADV'],
#   ['berbeda-beda', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Selain', 'ADP'],
#   ['itu', 'DET'],
#   [',', 'PUNCT'],
#   ['jenis', 'NOUN'],
#   ['pada', 'ADP'],
#   ['profesi', 'NOUN'],
#   ['korban', 'NOUN'],
#   ['juga', 'ADV'],
#   ['berbeda', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Di', 'ADP'],
#   ['antaranya', 'NOUN'],
#   ['dari', 'ADP'],
#   ['karyawan', 'NOUN'],
#   ['swasta', 'ADJ'],
#   [',', 'PUNCT'],
#   ['pelajar', 'NOUN'],
#   [',', 'PUNCT'],
#   ['Polri', 'PROPN'],
#   ['1', 'NUM'],
#   [',', 'PUNCT'],
#   ['dan', 'CCONJ'],
#   ['masih', 'ADV'],
#   ['banyak', 'ADV'],
#   ['yang', 'PRON'],
#   ['lain', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Sementara', 'SCONJ'],
#   ['itu', 'DET'],
#   ['pada', 'ADP'],
#   ['usia', 'NOUN'],
#   ['korban', 'NOUN'],
#   ['sendiri', 'ADJ'],
#   ['dimulai', 'VERB'],
#   ['dari', 'ADP'],
#   ['36-55', 'PROPN'],
#   [',', 'PUNCT'],
#   ['usia', 'NOUN'],
#   ['26-35', 'PROPN'],
#   ['dan', 'CCONJ'],
#   ['usia', 'NOUN'],
#   ['Remaja', 'PROPN'],
#   ['18-25', 'PROPN'],
#   [',', 'PUNCT'],
#   ['ujarnya', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Dengan', 'ADP'],
#   ['adanya', 'NOUN'],
#   ['beberapa', 'DET'],
#   ['faktor', 'NOUN'],
#   ['tersebut', 'DET'],
#   [',', 'PUNCT'],
#   ['Harayasa', 'ADV'],
#   ['mengingatkan', 'VERB'],
#   [',', 'PUNCT'],
#   ['agar', 'SCONJ'],
#   ['para', 'DET'],
#   ['pengendara', 'NOUN'],
#   ['agar', 'SCONJ'],
#   ['dapat', 'ADV'],
#   ['lebih', 'ADV'],
#   ['hati-hati', 'ADJ'],
#   ['dan', 'CCONJ'],
#   ['menyiapkan', 'VERB'],
#   ['segala', 'DET'],
#   ['sesuatunya', 'NOUN'],
#   ['saat', 'NOUN'],
#   ['sebelum', 'ADP'],
#   ['berkendara', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Keamanan', 'PROPN'],
#   ['dan', 'CCONJ'],
#   ['mengecek', 'VERB'],
#   ['kendaraan', 'NOUN'],
#   ['saat', 'NOUN'],
#   ['sebelum', 'ADP'],
#   ['berkendara', 'VERB'],
#   ['sangatlah', 'ADV'],
#   ['penting', 'ADJ'],
#   [',', 'PUNCT'],
#   ['dan', 'CCONJ'],
#   ['harus', 'ADV'],
#   ['dilakukan', 'VERB'],
#   [',', 'PUNCT'],
#   ['ujarnya', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['SUMBER', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Radar', 'PROPN'],
#   ['Bromo', 'PROPN'],
#   ['Rencana', 'PROPN'],
#   ['Ramadhan', 'PROPN'],
#   ['Budi', 'PROPN'],
#   [',', 'PUNCT'],
#   ['25', 'NUM'],
#   ['beserta', 'CCONJ'],
#   ['istri', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['anaknya', 'NOUN'],
#   ['untuk', 'ADP'],
#   ['pulang', 'VERB'],
#   ['usai', 'VERB'],
#   ['dari', 'ADP'],
#   ['Sumber', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kabupaten', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['berujung', 'VERB'],
#   ['tragedi', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Motor', 'PROPN'],
#   ['matiknya', 'NOUN'],
#   ['alami', 'ADJ'],
#   ['rem', 'NOUN'],
#   ['blong', 'NOUN'],
#   ['hingga', 'ADP'],
#   ['terjun', 'VERB'],
#   ['ke', 'ADP'],
#   ['pekarangan', 'NOUN'],
#   ['warga', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Kecelakaan', 'NOUN'],
#   ['tunggal', 'ADJ'],
#   ['itu', 'DET'],
#   ['terjadi', 'VERB'],
#   ['di', 'ADP'],
#   ['jalan', 'NOUN'],
#   ['Desa/Kecamatan', 'PROPN'],
#   ['Sumber', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Selasa', 'PROPN'],
#   ['(', 'PUNCT'],
#   ['29/12', 'PROPN'],
#   [')', 'PUNCT'],
#   ['sekitar', 'ADP'],
#   ['pukul', 'NOUN'],
#   ['16.00', 'NUM'],
#   ['.', 'PUNCT']],
#  [['Sore', 'PROPN'],
#   ['itu', 'DET'],
#   ['rombongan', 'NOUN'],
#   ['sekeluarga', 'NOUN'],
#   ['asal', 'NOUN'],
#   ['Jalan', 'PROPN'],
#   ['WR', 'PROPN'],
#   ['Supratman', 'PROPN'],
#   ['Sentono', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kelurahan', 'PROPN'],
#   ['Jati', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Mayangan', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kota', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['itu', 'DET'],
#   ['hendak', 'VERB'],
#   ['ke', 'ADP'],
#   ['arah', 'NOUN'],
#   ['kota', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Mereka', 'PRON'],
#   ['mengendarai', 'VERB'],
#   ['motor', 'NOUN'],
#   ['Honda', 'PROPN'],
#   ['Beat', 'PROPN'],
#   ['bernopol', 'PROPN'],
#   ['N', 'PROPN'],
#   ['6347', 'NUM'],
#   ['ST.', 'PUNCT'],
#   ['Yang', 'PRON'],
#   ['mengendarai', 'VERB'],
#   ['adalah', 'AUX'],
#   ['Ramadhan', 'PROPN'],
#   ['Budi', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Sementara', 'SCONJ'],
#   ['sang', 'DET'],
#   ['istri', 'NOUN'],
#   ['Dewi', 'PROPN'],
#   ['Nuke', 'PROPN'],
#   ['Mayasari', 'PROPN'],
#   [',', 'PUNCT'],
#   ['28', 'NUM'],
#   [',', 'PUNCT'],
#   ['dan', 'CCONJ'],
#   ['anaknya', 'NOUN'],
#   ['Akbar', 'PROPN'],
#   ['berusia', 'VERB'],
#   ['2', 'NUM'],
#   ['tahun', 'NOUN'],
#   [',', 'PUNCT'],
#   ['dibonceng', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Korban', 'PROPN'],
#   ['Dewi', 'PROPN'],
#   ['Nuke', 'PROPN'],
#   ['Mayasari', 'PROPN'],
#   ['sesaat', 'ADV'],
#   ['sebelum', 'ADV'],
#   ['dirujuk', 'VERB'],
#   ['ke', 'ADP'],
#   ['RSUD', 'PROPN'],
#   ['dr', 'PROPN'],
#   ['Moh', 'PROPN'],
#   ['Saleh', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['(', 'PUNCT'],
#   ['Polsek', 'PROPN'],
#   ['Sumber', 'PROPN'],
#   ['for', 'PROPN'],
#   ['Jawa', 'PROPN'],
#   ['Pos', 'PROPN'],
#   ['Radar', 'PROPN'],
#   ['Bromo', 'PROPN'],
#   [')', 'PUNCT'],
#   ['Kapolsek', 'PROPN'],
#   ['Sumber', 'PROPN'],
#   ['Iptu', 'PROPN'],
#   ['Sono', 'PROPN'],
#   ['menjelaskan', 'VERB'],
#   [',', 'PUNCT'],
#   ['saat', 'SCONJ'],
#   ['sampai', 'VERB'],
#   ['di', 'ADP'],
#   ['lokasi', 'NOUN'],
#   ['kejadian', 'NOUN'],
#   [',', 'PUNCT'],
#   ['rem', 'NOUN'],
#   ['motor', 'NOUN'],
#   ['matik', 'ADJ'],
#   ['korban', 'NOUN'],
#   ['alami', 'ADJ'],
#   ['panas', 'ADJ'],
#   ['dan', 'CCONJ'],
#   ['tak', 'PART'],
#   ['berfungsi', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Alias', 'PROPN'], ['ngeblong', 'PROPN'], ['.', 'PUNCT']],
#  [['Untuk', 'ADP'],
#   ['menghindari', 'VERB'],
#   ['tabrakan', 'NOUN'],
#   ['yang', 'PRON'],
#   ['lebih', 'ADV'],
#   ['fatal', 'ADJ'],
#   [',', 'PUNCT'],
#   ['Ramadhan', 'PROPN'],
#   ['Budi', 'PROPN'],
#   ['memilih', 'VERB'],
#   ['membelokkan', 'VERB'],
#   ['motornya', 'NOUN'],
#   ['untuk', 'ADP'],
#   ['masuk', 'VERB'],
#   ['ke', 'ADP'],
#   ['pekarangan', 'NOUN'],
#   ['warga', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Kecelakaan', 'NOUN'],
#   ['akibat', 'NOUN'],
#   ['rem', 'NOUN'],
#   ['motor', 'NOUN'],
#   ['blong', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Diduga', 'VERB'],
#   ['rem', 'NOUN'],
#   ['blong', 'NOUN'],
#   ['akibat', 'NOUN'],
#   ['panas', 'ADJ'],
#   ['setelah', 'ADP'],
#   ['dipakai', 'VERB'],
#   ['terus', 'ADV'],
#   ['menerus', 'VERB'],
#   ['saat', 'ADP'],
#   ['posisi', 'NOUN'],
#   ['jalan', 'NOUN'],
#   ['menurun', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Kemudian', 'SCONJ'],
#   ['motor', 'NOUN'],
#   ['pun', 'ADV'],
#   ['masuk', 'VERB'],
#   ['ke', 'ADP'],
#   ['pekarangan', 'NOUN'],
#   ['warga', 'NOUN'],
#   [',', 'PUNCT'],
#   ['katanya', 'NOUN'],
#   ['Iptu', 'PROPN'],
#   ['Sono', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Akibat', 'SCONJ'],
#   ['kecelakaan', 'NOUN'],
#   ['tunggal', 'ADJ'],
#   ['itu', 'DET'],
#   [',', 'PUNCT'],
#   ['korban', 'NOUN'],
#   ['Budi', 'PROPN'],
#   ['alami', 'VERB'],
#   ['luka', 'NOUN'],
#   ['patah', 'VERB'],
#   ['jari', 'NOUN'],
#   ['kelingking', 'NOUN'],
#   ['tangan', 'NOUN'],
#   ['sebelah', 'ADP'],
#   ['kanan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['luka', 'NOUN'],
#   ['robek', 'VERB'],
#   ['pada', 'ADP'],
#   ['tulang', 'NOUN'],
#   ['kering', 'ADJ'],
#   ['bawah', 'ADP'],
#   ['lutut', 'NOUN'],
#   ['kaki', 'NOUN'],
#   ['sebelah', 'NOUN'],
#   ['kanan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['dan', 'CCONJ'],
#   ['memar', 'VERB'],
#   ['di', 'ADP'],
#   ['punggung', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Sedangkan', 'SCONJ'],
#   ['korban', 'NOUN'],
#   ['Dewi', 'PROPN'],
#   ['alami', 'VERB'],
#   ['luka', 'NOUN'],
#   ['robek', 'VERB'],
#   ['kaki', 'NOUN'],
#   ['sebelah', 'ADP'],
#   ['kanan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['luka', 'NOUN'],
#   ['robek', 'VERB'],
#   ['di', 'ADP'],
#   ['pelipis', 'NOUN'],
#   ['mata', 'NOUN'],
#   ['sebelah', 'NOUN'],
#   ['kiri', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Dewi', 'PROPN'],
#   ['harus', 'ADV'],
#   ['dirujuk', 'VERB'],
#   ['ke', 'ADP'],
#   ['RSUD', 'PROPN'],
#   ['dr', 'PROPN'],
#   ['Moh', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Soleh', 'PROPN'],
#   ['Kota', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Sedangkan', 'SCONJ'],
#   ['korban', 'NOUN'],
#   ['Akbar', 'PROPN'],
#   ['anaknya', 'NOUN'],
#   [',', 'PUNCT'],
#   ['alami', 'ADJ'],
#   ['memar', 'VERB'],
#   ['di', 'ADP'],
#   ['dahi', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Semua', 'DET'],
#   ['korban', 'NOUN'],
#   ['hanya', 'ADV'],
#   ['alami', 'ADJ'],
#   ['luka', 'NOUN'],
#   ['luka', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Satu', 'NUM'],
#   ['korban', 'NOUN'],
#   ['dirujuk', 'VERB'],
#   ['ke', 'ADP'],
#   ['RSUD', 'PROPN'],
#   ['Moch', 'PROPN'],
#   ['Saleh', 'PROPN'],
#   ['Kota', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   [',', 'PUNCT'],
#   ['ujar', 'PROPN'],
#   ['Sono', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['SIDOARJO', 'PROPN'],
#   ['Arief', 'PROPN'],
#   ['Triono', 'PROPN'],
#   [',', 'PUNCT'],
#   ['34', 'NUM'],
#   [',', 'PUNCT'],
#   ['warga', 'NOUN'],
#   ['Desa', 'PROPN'],
#   ['Jaan', 'PROPN'],
#   ['RT', 'PROPN'],
#   ['04/RW', 'PUNCT'],
#   ['03', 'NUM'],
#   ['Kecamatan', 'PROPN'],
#   ['Gondang', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kabupaten', 'PROPN'],
#   ['Nganjuk', 'PROPN'],
#   [',', 'PUNCT'],
#   ['tewas', 'VERB'],
#   ['di', 'ADP'],
#   ['Jalan', 'PROPN'],
#   ['Raya', 'PROPN'],
#   ['Bypass', 'PROPN'],
#   ['Krian', 'PROPN'],
#   [',', 'PUNCT'],
#   ['KM.29', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Senin', 'PROPN'],
#   ['(', 'PUNCT'],
#   ['28/12', 'PROPN'],
#   [')', 'PUNCT'],
#   ['.', 'PUNCT']],
#  [['Korban', 'PROPN'],
#   ['tewas', 'VERB'],
#   ['setelah', 'ADP'],
#   ['terlibat', 'VERB'],
#   ['kecelakaan', 'NOUN'],
#   ['saat', 'SCONJ'],
#   ['hendak', 'ADV'],
#   ['mendahului', 'VERB'],
#   ['kendaraan', 'NOUN'],
#   ['lain', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Informasi', 'NOUN'],
#   ['yang', 'PRON'],
#   ['berhasil', 'VERB'],
#   ['dihimpun', 'VERB'],
#   [',', 'PUNCT'],
#   ['awalnya', 'ADV'],
#   ['korban', 'NOUN'],
#   ['diketahui', 'VERB'],
#   ['sedang', 'ADV'],
#   ['mengendarai', 'VERB'],
#   ['motor', 'NOUN'],
#   ['Yamaha', 'PROPN'],
#   ['Mio', 'PROPN'],
#   ['nopol', 'PROPN'],
#   ['AG', 'PROPN'],
#   ['6110', 'NUM'],
#   ['XU', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Korban', 'PROPN'],
#   ['saat', 'NOUN'],
#   ['itu', 'DET'],
#   ['melaju', 'VERB'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['barat', 'NOUN'],
#   ['ke', 'ADP'],
#   ['timur', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Korban', 'PROPN'],
#   ['berusaha', 'VERB'],
#   ['mendahului', 'VERB'],
#   ['truk', 'NOUN'],
#   ['Fuso', 'PROPN'],
#   ['nopol', 'PROPN'],
#   ['N', 'PROPN'],
#   ['8332', 'NUM'],
#   ['UW', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Truk', 'PROPN'],
#   ['Fuso', 'PROPN'],
#   ['itu', 'DET'],
#   ['berjalan', 'VERB'],
#   ['di', 'ADP'],
#   ['depan', 'NOUN'],
#   ['korban', 'NOUN'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['yang', 'PRON'],
#   ['sama', 'ADJ'],
#   ['dan', 'CCONJ'],
#   ['berusaha', 'VERB'],
#   ['didahului', 'VERB'],
#   ['oleh', 'ADP'],
#   ['korban', 'NOUN'],
#   [',', 'PUNCT'],
#   ['kata', 'NOUN'],
#   ['Kanit', 'PROPN'],
#   ['Laka', 'PROPN'],
#   ['Lantas', 'PROPN'],
#   ['Polresta', 'PROPN'],
#   ['Sidoarjo', 'PROPN'],
#   ['AKP', 'PROPN'],
#   ['Sugeng', 'PROPN'],
#   ['Sulistyono', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Namun', 'SCONJ'],
#   ['saat', 'ADV'],
#   ['mencoba', 'VERB'],
#   ['mendahului', 'VERB'],
#   ['tersebut', 'DET'],
#   ['korban', 'NOUN'],
#   ['menabrak', 'VERB'],
#   ['media', 'NOUN'],
#   ['jalan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Akibatnya', 'SCONJ'],
#   ['motor', 'NOUN'],
#   ['terjatuh', 'VERB'],
#   ['ke', 'ADP'],
#   ['sebelah', 'NOUN'],
#   ['kanan', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['korban', 'NOUN'],
#   ['terpental', 'VERB'],
#   ['ke', 'ADP'],
#   ['sebelah', 'NOUN'],
#   ['kiri', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Korban', 'PROPN'],
#   ['terlindas', 'VERB'],
#   ['roda', 'NOUN'],
#   ['belakang', 'ADJ'],
#   ['sebelah', 'ADP'],
#   ['kanan', 'NOUN'],
#   ['truk', 'NOUN'],
#   ['Fuso', 'PROPN'],
#   ['tersebut', 'DET'],
#   ['.', 'PUNCT']],
#  [['Di', 'ADP'],
#   ['tempat', 'NOUN'],
#   ['lain', 'ADJ'],
#   [',', 'PUNCT'],
#   ['Suhariyono', 'PROPN'],
#   [',', 'PUNCT'],
#   ['62', 'NUM'],
#   [',', 'PUNCT'],
#   ['warga', 'NOUN'],
#   ['Dusun', 'PROPN'],
#   ['Gresikan', 'PROPN'],
#   ['Kelurahan', 'PROPN'],
#   ['Krian', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Krian', 'PROPN'],
#   ['tewas', 'VERB'],
#   ['di', 'ADP'],
#   ['Jalan', 'PROPN'],
#   ['Raya', 'PROPN'],
#   ['Ki', 'PROPN'],
#   ['Hajar', 'PROPN'],
#   ['Dewantara', 'PROPN'],
#   ['Krian', 'PROPN'],
#   [',', 'PUNCT'],
#   ['sekitar', 'ADP'],
#   ['pukul', 'NOUN'],
#   ['12.10', 'NUM'],
#   ['.', 'PUNCT']],
#  [['Awalnya', 'ADV'],
#   ['korban', 'NOUN'],
#   ['sedang', 'ADV'],
#   ['berjalan', 'VERB'],
#   ['mengendarai', 'VERB'],
#   ['motor', 'NOUN'],
#   ['Honda', 'PROPN'],
#   ['Vario', 'PROPN'],
#   ['nopol', 'PROPN'],
#   ['W', 'PROPN'],
#   ['2444', 'NUM'],
#   ['YW', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Korban', 'PROPN'],
#   ['melaju', 'VERB'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['selatan', 'NOUN'],
#   ['ke', 'ADP'],
#   ['utara', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Namun', 'SCONJ'],
#   ['terserempet', 'VERB'],
#   ['kendaraan', 'NOUN'],
#   ['dump', 'NOUN'],
#   ['truk', 'NOUN'],
#   ['Tronton', 'PROPN'],
#   ['L', 'PROPN'],
#   ['8477', 'NUM'],
#   ['UO', 'PROPN'],
#   ['yang', 'PRON'],
#   ['datang', 'VERB'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['yang', 'PRON'],
#   ['sama', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Akibatnya', 'SCONJ'],
#   ['korban', 'NOUN'],
#   ['tewas', 'VERB'],
#   ['di', 'ADP'],
#   ['lokasi', 'NOUN'],
#   ['kejadian', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['dievakuasi', 'VERB'],
#   ['petugas', 'NOUN'],
#   ['ke', 'ADP'],
#   ['RSU', 'PROPN'],
#   ['Anwar', 'PROPN'],
#   ['Medika', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Dump', 'PROPN'],
#   ['truk', 'NOUN'],
#   ['tronton', 'NOUN'],
#   ['diketahui', 'VERB'],
#   ['dikemudikan', 'VERB'],
#   ['oleh', 'ADP'],
#   ['Riyanto', 'PROPN'],
#   [',', 'PUNCT'],
#   ['47', 'NUM'],
#   [',', 'PUNCT'],
#   ['warga', 'NOUN'],
#   ['Desa', 'PROPN'],
#   ['Widang', 'PROPN'],
#   ['RT', 'PROPN'],
#   ['07/RW', 'PUNCT'],
#   ['05', 'NUM'],
#   ['Widang', 'PROPN'],
#   ['Kabupaten', 'PROPN'],
#   ['Tuban', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Sejumlah', 'DET'],
#   ['barang', 'NOUN'],
#   ['bukti', 'NOUN'],
#   ['seperti', 'ADP'],
#   ['kendaraan', 'NOUN'],
#   ['korban', 'NOUN'],
#   ['kami', 'PRON'],
#   ['amankan', 'VERB'],
#   ['ke', 'ADP'],
#   ['Mapolsek', 'PROPN'],
#   ['Krian', 'PROPN'],
#   [',', 'PUNCT'],
#   ['kata', 'NOUN'],
#   ['petugas', 'NOUN'],
#   ['lantas', 'ADJ'],
#   ['Polsek', 'PROPN'],
#   ['Krian', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Aiptu', 'PROPN'],
#   ['Bachtiar', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['jatimnow.com', 'PROPN'],
#   ['-', 'PUNCT'],
#   ['Arief', 'PROPN'],
#   ['(', 'PUNCT'],
#   ['34', 'NUM'],
#   [')', 'PUNCT'],
#   ['pemotor', 'NOUN'],
#   ['asal', 'NOUN'],
#   ['Desa', 'PROPN'],
#   ['Jaan', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Gondang', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kabupaten', 'PROPN'],
#   ['Nganjuk', 'PROPN'],
#   ['tewas', 'VERB'],
#   ['di', 'ADP'],
#   ['Jalan', 'PROPN'],
#   ['Raya', 'PROPN'],
#   ['Bypass', 'PROPN'],
#   ['Kecamatan', 'PROPN'],
#   ['Krian', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kabupaten', 'PROPN'],
#   ['Sidoarjo', 'PROPN'],
#   ['setelah', 'ADP'],
#   ['tertabrak', 'VERB'],
#   ['truk', 'NOUN'],
#   ['Fuso', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Kanit', 'PROPN'],
#   ['Laka', 'PROPN'],
#   ['Satlantas', 'PROPN'],
#   ['Polresta', 'PROPN'],
#   ['Sidoarjo', 'PROPN'],
#   ['AKP', 'PROPN'],
#   ['Sugeng', 'PROPN'],
#   ['Sulistiyono', 'PROPN'],
#   ['mengatakan', 'VERB'],
#   [',', 'PUNCT'],
#   ['korban', 'NOUN'],
#   ['mengendarai', 'VERB'],
#   ['motor', 'NOUN'],
#   ['Honda', 'PROPN'],
# ...
#   ['tanggal', 'NOUN'],
#   [',', 'PUNCT'],
#   ['bibir', 'NOUN'],
#   ['robek', 'ADJ'],
#   [',', 'PUNCT'],
#   ['dagu', 'NOUN'],
#   ['lecet', 'ADJ'],
#   [',', 'PUNCT'],
#   ['tangan', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['kaki', 'NOUN'],
#   ['lecet', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['``', 'PUNCT'],
#   ['Pengayuh', 'NOUN'],
#   ['sepeda', 'NOUN'],
#   ['mengalami', 'VERB'],
#   ['luka', 'NOUN'],
#   ['pada', 'ADP'],
#   ['kepala', 'NOUN'],
#   ['kanan', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['meninggal', 'VERB'],
#   ['dunia', 'NOUN'],
#   ['di', 'ADP'],
#   ['lokasi', 'NOUN'],
#   ['kejadian', 'NOUN'],
#   [',', 'PUNCT'],
#   ["''", 'NOUN'],
#   ['jelas', 'ADJ'],
#   ['Imammudin', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Setelah', 'ADP'],
#   ['mendapat', 'VERB'],
#   ['laporan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['Unit', 'PROPN'],
#   ['Laka', 'PROPN'],
#   ['Satlantas', 'PROPN'],
#   ['Polres', 'PROPN'],
#   ['Ponorogo', 'PROPN'],
#   ['menuju', 'VERB'],
#   ['lokasi', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['langsung', 'ADV'],
#   ['mengevakuasi', 'VERB'],
#   ['korban', 'NOUN'],
#   ['luka', 'ADJ'],
#   ['maupun', 'CCONJ'],
#   ['meninggal', 'VERB'],
#   ['untuk', 'ADP'],
#   ['dibawa', 'VERB'],
#   ['ke', 'ADP'],
#   ['Rumah', 'PROPN'],
#   ['Sakit', 'PROPN'],
#   ['Muhammadiyah', 'PROPN'],
#   ['setempat', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['GRESIK', 'PROPN'],
#   ['Kecelakaan', 'NOUN'],
#   ['tragis', 'NOUN'],
#   ['menimpa', 'VERB'],
#   ['Soetjipto', 'PROPN'],
#   ['warga', 'NOUN'],
#   ['Jjalan', 'PUNCT'],
#   ['Veteran', 'PROPN'],
#   ['9-D/7', 'PROPN'],
#   ['RT', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['3', 'NUM'], ['RW', 'PROPN'], ['.', 'PUNCT']],
#  [['2', 'NUM'],
#   ['Kelurahan', 'PROPN'],
#   ['Singosari', 'PROPN'],
#   ['Kecamatan', 'PROPN'],
#   ['Kebomas', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Pria', 'PROPN'],
#   ['60', 'NUM'],
#   ['tahun', 'NOUN'],
#   ['itu', 'DET'],
#   ['tewas', 'VERB'],
#   ['dengan', 'ADP'],
#   ['luka', 'NOUN'],
#   ['dikepala', 'VERB'],
#   ['saat', 'ADP'],
#   ['tengah', 'NOUN'],
#   ['mengendarai', 'VERB'],
#   ['kendaraan', 'NOUN'],
#   ['listrik', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Informasi', 'NOUN'],
#   ['di', 'ADP'],
#   ['lapangan', 'NOUN'],
#   ['menyebut', 'VERB'],
#   [',', 'PUNCT'],
#   ['kecelakaan', 'NOUN'],
#   ['terjadi', 'VERB'],
#   ['lada', 'NOUN'],
#   ['hari', 'NOUN'],
#   ['Minggu', 'PROPN'],
#   ['(', 'PUNCT'],
#   ['13/12', 'PROPN'],
#   [')', 'PUNCT'],
#   ['pukul', 'NOUN'],
#   ['06.00', 'NUM'],
#   ['WIB', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Korban', 'PROPN'],
#   ['yang', 'PRON'],
#   ['saat', 'NOUN'],
#   ['itu', 'DET'],
#   ['hendak', 'ADV'],
#   ['pulang', 'VERB'],
#   ['ke', 'ADP'],
#   ['rumahnya', 'NOUN'],
#   ['melintasi', 'VERB'],
#   ['jalan', 'NOUN'],
#   ['Veteran', 'PROPN'],
#   ['Gresik', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Diduga', 'PROPN'],
#   ['saat', 'SCONJ'],
#   ['hendak', 'ADV'],
#   ['berpindah', 'VERB'],
#   ['haluan', 'NOUN'],
#   ['korban', 'NOUN'],
#   ['tidak', 'PART'],
#   ['memperhatikan', 'VERB'],
#   ['arah', 'NOUN'],
#   ['belakang', 'ADJ'],
#   ['.', 'PUNCT']],
#  [['Nahas', 'PROPN'],
#   ['pada', 'ADP'],
#   ['waktu', 'NOUN'],
#   ['yang', 'PRON'],
#   ['bersamaan', 'VERB'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['yang', 'PRON'],
#   ['sama', 'ADJ'],
#   ['melaju', 'VERB'],
#   ['kencang', 'VERB'],
#   ['motor', 'NOUN'],
#   ['Honda', 'PROPN'],
#   ['CRF', 'PROPN'],
#   ['Nomer', 'PROPN'],
#   ['polisi', 'PROPN'],
#   ['W', 'PROPN'],
#   ['6917', 'NUM'],
#   ['CY', 'PROPN'],
#   ['yang', 'PRON'],
#   ['dikendarai', 'VERB'],
#   ['Sugiarta', 'PROPN'],
#   ['Rukmana', 'PROPN'],
#   ['warga', 'NOUN'],
#   ['Jalan', 'PROPN'],
#   ['Faqih', 'PROPN'],
#   ['Usman', 'PROPN'],
#   ['14/8', 'PROPN'],
#   ['Kelurahan', 'PROPN'],
#   ['Kemuteran', 'PROPN'],
#   ['Kecamatan', 'PROPN'],
#   ['Gresik', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Jarak', 'PROPN'],
#   ['yang', 'PRON'],
#   ['terlalu', 'ADV'],
#   ['dekat', 'ADJ'],
#   ['akibatnya', 'SCONJ'],
#   ['benturan', 'NOUN'],
#   ['tdak', 'VERB'],
#   ['bisa', 'ADV'],
#   ['dihindari', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Kedua', 'NUM'],
#   ['korban', 'NOUN'],
#   ['jatuh', 'VERB'],
#   ['tersungkur', 'VERB'],
#   ['dan', 'CCONJ'],
#   ['membentur', 'VERB'],
#   ['aspal', 'NOUN'],
#   [',', 'PUNCT'],
#   ['kata', 'NOUN'],
#   ['Kanit', 'PROPN'],
#   ['Laka', 'PROPN'],
#   ['Lantas', 'PROPN'],
#   ['Satlantas', 'PROPN'],
#   ['Polres', 'PROPN'],
#   ['Gresik', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Ipda', 'PROPN'],
#   ['Yossy', 'PROPN'],
#   ['Syahputra', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Celakanya', 'SCONJ'],
#   ['korban', 'NOUN'],
#   ['pengendara', 'NOUN'],
#   ['sepeda', 'NOUN'],
#   ['listrik', 'NOUN'],
#   ['tidak', 'PART'],
#   ['memakai', 'VERB'],
#   ['peralatn', 'ADP'],
#   ['safety', 'NOUN'],
#   ['sehingga', 'SCONJ'],
#   ['kepalanya', 'NOUN'],
#   ['membentur', 'VERB'],
#   ['aspal', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Tidak', 'PART'],
#   ['berselang', 'ADV'],
#   ['lama', 'ADJ'],
#   ['korban', 'NOUN'],
#   ['tewas', 'VERB'],
#   ['dilokasi', 'NOUN'],
#   ['kejadian', 'NOUN'],
#   ['sementara', 'SCONJ'],
#   ['pengendara', 'NOUN'],
#   ['motor', 'NOUN'],
#   ['trail', 'NOUN'],
#   ['dilarikan', 'VERB'],
#   ['ke', 'ADP'],
#   ['rumah', 'NOUN'],
#   ['sakit', 'NOUN'],
#   ['akibat', 'NOUN'],
#   ['luka', 'NOUN'],
#   ['yang', 'PRON'],
#   ['serius', 'ADJ'],
#   ['dibagian', 'VERB'],
#   ['kaki', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['tangan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Kami', 'PRON'],
#   ['mengimbau', 'VERB'],
#   ['kepada', 'ADP'],
#   ['seluruh', 'DET'],
#   ['pengguna', 'NOUN'],
#   ['jalan', 'NOUN'],
#   ['agar', 'SCONJ'],
#   ['tetal', 'ADV'],
#   ['berhati-hati', 'VERB'],
#   ['saat', 'NOUN'],
#   ['berkendara', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Selalu', 'ADV'],
#   ['penuhi', 'VERB'],
#   ['perlengkapan', 'NOUN'],
#   ['berkendara', 'NOUN'],
#   ['utamanya', 'ADJ'],
#   ['helm', 'NOUN'],
#   ['untuk', 'ADP'],
#   ['menghindari', 'VERB'],
#   ['luka', 'NOUN'],
#   ['yang', 'PRON'],
#   ['lebih', 'ADV'],
#   ['parah', 'ADJ'],
#   ['saat', 'SCONJ'],
#   ['terjadi', 'VERB'],
#   ['kecelakaan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['pungkasnya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['MALANG', 'PROPN'],
#   ['KOTA', 'PROPN'],
#   ['Bocah', 'PROPN'],
#   ['berusia', 'VERB'],
#   ['12', 'NUM'],
#   ['tahun', 'NOUN'],
#   ['bernama', 'VERB'],
#   ['Kristian', 'PROPN'],
#   ['Verrel', 'PROPN'],
#   ['Andrianto', 'PROPN'],
#   ['tewas', 'VERB'],
#   ['tertabrak', 'VERB'],
#   ['truk', 'NOUN'],
#   ['ketika', 'SCONJ'],
#   ['berusaha', 'VERB'],
#   ['menyalip', 'VERB'],
#   ['sepeda', 'NOUN'],
#   ['motor', 'NOUN'],
#   ['Honda', 'PROPN'],
#   ['Supra', 'PROPN'],
#   ['di', 'ADP'],
#   ['depannya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Kecelakaan', 'NOUN'],
#   ['terjadi', 'VERB'],
#   ['pada', 'ADP'],
#   ['Senin', 'PROPN'],
#   ['(', 'PUNCT'],
#   ['14/12', 'PROPN'],
#   [')', 'PUNCT'],
#   ['pukul', 'NOUN'],
#   ['15.00', 'NUM'],
#   ['di', 'ADP'],
#   ['Jalan', 'PROPN'],
#   ['Raya', 'PROPN'],
#   ['Dusun', 'PROPN'],
#   ['Cerme', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Desa', 'PROPN'],
#   ['Kendalpayak', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Pakisaji', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Saat', 'SCONJ'],
#   ['kejadian', 'NOUN'],
#   ['kondisi', 'NOUN'],
#   ['jalanan', 'NOUN'],
#   ['licin', 'ADJ'],
#   ['seusai', 'ADP'],
#   ['hujan', 'NOUN'],
#   [',', 'PUNCT'],
#   ['motor', 'NOUN'],
#   ['Honda', 'PROPN'],
#   ['Grand', 'PROPN'],
#   ['dengan', 'ADP'],
#   ['nomor', 'NOUN'],
#   ['polisi', 'NOUN'],
#   ['(', 'PUNCT'],
#   ['nopol', 'PROPN'],
#   [')', 'PUNCT'],
#   ['N', 'PROPN'],
#   ['6284', 'NUM'],
#   ['FW', 'NOUN'],
#   ['yang', 'PRON'],
#   ['dikendarai', 'VERB'],
#   ['Verrel', 'PROPN'],
#   [',', 'PUNCT'],
#   ['melaju', 'VERB'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['barat', 'NOUN'],
#   ['dengan', 'ADP'],
#   ['kecepatan', 'NOUN'],
#   ['sedang', 'ADV'],
#   ['.', 'PUNCT']],
#  [['Sesampainya', 'VERB'],
#   ['di', 'ADP'],
#   ['Jalan', 'PROPN'],
#   ['Raya', 'PROPN'],
#   ['Dusun', 'PROPN'],
#   ['Cerme', 'PROPN'],
#   [',', 'PUNCT'],
#   ['korban', 'NOUN'],
#   ['berusaha', 'VERB'],
#   ['mendahului', 'VERB'],
#   ['Honda', 'PROPN'],
#   ['Supra', 'PROPN'],
#   ['X125', 'PROPN'],
#   ['dengan', 'ADP'],
#   ['nopol', 'PROPN'],
#   ['N', 'PROPN'],
#   ['4516', 'NUM'],
#   ['EW', 'PROPN'],
#   ['yang', 'PRON'],
#   ['dikendarai', 'VERB'],
#   ['Syharul', 'ADP'],
#   ['Musafak', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Namun', 'SCONJ'],
#   ['nahas', 'PROPN'],
#   [',', 'PUNCT'],
#   ['karena', 'SCONJ'],
#   ['belum', 'ADV'],
#   ['memahami', 'VERB'],
#   ['benar', 'ADJ'],
#   ['haluan', 'NOUN'],
#   ['berkendara', 'VERB'],
#   ['korban', 'NOUN'],
#   ['menyerempet', 'VERB'],
#   ['motor', 'NOUN'],
#   ['di', 'ADP'],
#   ['depannya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Motor', 'PROPN'],
#   ['Syahrul', 'PROPN'],
#   ['yang', 'PRON'],
#   ['melaju', 'VERB'],
#   ['searah', 'ADJ'],
#   ['di', 'ADP'],
#   ['depannya', 'NOUN'],
#   [',', 'PUNCT'],
#   ['rupanya', 'ADV'],
#   ['kurang', 'ADV'],
#   ['berhaluan', 'VERB'],
#   ['kekanan', 'NOUN'],
#   ['sehingga', 'SCONJ'],
#   ['terjadi', 'VERB'],
#   ['serempetan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Kemudian', 'ADP'],
#   ['kendaraan', 'NOUN'],
#   ['Honda', 'PROPN'],
#   ['Grand', 'PROPN'],
#   ['yang', 'PRON'],
#   ['ditumpangi', 'VERB'],
#   ['Verrel', 'PROPN'],
#   ['terjatuh', 'VERB'],
#   ['kekanan', 'NOUN'],
#   ['bersamaan', 'VERB'],
#   ['itu', 'DET'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['berlawanan', 'ADJ'],
#   ['ada', 'VERB'],
#   ['kendaraan', 'NOUN'],
#   ['truk', 'NOUN'],
#   ['box', 'NOUN'],
#   ['Mitsubhisi', 'ADP'],
#   ['nomor', 'NOUN'],
#   ['polisi', 'NOUN'],
#   ['N', 'PROPN'],
#   ['9082', 'NUM'],
#   ['C', 'PROPN'],
#   ['yang', 'PRON'],
#   ['dikemudikan', 'VERB'],
#   ['Hilarius', 'PROPN'],
#   ['Darman', 'PROPN'],
#   [',', 'PUNCT'],
#   ['ungkap', 'PROPN'],
#   ['Kanit', 'PROPN'],
#   ['Laka', 'PROPN'],
#   ['Lantas', 'PROPN'],
#   ['Polres', 'PROPN'],
#   ['Malang', 'PROPN'],
#   ['Ipda', 'PROPN'],
#   ['Agus', 'PROPN'],
#   ['Yulianto', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Karena', 'SCONJ'],
#   ['jarak', 'NOUN'],
#   ['sudah', 'ADV'],
#   ['dekat', 'ADJ'],
#   [',', 'PUNCT'],
#   ['Agus', 'PROPN'],
#   ['melanjutkan', 'VERB'],
#   [',', 'PUNCT'],
#   ['terjadi', 'VERB'],
#   ['tabrak', 'NOUN'],
#   ['depan', 'ADJ'],
#   ['oleh', 'ADP'],
#   ['truk', 'NOUN'],
#   ['dengan', 'ADP'],
#   ['kendaraan', 'NOUN'],
#   ['Honda', 'PROPN'],
#   ['Grand', 'PROPN'],
#   ['yang', 'PRON'],
#   ['berakibat', 'VERB'],
#   ['korban', 'NOUN'],
#   ['mengalami', 'VERB'],
#   ['luka', 'NOUN'],
#   ['benturan', 'ADJ'],
#   ['pada', 'ADP'],
#   ['kepala', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['meninggal', 'VERB'],
#   ['dunia', 'NOUN'],
#   ['di', 'ADP'],
#   ['TKP', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Selanjutnya', 'ADV'],
#   [',', 'PUNCT'],
#   ['korban', 'NOUN'],
#   ['dibawa', 'VERB'],
#   ['ke', 'ADP'],
#   ['RSSA', 'PROPN'],
#   ['(', 'PUNCT'],
#   ['RS', 'PROPN'],
#   ['Saiful', 'PROPN'],
#   ['Anwar', 'PROPN'],
#   [')', 'PUNCT'],
#   [',', 'PUNCT'],
#   ['dan', 'CCONJ'],
#   ['kami', 'PRON'],
#   ['mengamankan', 'VERB'],
#   ['barang', 'NOUN'],
#   ['bukti', 'NOUN'],
#   ['kendaraan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Kerugian', 'NOUN'],
#   ['materil', 'ADJ'],
#   ['tidak', 'PART'],
#   ['banyak', 'ADV'],
#   [',', 'PUNCT'],
#   ['hanya', 'ADV'],
#   ['sekitar', 'ADP'],
#   ['Rp', 'PROPN'],
#   ['200.000', 'NUM'],
#   ['saja', 'ADV'],
#   [',', 'PUNCT'],
#   ['jelas', 'ADJ'],
#   ['Agus', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['PAJARAKAN', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Radar', 'PROPN'],
#   ['Bromo', 'PROPN'],
#   ['Nasib', 'PROPN'],
#   ['nahas', 'PROPN'],
#   ['dialami', 'VERB'],
#   ['Jamil', 'PROPN'],
#   [',', 'PUNCT'],
#   ['51', 'NUM'],
#   ['.', 'PUNCT']],
#  [['Warga', 'PROPN'],
#   ['Desa', 'PROPN'],
#   ['Satreyan', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Maron', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kabupaten', 'PROPN'],
#   ['Probolinggo', 'PROPN'],
#   ['tersebut', 'DET'],
#   ['tewas', 'VERB'],
#   ['setelah', 'ADP'],
#   ['tertabrak', 'VERB'],
#   ['pikap', 'NOUN'],
#   ['saat', 'SCONJ'],
#   ['sedang', 'ADV'],
#   ['melayani', 'VERB'],
#   ['pembeli', 'NOUN'],
#   ['di', 'ADP'],
#   ['pinggir', 'NOUN'],
#   ['jalan', 'NOUN'],
#   ['di', 'ADP'],
#   ['Desa', 'PROPN'],
#   ['Pajarakan', 'PROPN'],
#   ['Kulon', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Pajarakan', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Informasi', 'NOUN'],
#   ['yang', 'PRON'],
#   ['dihimpun', 'VERB'],
#   ['Jawa', 'PROPN'],
#   ['Pos', 'PROPN'],
#   ['Radar', 'PROPN'],
#   ['Bromo', 'PROPN'],
#   [',', 'PUNCT'],
#   ['kecelakaan', 'NOUN'],
#   ['terjadi', 'VERB'],
#   ['kemarin', 'NOUN'],
#   ['(', 'PUNCT'],
#   ['14/12', 'PROPN'],
#   [')', 'PUNCT'],
#   ['sekitar', 'ADP'],
#   ['pukul', 'NOUN'],
#   ['04.30', 'NUM'],
#   ['.', 'PUNCT']],
#  [['Bermula', 'VERB'],
#   ['ketika', 'SCONJ'],
#   ['korban', 'NOUN'],
#   ['yang', 'PRON'],
#   ['mengendarai', 'VERB'],
#   ['motor', 'NOUN'],
#   ['bernopol', 'PROPN'],
#   ['N', 'PROPN'],
#   ['4469', 'NUM'],
#   ['P', 'PROPN'],
#   [',', 'PUNCT'],
#   ['tengah', 'NOUN'],
#   ['berhenti', 'VERB'],
#   ['di', 'ADP'],
#   ['bahu', 'NOUN'],
#   ['jalan', 'NOUN'],
#   ['sisi', 'NOUN'],
#   ['timur', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Dia', 'PRON'],
#   ['berhenti', 'VERB'],
#   ['karena', 'SCONJ'],
#   ['melayani', 'VERB'],
#   ['pembeli', 'NOUN'],
#   ['sayur', 'NOUN'],
#   ['mayur', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['ikan', 'NOUN'],
#   ['yang', 'PRON'],
#   ['dijualnya', 'VERB'],
#   ['.', 'PUNCT']],
#  [['Korban', 'PROPN'],
#   ['diketahui', 'VERB'],
#   ['seorang', 'DET'],
#   ['welijo', 'NOUN'],
#   ['atau', 'CCONJ'],
#   ['penjual', 'NOUN'],
#   ['sayur', 'NOUN'],
#   ['yang', 'PRON'],
#   ['sudah', 'ADV'],
#   ['biasa', 'ADJ'],
#   ['berjualan', 'VERB'],
#   ['di', 'ADP'],
#   ['lokasi', 'NOUN'],
#   ['tersebut', 'DET'],
#   ['.', 'PUNCT']],
#  [['Saat', 'NOUN'],
#   ['itu', 'DET'],
#   [',', 'PUNCT'],
#   ['dari', 'ADP'],
#   ['arah', 'NOUN'],
#   ['selatan', 'NOUN'],
#   ['ke', 'ADP'],
#   ['utara', 'NOUN'],
#   ['melaju', 'VERB'],
#   ['mobil', 'NOUN'],
#   ['pikap', 'NOUN'],
#   ['bernopol', 'PROPN'],
#   ['P', 'PROPN'],
#   ['9095', 'NUM'],
#   ['VC', 'PROPN'],
#   ['yang', 'PRON'],
#   ['dikemudikan', 'VERB'],
#   ['Humaidi', 'PROPN'],
#   [',', 'PUNCT'],
#   ['23', 'NUM'],
#   [',', 'PUNCT'],
#   ['warga', 'NOUN'],
#   ['Desa', 'PROPN'],
#   ['Sumberrejo', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Kecamatan', 'PROPN'],
#   ['Paiton', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Penumpangnya', 'NOUN'],
#   ['ada', 'VERB'],
#   ['tiga', 'NUM'],
#   ['orang', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Yakni', 'SCONJ'],
#   ['Mohamad', 'PROPN'],
#   ['Sholehuddin', 'PROPN'],
#   [',', 'PUNCT'],
#   ['Babun', 'PROPN'],
#   ['Naim', 'PROPN'],
#   ['dan', 'CCONJ'],
#   ['Miftahussurur', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Sesampainya', 'VERB'],
#   ['di', 'ADP'],
#   ['lokasi', 'NOUN'],
#   [',', 'PUNCT'],
#   ['pikap', 'NOUN'],
#   ['diduga', 'ADJ'],
#   ['kurang', 'ADV'],
#   ['konsentrasi', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Entah', 'ADV'],
#   ['mengapa', 'ADV'],
#   ['pikap', 'NOUN'],
#   ['tersebut', 'DET'],
#   ['oleng', 'NOUN'],
#   ['ke', 'ADP'],
#   ['kanan', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['langsung', 'ADV'],
#   ['menabrak', 'VERB'],
#   ['korban', 'NOUN'],
#   ['beserta', 'VERB'],
#   ['motornya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Akibatnya', 'SCONJ'],
#   [',', 'PUNCT'],
#   ['korban', 'NOUN'],
#   ['tak', 'PART'],
#   ['sadarkan', 'VERB'],
#   ['diri', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['langsung', 'ADV'],
#   ['tewas', 'VERB'],
#   ['di', 'ADP'],
#   ['lokasi', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['DIAMANKAN', 'VERB'],
#   [':', 'PUNCT'],
#   ['Pikap', 'PROPN'],
#   ['yang', 'PRON'],
#   ['menabrak', 'VERB'],
#   ['Jamil', 'PROPN'],
#   ['hingga', 'ADP'],
#   ['tewas', 'VERB'],
#   ['di', 'ADP'],
#   ['TKP', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Hingga', 'ADP'],
#   ['kemudian', 'ADV'],
#   [',', 'PUNCT'],
#   ['tidak', 'PART'],
#   ['bisa', 'ADV'],
#   ['menguasai', 'VERB'],
#   ['kendaraannya', 'NOUN'],
#   ['dan', 'CCONJ'],
#   ['oleng', 'NOUN'],
#   ['ke', 'ADP'],
#   ['kanan', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Dugaan', 'NOUN'],
#   ['sementara', 'SCONJ'],
#   ['sopir', 'NOUN'],
#   ['pikap', 'NOUN'],
#   ['kehilangan', 'VERB'],
#   ['konsentrasi', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Yang', 'PRON'],
#   ['kemudian', 'ADV'],
#   ['mengakibatkan', 'VERB'],
#   ['hilangnya', 'NOUN'],
#   ['kendali', 'NOUN'],
#   ['terhadap', 'ADP'],
#   ['kendaraannya', 'NOUN'],
#   [',', 'PUNCT'],
#   ['katanya', 'NOUN'],
#   ['.', 'PUNCT']],
#  [['Usai', 'NOUN'],
#   ['kejadian', 'NOUN'],
#   [',', 'PUNCT'],
#   ['korban', 'NOUN'],
#   ['langsung', 'ADJ'],
#   ['dibawa', 'VERB'],
#   ['ke', 'ADP'],
#   ['kamar', 'NOUN'],
#   ['mayat', 'NOUN'],
#   ['RSUD', 'PROPN'],
#   ['Waluyo', 'PROPN'],
#   ['Jati', 'PROPN'],
#   ['.', 'PUNCT']],
#  [['Polisi', 'PROPN'],
#   [',', 'PUNCT'],
#   ['juga', 'ADV'],
#   ['melakukan', 'VERB'],
#   ['olah', 'NOUN'],
#   ['tempat', 'NOUN'],
#   ['kejadian', 'NOUN'],
#   ['perkara', 'NOUN'],
#   ['di', 'ADP'],
#   ['lokasi', 'NOUN'],
#   ['.', 'PUNCT']],
#  ...]

# %%
# Transform Datasets
sentences_ = addCharInformation_new(deepcopy(array_))
set_ = padding(createMatrices_new(sentences_, word2Idx, case2Idx, char2Idx, pos2Idx))
batch_idx_, batch_, batch_len_ = createBatches_new(set_)

# %%
# Predict Token
pred_ = tag_dataset_new(batch_,model)
# Out:
# Tagging token..
# 21007/21007 [==============================] - 1242s 59ms/step
# Done.

# %%
# Get the Predictions
tag_ = get_prediction_ner_new(array_,pred_,batch_idx_,idx2Label)
prediction_ner_df_ = prediction_ner_to_df_new(tag_,data_)
out = deepcopy(data_)
out['pred_ner']=prediction_ner_df_['pred_ner']
out
# Out:
#        article sentence      word    pos   pred_ner
# 1         3659        0  SIDOARJO  PROPN          O
# 2         3659        0    Sebuah    DET          O
# 3         3659        0      truk   NOUN  B-VEHICLE
# 4         3659        0    Toyota  PROPN  I-VEHICLE
# 5         3659        0      Dyna  PROPN  I-VEHICLE
# ...        ...      ...       ...    ...        ...
# 328869     508    21006    kepala   NOUN          O
# 328870     508    21006    pusing   NOUN          O
# 328871     508    21006   kondisi   NOUN          O
# 328872     508    21006     sadar    ADJ          O
# 328873     508    21006         .  PUNCT          O
#
# [327627 rows x 5 columns]

# %%
out[:60]
# Out:
#    article sentence       word    pos   pred_ner
# 1     3659        0   SIDOARJO  PROPN          O
# 2     3659        0     Sebuah    DET          O
# 3     3659        0       truk   NOUN  B-VEHICLE
# 4     3659        0     Toyota  PROPN  I-VEHICLE
# 5     3659        0       Dyna  PROPN  I-VEHICLE
# 6     3659        0      nopol  PROPN          O
# 7     3659        0          L  PROPN    B-PLATE
# 8     3659        0       8894    NUM    I-PLATE
# 9     3659        0         US  PROPN    I-PLATE
# 10    3659        0       yang   PRON          O
# 11    3659        0     melaju   VERB          O
# 12    3659        0         di    ADP          O
# 13    3659        0      Jalan  PROPN      B-LOC
# 14    3659        0       Raya  PROPN      I-LOC
# 15    3659        0     Seduri  PROPN      I-LOC
# 16    3659        0  terguling  PROPN          O
# 17    3659        0          ,  PUNCT          O
# 18    3659        0     Selasa  PROPN     B-DATE
# 19    3659        0          (  PUNCT          O
# 20    3659        0      29/12  PROPN     B-DATE
# 21    3659        0          )  PUNCT          O
# 22    3659        0      malam   NOUN     B-TIME
# 23    3659        0          .  PUNCT          O
# 24    3659        1        Hal   NOUN          O
# 25    3659        1        itu    DET          O
# 26    3659        1    membuat   VERB          O
# 27    3659        1      sopir   NOUN          O
# 28    3659        1      harus    ADV          O
# 29    3659        1  dilarikan   VERB          O
# 30    3659        1         ke    ADP          O
# 31    3659        1      rumah   NOUN          O
# 32    3659        1      sakit   NOUN          O
# 33    3659        1      untuk    ADP          O
# 34    3659        1  menjalani   VERB          O
# 35    3659        1  perawatan   NOUN          O
# 36    3659        1   lantaran  SCONJ          O
# 37    3659        1  mengalami   VERB          O
# 38    3659        1  luka-luka   NOUN          O
# 39    3659        1          .  PUNCT          O
# 40    3659        2  Informasi   NOUN          O
# 41    3659        2       yang   PRON          O
# 42    3659        2   berhasil   VERB          O
# 43    3659        2   dihimpun   VERB          O
# 44    3659        2          ,  PUNCT          O
# 45    3659        2    awalnya    ADV          O
# 46    3659        2       truk   NOUN  B-VEHICLE
# 47    3659        2     melaju   VERB          O
# 48    3659        2       dari    ADP          O
# 49    3659        2       arah   NOUN          O
# 50    3659        2      timur   NOUN          O
# 51    3659        2         ke    ADP          O
# 52    3659        2      barat   NOUN          O
# 53    3659        2          .  PUNCT          O
# 54    3659        3      Namun  SCONJ          O
# 55    3659        3      tepat    ADJ          O
# 56    3659        3         di    ADP          O
# 57    3659        3     lokasi   NOUN          O
# 58    3659        3   kejadian   NOUN          O
# 59    3659        3        ban   NOUN          O
# 60    3659        3   belakang    ADJ          O

# %%
out.to_csv("./OUTPUT/PREDICTED.csv")
